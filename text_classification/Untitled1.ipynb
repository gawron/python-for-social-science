# %%
import time
print(time.localtime().strftime("%H %M %S"))
dir(time)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import time
# ----> 2 print(time.localtime().strftime("%H %M %S"))
#       3 dir(time)
#
# AttributeError: 'time.struct_time' object has no attribute 'strftime'

# %%
from datetime import datetime
d = datetime.now()
print(d)
d.strftime("%h %M %S")
# Out:
# 2024-11-25 14:23:41.626710
# 'Nov 23 41'
