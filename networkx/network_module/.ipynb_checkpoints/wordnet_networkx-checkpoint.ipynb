# %% [markdown]
# ## Using networkx on word graphs (Wordnet)

# %% [markdown]
# For this notebook you need some homegrown code, a module called `code_networkx`, which
# is distributed with the zipfile containing this notebook or located at http://www-rohan.sdsu.edu/~gawron/python_for_ss/course_core/assignments/code_networkx.py.  In any case, it should be in the same directory as this noteboo,, because it is not a standard Python
# distribution.
#
# You should also have nltk and the wordnet corpus (which may need to be downloaded
# via `nltk.download()`).
#
# Executing the first cell should give you a pretty good idea of whether you've
# got the basics.

# %%
import networkx as nx
import matplotlib
import sys,random
from nltk.corpus import wordnet as wn
from collections import Counter

def traverse(graph, start, node, rel='hyponyms',max_depth=None,prob=1.0,
             do_leaves=True):
    """
    This calls itself recursively following links
    of type C{rel} extending from C{child}.  C{Start} is the
    node the recursive traversal started at, passed in
    so that we can compute the depth of the traversal thus far.
    This is not the same as the depth of the recursion,
    which could be computed more easily.  The depth
    of the traversal is defined as the shortest distance
    between the start and node.  'rels' is a string
    that is turned into a method with C{getattr} so it must be legal
    method name on C{node}, and it must return a container of nodes
    (e.g., hyponyms,hypernyms, antonyms)

    prob is the prob that a node should be included. So prob=1.0 means
    include all nodes.
    """
    depth = node.shortest_path_distance(start)
    graph.depth[node.name] = depth
    #for child in node.hyponyms():
    for child in getattr(node,rel)():
        if random.random() > prob:
            continue
        if do_leaves or getattr(child,rel)():
            graph.add_edge(node.name().split('.')[0],
                           child.name().split('.')[0]) # [_add-edge]
        else:
            continue
        if (max_depth is None) or depth < max_depth:
            traverse(graph, start, child, rel=rel,max_depth=max_depth) # [_recursive-traversal]
        else:
            graph.depth[child.name] = child.shortest_path_distance(start)
            

def rel_graph(start,rel='hyponyms',max_depth=None,prob=1.0,do_leaves=True,graph_in=None):
    if graph_in is None:
        G = nx.Graph() # [_define-graph]
        G.depth = {}
    else:
        G = graph_in
    traverse(G, start, start,rel=rel,max_depth=max_depth,prob=prob,do_leaves=do_leaves)
    return G

# %%
from nltk.corpus import wordnet as wn
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
#matplotlib.pyplot.switch_backend('QT4Agg')

dog= wn.synsets('dog','n')[0]
dog_nw = rel_graph(dog,rel='hyponyms',max_depth=3,prob=.8)
#dog_nw = rel_graph(dog,rel='hyponyms')
#dog_nw = rel_graph(dog)

person = wn.synsets('person','n')[0]
#person_nw = c_nx.rel_graph(person,rel='hyponyms',max_depth=3,prob=.8)
#person_nw = c_nx.rel_graph(person,rel='hyponyms')
person_nw = rel_graph(person)

# %%
len(person_nw)
# Out:
# 6261

# %%
dog_nw

# %%
dog_nw.nodes()
# Out:
# NodeView(('dog', 'basenji', 'corgi', 'cardigan', 'pembroke', 'cur', 'feist', 'pariah_dog', 'dalmatian', 'liver-spotted_dalmatian', 'great_pyrenees', 'hunting_dog', 'courser', 'dachshund', 'sausage_dog', 'hound', 'afghan_hound', 'basset', 'beagle', 'bloodhound', 'bluetick', 'boarhound', 'coonhound', 'black-and-tan_coonhound', 'coondog', 'foxhound', 'american_foxhound', 'english_foxhound', 'walker_hound', 'greyhound', 'italian_greyhound', 'whippet', 'harrier', 'ibizan_hound', 'norwegian_elkhound', 'otterhound', 'plott_hound', 'redbone', 'saluki', 'scottish_deerhound', 'staghound', 'weimaraner', 'wolfhound', 'borzoi', 'irish_wolfhound', 'rhodesian_ridgeback', 'sporting_dog', 'bird_dog', 'griffon', 'pointer', 'german_short-haired_pointer', 'vizsla', 'retriever', 'chesapeake_bay_retriever', 'curly-coated_retriever', 'flat-coated_retriever', 'golden_retriever', 'labrador_retriever', 'setter', 'english_setter', 'gordon_setter', 'irish_setter', 'spaniel', 'brittany_spaniel', 'clumber', 'cocker_spaniel', 'field_spaniel', 'springer_spaniel', 'sussex_spaniel', 'water_spaniel', 'water_dog', 'terrier', 'airedale', 'australian_terrier', 'bedlington_terrier', 'border_terrier', 'boston_bull', 'bullterrier', 'american_staffordshire_terrier', 'staffordshire_bullterrier', 'cairn', 'dandie_dinmont', 'fox_terrier', 'smooth-haired_fox_terrier', 'wire-haired_fox_terrier', 'irish_terrier', 'kerry_blue_terrier', 'lhasa', 'norfolk_terrier', 'norwich_terrier', 'rat_terrier', 'manchester_terrier', 'schnauzer', 'giant_schnauzer', 'miniature_schnauzer', 'standard_schnauzer', 'scotch_terrier', 'silky_terrier', 'skye_terrier', 'clydesdale_terrier', 'soft-coated_wheaten_terrier', 'tibetan_terrier', 'west_highland_white_terrier', 'wirehair', 'lakeland_terrier', 'welsh_terrier', 'yorkshire_terrier', 'mexican_hairless', 'newfoundland', 'pooch', 'poodle', 'large_poodle', 'miniature_poodle', 'standard_poodle', 'toy_poodle', 'pug', 'puppy', 'spitz', 'chow', 'keeshond', 'pomeranian', 'samoyed', 'toy_dog', 'chihuahua', 'japanese_spaniel', 'maltese_dog', 'pekinese', 'shih-tzu', 'toy_spaniel', 'english_toy_spaniel', 'blenheim_spaniel', 'king_charles_spaniel', 'papillon', 'toy_terrier', 'working_dog', 'boxer', 'bull_mastiff', 'bulldog', 'french_bulldog', 'eskimo_dog', 'great_dane', 'guide_dog', 'seeing_eye_dog', 'hearing_dog', 'mastiff', 'tibetan_mastiff', 'police_dog', 'saint_bernard', 'seizure-alert_dog', 'sennenhunde', 'appenzeller', 'bernese_mountain_dog', 'entlebucher', 'greater_swiss_mountain_dog', 'shepherd_dog', 'belgian_sheepdog', 'groenendael', 'malinois', 'border_collie', 'bouvier_des_flandres', 'briard', 'collie', 'german_shepherd', 'kelpie', 'komondor', 'old_english_sheepdog', 'rottweiler', 'shetland_sheepdog', 'sled_dog', 'malamute', 'siberian_husky', 'watchdog', 'attack_dog', 'housedog', 'kuvasz', 'pinscher', 'affenpinscher', 'doberman', 'miniature_pinscher', 'schipperke'))

# %%
person_l = wn.synsets('dog','n')
person_l
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01')]

# %% [markdown]
# What this does is extract a sizable subgraph from the WordNet graph consisting of specializations of the word `dog` (Schnauser,Cocker Spaniel, Border Collie, etcetera).
# This `networkx` graph is called `dog_nw` above. The variable `dog` is set to be the first (most important) concept associated with the word *dog*.  This is used as a starting point for a traversal of the WordNet graph which follows only **hyponym** links (more specific than).

# %%
import networkx as nx
import math
K=1/math.sqrt(len(dog_nw.nodes()))
pos = nx.spring_layout(dog_nw,scale=5.0,k=5*K) 

plt.figure(figsize=(10,15))
nx.draw_networkx_labels(dog_nw,pos,font_size=9,font_color='black')
nx.draw_networkx_nodes(dog_nw,pos,node_color='red',node_size=20,node_shape='o')
nx.draw_networkx_edges(dog_nw,pos)

# %%
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# It's fun to edit out the label drawing command and view the graph without labels.  You can see that label overlap is obscuring a lot of the beauty of the picture.
# To deal with the problem of label overlap, we have tried using a small font and resetting the figure size as above. We have also tweaked the value of the `k` parameter in the `spring_layout` function.  The default value  is `K`, as defined above, and we have quintupled it to increase the default distance between nodes (which can still change in the actual rendering due to the needs of the algorithm).  You can try tweaking the figure size and the value of `k` some more to get a better picture but see the networkx notebooks for more robust ideas about how to deal with label placement.  You can also use the "Zoom to rectangle" tool in the matplotlib GUI, or the "Edit curves,lines, and axes parameters" tool (Checkmark icon).  You can save in the zoomed state, to use the adjustments to save a cropped or clearer version of the image.

# %% [markdown]
# ## Top of WordNet Noun hierarchy

# %%
import code_networkx as c_nx
from nltk.corpus import wordnet as wn
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt


top = wn.synsets('entity','n')[0]
#dog_nw = c_nx.rel_graph(dog,rel='hyponyms',max_depth=3,prob=.8)
top_nw = c_nx.rel_graph(top,rel='hyponyms',max_depth=2)
#dog_nw = c_nx.rel_graph(dog)

#person = wn.synsets('person','n')[0]
#person_nw = c_nx.rel_graph(person,rel='hyponyms',max_depth=3,prob=.8)
#person_nw = c_nx.rel_graph(person,rel='hyponyms')
#person_nw = c_nx.rel_graph(person)

# %%
len(top_nw)
# Out:
# 236

# %%
top_nw.nodes()
# Out:
# NodeView(('entity', 'abstraction', 'attribute', 'ballast', 'character', 'cheerfulness', 'common_denominator', 'depth', 'eidos', 'ethos', 'human_nature', 'inheritance', 'personality', 'property', 'quality', 'shape', 'space', 'state', 'thing', 'time', 'trait', 'uncheerfulness', 'communication', 'auditory_communication', 'contagion', 'didacticism', 'display', 'document', 'expressive_style', 'indication', 'language', 'message', 'paralanguage', 'psychic_communication', 'publication', 'sign', 'signal', 'visual_communication', 'voice', 'written_communication', 'group', 'actinoid', 'arrangement', 'association', 'biological_group', 'circuit', 'citizenry', 'collection', 'community', 'edition', 'electron_shell', 'ethnic_group', 'halogen', 'kingdom', 'multitude', 'people', 'population', 'race', 'rare_earth', 'sainthood', 'series', 'social_group', 'straggle', 'subgroup', 'swarm', 'system', 'varna', 'world', 'measure', 'cordage', 'definite_quantity', 'fundamental_quantity', 'indefinite_quantity', 'magnetization', 'octane_number', 'playing_period', 'point', 'probability', 'proof', 'quantum', 'radical', 'relative_quantity', 'system_of_measurement', 'time_interval', 'time_unit', 'value', 'volume', 'otherworld', 'psychological_feature', 'cognition', 'event', 'motivation', 'relation', 'affinity', 'business_relation', 'causality', 'change', 'comparison', 'connection', 'control', 'foundation', 'function', 'interrelation', 'kinship', 'linguistic_relation', 'logical_relation', 'magnitude_relation', 'mathematical_relation', 'opposition', 'ownership', 'part', 'position', 'possession', 'reciprocality', 'relationship', 'social_relation', 'temporal_relation', 'unconnectedness', 'set', 'diagonal', 'domain', 'field', 'image', 'intersection', 'interval', 'locus', 'mandelbrot_set', 'mathematical_space', 'null_set', 'solution', 'subset', 'universal_set', 'physical_entity', 'causal_agent', 'agent', 'catalyst', 'cause_of_death', 'danger', 'destiny', 'deus_ex_machina', 'engine', 'first_cause', 'nature', 'operator', 'person', 'power', 'supernatural', 'theurgy', 'vital_principle', 'matter', 'antimatter', 'dark_matter', 'emanation', 'fluid', 'glop', 'residue', 'sediment', 'sludge', 'solid', 'solute', 'substance', 'vegetable_matter', 'ylem', 'object', 'catch', 'charm', 'commemorative', 'curio', 'discard', 'draw', 'film', 'finding', 'floater', 'fomite', 'geological_formation', 'growth', 'hail', 'head', 'hoodoo', 'ice', 'je_ne_sais_quoi', 'keepsake', 'land', 'location', 'makeweight', 'moon', 'neighbor', 'paring', 'remains', 'ribbon', 'shiner', 'snake', 'stuff', 'triviality', 'vagabond', 'wall', 'web', 'whole', 'process', 'chelation', 'dealignment', 'decrease', 'degeneration', 'development', 'economic_process', 'encapsulation', 'execution', 'human_process', 'increase', 'industrial_process', 'irreversible_process', 'iteration', 'natural_process', 'operation', 'organic_process', 'phenomenon', 'photography', 'processing', 'reversible_process', 'sensitization', 'shaping', 'variation', 'body_of_water', 'inessential', 'necessity', 'reservoir', 'subject', 'unit', 'variable', 'freshener', 'horror', 'jimdandy', 'pacifier', 'security_blanket', 'stinker', 'whacker'))

# %%
thing = wn.synsets('physical_entity','n')[0]
thing_nw = rel_graph(thing,rel='hyponyms',max_depth=1)

# %%
len(thing_nw)
# Out:
# 101

# %%
import math
K=1/math.sqrt(len(thing_nw.nodes()))
top_pos = nx.spring_layout(top_nw,scale=5.0,k=5*K) 
#top_pos = nx.spring_layout(thing_nw) 

plt.figure(figsize=(8,8))
nx.draw_networkx_labels(thing_nw,top_pos,font_size=9,font_color='black')
nx.draw_networkx_nodes(thing_nw,top_pos,node_color='red',node_size=20,node_shape='o')
nx.draw_networkx_edges(thing_nw,top_pos)
