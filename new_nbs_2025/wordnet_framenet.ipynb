# %% [markdown]
# ## Intro

# %% [markdown]
# Wordnet is blah blah blah.
#
# ### Other resources hooked up to WordNet
#
# Let's use the following environment vars:
#
# ```python
# CORPUS = /Users/gawron/ext/corpus/
# CODE = /Users/gawron/Desktop/src/sentiment_tagger/
# ```
#
# 1.  Sentiwordsnet: /Users/gawron/ext/corpus/sentiwordnet; access_wordnet_for_sentiwordnet.py contains code
#     for linking valence.
# 2.  FrameNet.  XML format for frames.  Version 1.5.  `CORPUS`/framenet_plus/framenet
#     has the Framenet data; `CODE`/mt/framenet has python code for loading and reading the
#     XMl data (using the Python `xml` module).

# %%
import nltk
stemmers = [nm for nm in dir(nltk) if "temmer" in nm]
print(stemmers)
stemmer = nltk.PorterStemmer()
#stemmer.stem("sadness")
# Out:
# ['ISRIStemmer', 'LancasterStemmer', 'PorterStemmer', 'RSLPStemmer', 'RegexpStemmer', 'SnowballStemmer', 'StemmerI']

# %%
from nltk.corpus import wordnet as wn
#from nltk import wordnet as wnl

# %%
len(all_ss)
# Out:
# 117659

# %%
all_ss = list(wn.all_synsets())

# %% [markdown]
# The parts of speech in wordnet: `s` is satellite (to be explained).

# %%
from collections import Counter

ctr = Counter(ss.pos() for ss in all_ss)
ctr
# Out:
# Counter({'n': 82115, 'v': 13767, 's': 10693, 'a': 7463, 'r': 3621})

# %% [markdown]
# The **synsets** (or **concepts**) related to the noun "dog":

# %%
dog_synsets = wn.synsets("dog","n")
for ss in dog_synsets:
    print(ss.name(),ss.definition(),end="\n\n")
# Out:
# dog.n.01 a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds
#
# frump.n.01 a dull unattractive unpleasant girl or woman
#
# dog.n.03 informal term for a man
#
# cad.n.01 someone who is morally reprehensible
#
# frank.n.02 a smooth-textured sausage of minced beef or pork usually smoked; often served on a bread roll
#
# pawl.n.01 a hinged catch that fits into a notch of a ratchet to move a wheel forward or prevent it from moving backward
#
# andiron.n.01 metal supports for logs in a fireplace

# %%
#The **synsets** of the noun "file":
dog_synsets = wn.synsets("file","n")
for ss in dog_synsets:
    print(ss.name(),ss.definition(),end="\n\n")
# Out:
# file.n.01 a set of related records (either written or electronic) kept together
#
# file.n.02 a line of persons or things ranged one behind the other
#
# file.n.03 office furniture consisting of a container for keeping papers in order
#
# file.n.04 a steel hand tool with small sharp teeth on some or all of its surfaces; used for smoothing wood or metal

# %%
#The **synsets** of the noun "record":
dog_synsets = wn.synsets("record","n")
for ss in dog_synsets:
    print(ss.name(),ss.definition(),end="\n\n")
# Out:
# record.n.01 anything (such as a document or a phonograph record or a photograph) providing permanent evidence of or information about past events
#
# phonograph_record.n.01 sound recording consisting of a disk with a continuous groove; used to reproduce music by rotating while a phonograph needle tracks in the groove
#
# record.n.03 the number of wins versus losses and ties a team has had
#
# record.n.04 the sum of recognized accomplishments
#
# record.n.05 a compilation of the known facts regarding something or someone
#
# record.n.06 an extreme attainment; the best (or worst) performance ever attested (as in a sport)
#
# record.n.07 a document that can serve as legal evidence of a transaction
#
# criminal_record.n.01 a list of crimes for which an accused person has been previously convicted

# %% [markdown]
# ## Satellites: Wheels and axes

# %% [markdown]
# What satellites all share: some  **adjective** synset they are all satellites **of**.
#
#
# Technically,  **a hub** (to which they all play satellite) linked via the `similar_to` relation:

# %%
all_satellites = sorted(ss.name() for ss in all_ss if ss.pos() == "s")
print(len(all_satellites))
Counter(len(wn.synset(ss).similar_tos()) for ss in all_satellites)
# Out:
# 10693
# Counter({1: 10693})

# %% [markdown]
# For example, Consider the senses of "bald", all of which have pos "s".

# %%
baldies = wn.synsets("bald","a")
for ss in baldies:
    print(ss.name(),ss.definition())
# Out:
# bald.s.01 with no effort to conceal
# bald.s.02 lacking hair on all or most of the scalp
# bald.s.03 without the natural or usual covering

# %%
def print_head_and_satellites(head,satellites):
    banner = f"Head: {head.name()}"
    print(banner)
    print("="*len(banner))
    for sat in satellites:
        print(f"  {sat.name()}")
    
def get_wheel (ss,verbose=False):
    """
    ss is a satellite if some head (because it is pos s).
    
    Return the head and all satellites of the ehad (including ss)
    """
    assert ss.pos() == "s", "Only synsets with part of speech s have wheels"
    # The rule is that satellites have only one head linked by .similar_tos()
    head = ss.similar_tos()[0]
    satellites = get_satellites(head,verbose=verbose)
    return head,satellites

def get_satellites(head,verbose=False,include_head=False):
    """
    Return all satellites of {head} 
    """
    satellites = head.similar_tos()
    if verbose:
        print_head_and_satellites(head,satellites)
    return [head] + satellites

def get_wheels_and_axle(ss,verbose=False,return_set=False):
    head, satellites = get_wheel (ss,verbose=verbose)
    # antonymy is an attribute of lemmas, not synsets.  This is confusing.
    antonyms = [ant.synset() for lem in head.lemmas() for ant in lem.antonyms()]
    if verbose:
        print()
    ant_wheels = [get_satellites (ant,verbose=verbose,include_head=True) for ant in antonyms] 
    if return_set:
        res = set([head]).union(satellites)
        for wheel in ant_wheels:
            res.update(wheel)
        return res
    else:
        return head, satellites, ant_wheels

# %% [markdown]
# Let's look at the head of the first sense the synset `bald.s.01`, and get all the `similar_tos()` of that head (all of that head's satellites).

# %% [markdown]
# The head connected to `bald.s.01` by `similar_tos()` is `overt.a.01`.  The 4 satellites of `overt.a.01`
# are the `similar_tos()` of `overt.a.01`:

# %%
ss = baldies[0]
print(ss.name(),end="\n\n")
head, sats = get_wheel(ss,verbose=True)
# Out:
# bald.s.01
#
# Head: overt.a.01
# ================
#   visible.s.02
#   undisguised.s.01
#   bald.s.01
#   naked.s.04

# %% [markdown]
# We call such a Wordnet subnetwork a **wheel**: `overt.a.01` is the **hub**.  Adjectives like
# `visible.s`, `undisguised.s` and `bald.s` (which is where we started), are the **satellites**.

# %% [markdown]
# This time we find the head and it satellites; then we find the sole antonym of the head `overt.a.01`, `covert.a.01`, which is another head, and find all of its satellites:

# %%
res = get_wheels_and_axle(ss,return_set=True)
#wn.synset("overt.a.01") in res
res
# Out:
# {Synset('backstair.s.01'),
#  Synset('bald.s.01'),
#  Synset('black.s.10'),
#  Synset('clandestine.s.01'),
#  Synset('cloaked.s.01'),
#  Synset('collusive.s.01'),
#  Synset('covert.a.01'),
#  Synset('naked.s.04'),
#  Synset('overt.a.01'),
#  Synset('secret.s.04'),
#  Synset('secret.s.09'),
#  Synset('sub-rosa.s.01'),
#  Synset('subterranean.s.02'),
#  Synset('under_wraps.s.01'),
#  Synset('undisclosed.s.01'),
#  Synset('undisguised.s.01'),
#  Synset('visible.s.02')}

# %% [markdown]
# An axis of anyonymy connects the two wheels:

# %%
head, satellites, ant_wheels = get_wheels_and_axle(ss,verbose=True)
# Out:
# Head: overt.a.01
# ================
#   naked.s.04
#   undisguised.s.01
#   bald.s.01
#   visible.s.02
#
# Head: covert.a.01
# =================
#   secret.s.09
#   clandestine.s.01
#   backstair.s.01
#   cloaked.s.01
#   sub-rosa.s.01
#   under_wraps.s.01
#   collusive.s.01
#   undisclosed.s.01
#   subterranean.s.02
#   black.s.10
#   secret.s.04

# %%
import random
sat_samp = random.sample(all_satellites,60)
for sat in sat_samp:
    print(sat)
    get_wheels_and_axle(wn.synset(sat),verbose=True)
    print(end="\n^^^^^^^^^^^^^^^^^^^^^^\n")
# Out:
# supperless.s.01
# Head: hungry.a.01
# =================
#   supperless.s.01
#   peckish.s.01
#   empty.s.03
#   famished.s.01
#
# Head: thirsty.a.02
# ==================
#
# ^^^^^^^^^^^^^^^^^^^^^^
# deprecative.s.02
# Head: critical.a.01
# ===================
#   captious.s.01
#   censorious.s.01
#   hypercritical.s.01
#   scathing.s.01
#   deprecative.s.02
#   searing.s.01
#
# Head: uncritical.a.02
# =====================
#
# ^^^^^^^^^^^^^^^^^^^^^^
# apostate.s.01
# Head: unfaithful.a.01
# =====================
#   punic.s.02
#   apostate.s.01
#   untrue.s.02
#
# Head: faithful.a.01
# ===================
#   true.s.03
#   firm.s.10
#
# ^^^^^^^^^^^^^^^^^^^^^^
# oblanceolate.s.01
# Head: simple.a.06
# =================
#   apiculate.s.01
#   lanceolate.s.01
#   lyrate.s.01
#   oblanceolate.s.01
#   ovate.s.01
#   two-needled.s.01
#   acerate.s.01
#   peltate.s.01
#   cuneate.s.01
#   spatulate.s.01
#   acuminate.s.01
#   pandurate.s.01
#   dolabriform.s.01
#   reniform.s.01
#   oblong.s.01
#   obtuse.s.02
#   orbiculate.s.01
#   obovate.s.01
#   caudate.s.02
#   three-needled.s.01
#   needled.s.01
#   ensiform.s.01
#   five-needled.s.01
#   elliptic.s.01
#   perfoliate.s.01
#   unlobed.s.01
#   deltoid.s.01
#   sagittate.s.01
#   four-needled.s.01
#   hastate.s.01
#   linear.s.04
#   cordate.s.01
#
# Head: compound.a.01
# ===================
#   pinnate.s.01
#   lobed.s.01
#   bipinnatifid.s.01
#   tripinnate.s.01
#   palmate.s.02
#   quinquefoliate.s.01
#   bipartite.s.01
#   pinnatisect.s.01
#   cleft.s.01
#   bilobate.s.01
#   conjugate.s.02
#   tripinnatifid.s.01
#   ternate.s.01
#   bipinnate.s.01
#   parted.s.01
#   incised.s.01
#   palmatifid.s.01
#   even-pinnate.s.01
#   binate.s.01
#   trifoliate.s.01
#   trilobate.s.01
#   radiate.s.02
#   pinnatifid.s.01
#   odd-pinnate.s.01
#   pedate.s.01
#   decompound.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# oppressive.s.02
# Head: domineering.a.01
# ======================
#   oppressive.s.02
#   blustery.s.02
#   heavy-handed.s.02
#   authoritarian.s.02
#   cavalier.s.01
#   autocratic.s.01
#
# Head: submissive.a.01
# =====================
#   meek.s.03
#   dominated.s.02
#   abject.s.04
#   bowed.s.04
#   cringing.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# desperate.s.05
# Head: imperative.a.01
# =====================
#   adjuratory.s.02
#   clamant.s.02
#   peremptory.s.02
#   pressing.s.01
#   strident.s.03
#   desperate.s.05
#
# Head: beseeching.a.01
# =====================
#   importunate.s.01
#   suppliant.s.01
#   precatory.s.01
#   adjuratory.s.01
#   mendicant.s.01
#   petitionary.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# well-groomed.s.02
# Head: groomed.a.01
# ==================
#   plastered.s.01
#   pomaded.s.01
#   brushed.s.02
#   sleek.s.01
#   well-groomed.s.01
#   well-groomed.s.02
#   kempt.s.01
#
# Head: ungroomed.a.01
# ====================
#   bushy.s.01
#   ill-dressed.s.01
#   unbrushed.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# semipermeable.s.01
# Head: permeable.a.01
# ====================
#   semipermeable.s.01
#   porous.s.01
#
# Head: impermeable.a.01
# ======================
#   water-repellent.s.01
#   retentive.s.03
#
# ^^^^^^^^^^^^^^^^^^^^^^
# harmonious.s.02
# Head: balanced.a.01
# ===================
#   stable.s.04
#   self-balancing.s.01
#   harmonious.s.02
#   counterbalanced.s.01
#   well-balanced.s.01
#   poised.s.01
#
# Head: unbalanced.a.01
# =====================
#   labile.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# red-coated.s.01
# Head: clothed.a.01
# ==================
#   cassocked.s.01
#   red-coated.s.01
#   bundled-up.s.01
#   arrayed.s.01
#   vestmented.s.01
#   habited.s.01
#   appareled.s.01
#   turned_out.s.01
#   gowned.s.01
#   cowled.s.01
#   caparisoned.s.01
#   togged.s.01
#   underdressed.s.01
#   overdressed.s.01
#   dressed.s.04
#   surpliced.s.01
#   suited.s.02
#   dighted.s.01
#   tuxedoed.s.01
#   costumed.s.01
#   uniformed.s.01
#   heavy-coated.s.01
#   breeched.s.01
#   coated.s.02
#   petticoated.s.01
#
# Head: unclothed.a.01
# ====================
#   en_deshabille.s.01
#   mother-naked.s.01
#   without_a_stitch.s.01
#   off-the-shoulder.s.01
#   seminude.s.01
#   unappareled.s.01
#   barelegged.s.01
#   half-clothed.s.01
#   bare-breasted.s.01
#   clothesless.s.01
#   stripped.s.03
#   bare-assed.s.01
#   exposed.s.02
#   starkers.s.01
#   bareheaded.s.01
#   bottomless.s.04
#   bare.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# bountied.s.01
# Head: rewarding.a.01
# ====================
#   bountied.s.01
#   rewardful.s.01
#
# Head: unrewarding.a.01
# ======================
#   thankless.s.02
#   profitless.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# sedentary.s.01
# Head: inactive.a.09
# ===================
#   desk-bound.s.01
#   hypoactive.s.01
#   abeyant.s.01
#   inert.s.03
#   sedentary.s.01
#
# Head: active.a.05
# =================
#   hyperactive.s.01
#   on_the_go.s.01
#   acrobatic.s.01
#   about.s.01
#   agile.s.01
#   hot.s.21
#   sporty.s.03
#
# ^^^^^^^^^^^^^^^^^^^^^^
# one_hundred_seventy.s.01
# Head: cardinal.a.02
# ===================
#   forty-eight.s.01
#   four.s.01
#   eighty-five.s.01
#   twenty-seven.s.01
#   fifty.s.01
#   one_hundred_eighty.s.01
#   non-zero.s.01
#   twenty-nine.s.01
#   forty-seven.s.01
#   thousand.s.01
#   one.s.01
#   ten.s.01
#   fifty-four.s.01
#   ninety-one.s.01
#   eighty.s.01
#   forty-one.s.01
#   one_hundred_ten.s.01
#   ninety-eight.s.01
#   nine.s.01
#   twenty-four.s.01
#   ninety.s.01
#   ninety-two.s.01
#   ten_thousand.s.01
#   three_hundred.s.01
#   forty-three.s.01
#   eighty-eight.s.01
#   zero.s.01
#   ninety-five.s.01
#   thirty-seven.s.01
#   twelve.s.01
#   thirty-one.s.01
#   three.s.01
#   seventy-seven.s.01
#   fifty-six.s.01
#   million.s.01
#   eighty-six.s.01
#   eighty-nine.s.01
#   seventy-three.s.01
#   one_hundred_seventy.s.01
#   seventy-six.s.01
#   one_hundred_five.s.01
#   seventeen.s.01
#   one_hundred_fifty.s.01
#   seventy-eight.s.01
#   seventy-two.s.01
#   hundred.s.01
#   one_hundred_thirty.s.01
#   thirty-nine.s.01
#   nineteen.s.01
#   hundred_thousand.s.01
#   thirty-six.s.01
#   twenty-eight.s.01
#   seventy-four.s.01
#   ninety-six.s.01
#   sixty-five.s.01
#   twenty-two.s.01
#   one_hundred_ninety.s.01
#   one_hundred_fifty-five.s.01
#   one_hundred_sixty.s.01
#   seventy-five.s.01
#   sixty-nine.s.01
#   eighty-four.s.01
#   twenty.s.01
#   sixty-six.s.01
#   forty-four.s.01
#   thirteen.s.01
#   zillion.s.01
#   eighty-two.s.01
#   forty.s.01
#   six.s.01
#   fifty-eight.s.01
#   two.s.01
#   fifty-one.s.01
#   fifty-three.s.01
#   sixty.s.01
#   one_hundred_seventy-five.s.01
#   sixty-seven.s.01
#   sixty-two.s.01
#   one_hundred_twenty-five.s.01
#   thirty-four.s.01
#   one_hundred_thirty-five.s.01
#   twenty-six.s.01
#   twenty-one.s.01
#   eighty-one.s.01
#   four_hundred.s.01
#   sixteen.s.01
#   one_hundred_fifteen.s.01
#   eight.s.01
#   fifteen.s.01
#   thirty.s.01
#   ninety-three.s.01
#   forty-nine.s.01
#   ninety-four.s.01
#   forty-six.s.01
#   twenty-five.s.01
#   thirty-two.s.01
#   trillion.s.02
#   fifty-nine.s.01
#   one_hundred_forty.s.01
#   one_hundred_twenty.s.01
#   sixty-eight.s.01
#   seventy-one.s.01
#   eleven.s.01
#   eighteen.s.01
#   thirty-five.s.01
#   seventy-nine.s.01
#   seven.s.01
#   hundred_and_one.s.01
#   fourteen.s.01
#   eighty-seven.s.01
#   five.s.01
#   forty-two.s.01
#   fifty-two.s.01
#   ninety-seven.s.01
#   twenty-three.s.01
#   sixty-one.s.01
#   thirty-three.s.01
#   ninety-nine.s.01
#   seventy.s.01
#   fifty-five.s.01
#   one_hundred_sixty-five.s.01
#   trillion.s.01
#   forty-five.s.01
#   sixty-four.s.01
#   one_hundred_forty-five.s.01
#   billion.s.02
#   sixty-three.s.01
#   thirty-eight.s.01
#   two_hundred.s.01
#   fifty-seven.s.01
#   billion.s.01
#   five_hundred.s.01
#   eighty-three.s.01
#
# Head: ordinal.a.02
# ==================
#   eleventh.s.01
#   hundred-and-tenth.s.01
#   trillionth.s.01
#   hundred-and-fiftieth.s.01
#   thirty-sixth.s.01
#   four-hundredth.s.01
#   forty-ninth.s.01
#   forty-fifth.s.01
#   twenty-first.s.01
#   zeroth.s.01
#   thirty-fifth.s.01
#   forty-eighth.s.01
#   five-hundredth.s.01
#   twenty-fifth.s.01
#   fifty-fifth.s.01
#   hundred-and-sixty-fifth.s.01
#   sixty-fifth.s.01
#   second.s.01
#   hundred-and-fifty-fifth.s.01
#   thousandth.s.01
#   thirty-first.s.01
#   hundred-and-forty-fifth.s.01
#   eighteenth.s.01
#   thirty-seventh.s.01
#   hundred-and-twentieth.s.01
#   hundred-and-seventy-fifth.s.01
#   quadrillionth.s.01
#   hundred-and-fifteenth.s.01
#   seventeenth.s.01
#   fourth.s.01
#   tenth.s.01
#   twenty-second.s.01
#   ninetieth.s.01
#   twenty-ninth.s.01
#   twelfth.s.01
#   sixth.s.01
#   seventy-fifth.s.01
#   eightieth.s.01
#   thirty-third.s.01
#   hundred-and-eightieth.s.01
#   umpteenth.s.01
#   millionth.s.01
#   thirty-second.s.01
#   ninth.s.01
#   first.s.02
#   fifth.s.01
#   forty-third.s.01
#   forty-first.s.01
#   nineteenth.s.01
#   fortieth.s.01
#   twenty-sixth.s.01
#   fiftieth.s.01
#   forty-sixth.s.01
#   twenty-fourth.s.01
#   hundredth.s.01
#   hundred-and-first.s.01
#   hundred-and-thirtieth.s.01
#   seventh.s.01
#   thirteenth.s.01
#   twenty-seventh.s.01
#   thirty-eighth.s.01
#   thirty-ninth.s.01
#   sixtieth.s.01
#   ninety-fifth.s.01
#   nth.s.01
#   forty-second.s.01
#   seventieth.s.01
#   fifteenth.s.01
#   third.s.01
#   eighty-fifth.s.01
#   hundred-and-ninetieth.s.01
#   billionth.s.01
#   sixteenth.s.01
#   thirty-fourth.s.01
#   forty-seventh.s.01
#   hundred-and-fortieth.s.01
#   hundred-and-twenty-fifth.s.01
#   forty-fourth.s.01
#   zero.s.03
#   fourteenth.s.01
#   twenty-eighth.s.01
#   twentieth.s.01
#   two-hundredth.s.01
#   three-hundredth.s.01
#   twenty-third.s.01
#   eighth.s.01
#   quintillionth.s.01
#   thirtieth.s.01
#   sixty-fourth.s.01
#   hundred-and-thirty-fifth.s.01
#   hundred-and-seventieth.s.01
#   hundred-and-sixtieth.s.01
#   hundred-and-fifth.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# crazed.s.01
# Head: insane.a.01
# =================
#   brainsick.s.01
#   maniacal.s.01
#   paranoid.s.01
#   hebephrenic.s.01
#   screw-loose.s.01
#   amuck.s.01
#   balmy.s.01
#   certifiable.s.01
#   non_compos_mentis.s.01
#   crazed.s.01
#   mentally_ill.s.01
#   crackbrained.s.01
#   maniclike.s.01
#   psychopathic.s.01
#   lunatic.s.01
#   schizophrenic.s.01
#   fey.s.01
#   raving_mad.s.01
#   manic-depressive.s.01
#   psychotic.s.01
#
# Head: sane.a.01
# ===============
#   in_his_right_mind.s.01
#   lucid.s.02
#   compos_mentis.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# prima_facie.s.01
# Head: clear.a.01
# ================
#   broad.s.04
#   clear-cut.s.01
#   vivid.s.02
#   unmistakable.s.01
#   prima_facie.s.01
#   limpid.s.03
#
# Head: unclear.a.02
# ==================
#   blurred.s.02
#   confusing.s.02
#   obscure.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# heart-healthy.s.01
# Head: wholesome.a.01
# ====================
#   hearty.s.02
#   healthy.s.03
#   heart-healthy.s.01
#   salubrious.s.02
#   organic.s.04
#   alimentary.s.01
#
# Head: unwholesome.a.01
# ======================
#   rich.s.09
#   morbid.s.01
#   insalubrious.s.01
#   nauseating.s.01
#   insubstantial.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# trillion.s.01
# Head: cardinal.a.02
# ===================
#   forty-eight.s.01
#   four.s.01
#   eighty-five.s.01
#   twenty-seven.s.01
#   fifty.s.01
#   one_hundred_eighty.s.01
#   non-zero.s.01
#   twenty-nine.s.01
#   forty-seven.s.01
#   thousand.s.01
#   one.s.01
#   ten.s.01
#   fifty-four.s.01
#   ninety-one.s.01
#   eighty.s.01
#   forty-one.s.01
#   one_hundred_ten.s.01
#   ninety-eight.s.01
#   nine.s.01
#   twenty-four.s.01
#   ninety.s.01
#   ninety-two.s.01
#   ten_thousand.s.01
#   three_hundred.s.01
#   forty-three.s.01
#   eighty-eight.s.01
#   zero.s.01
#   ninety-five.s.01
#   thirty-seven.s.01
#   twelve.s.01
#   thirty-one.s.01
#   three.s.01
#   seventy-seven.s.01
#   fifty-six.s.01
#   million.s.01
#   eighty-six.s.01
#   eighty-nine.s.01
#   seventy-three.s.01
#   one_hundred_seventy.s.01
#   seventy-six.s.01
#   one_hundred_five.s.01
#   seventeen.s.01
#   one_hundred_fifty.s.01
#   seventy-eight.s.01
#   seventy-two.s.01
#   hundred.s.01
#   one_hundred_thirty.s.01
#   thirty-nine.s.01
#   nineteen.s.01
#   hundred_thousand.s.01
#   thirty-six.s.01
#   twenty-eight.s.01
#   seventy-four.s.01
#   ninety-six.s.01
#   sixty-five.s.01
#   twenty-two.s.01
#   one_hundred_ninety.s.01
#   one_hundred_fifty-five.s.01
#   one_hundred_sixty.s.01
#   seventy-five.s.01
#   sixty-nine.s.01
#   eighty-four.s.01
#   twenty.s.01
#   sixty-six.s.01
#   forty-four.s.01
#   thirteen.s.01
#   zillion.s.01
#   eighty-two.s.01
#   forty.s.01
#   six.s.01
#   fifty-eight.s.01
#   two.s.01
#   fifty-one.s.01
#   fifty-three.s.01
#   sixty.s.01
#   one_hundred_seventy-five.s.01
#   sixty-seven.s.01
#   sixty-two.s.01
#   one_hundred_twenty-five.s.01
#   thirty-four.s.01
#   one_hundred_thirty-five.s.01
#   twenty-six.s.01
#   twenty-one.s.01
#   eighty-one.s.01
#   four_hundred.s.01
#   sixteen.s.01
#   one_hundred_fifteen.s.01
#   eight.s.01
#   fifteen.s.01
#   thirty.s.01
#   ninety-three.s.01
#   forty-nine.s.01
#   ninety-four.s.01
#   forty-six.s.01
#   twenty-five.s.01
#   thirty-two.s.01
#   trillion.s.02
#   fifty-nine.s.01
#   one_hundred_forty.s.01
#   one_hundred_twenty.s.01
#   sixty-eight.s.01
#   seventy-one.s.01
#   eleven.s.01
#   eighteen.s.01
#   thirty-five.s.01
#   seventy-nine.s.01
#   seven.s.01
#   hundred_and_one.s.01
#   fourteen.s.01
#   eighty-seven.s.01
#   five.s.01
#   forty-two.s.01
#   fifty-two.s.01
#   ninety-seven.s.01
#   twenty-three.s.01
#   sixty-one.s.01
#   thirty-three.s.01
#   ninety-nine.s.01
#   seventy.s.01
#   fifty-five.s.01
#   one_hundred_sixty-five.s.01
#   trillion.s.01
#   forty-five.s.01
#   sixty-four.s.01
#   one_hundred_forty-five.s.01
#   billion.s.02
#   sixty-three.s.01
#   thirty-eight.s.01
#   two_hundred.s.01
#   fifty-seven.s.01
#   billion.s.01
#   five_hundred.s.01
#   eighty-three.s.01
#
# Head: ordinal.a.02
# ==================
#   eleventh.s.01
#   hundred-and-tenth.s.01
#   trillionth.s.01
#   hundred-and-fiftieth.s.01
#   thirty-sixth.s.01
#   four-hundredth.s.01
#   forty-ninth.s.01
#   forty-fifth.s.01
#   twenty-first.s.01
#   zeroth.s.01
#   thirty-fifth.s.01
#   forty-eighth.s.01
#   five-hundredth.s.01
#   twenty-fifth.s.01
#   fifty-fifth.s.01
#   hundred-and-sixty-fifth.s.01
#   sixty-fifth.s.01
#   second.s.01
#   hundred-and-fifty-fifth.s.01
#   thousandth.s.01
#   thirty-first.s.01
#   hundred-and-forty-fifth.s.01
#   eighteenth.s.01
#   thirty-seventh.s.01
#   hundred-and-twentieth.s.01
#   hundred-and-seventy-fifth.s.01
#   quadrillionth.s.01
#   hundred-and-fifteenth.s.01
#   seventeenth.s.01
#   fourth.s.01
#   tenth.s.01
#   twenty-second.s.01
#   ninetieth.s.01
#   twenty-ninth.s.01
#   twelfth.s.01
#   sixth.s.01
#   seventy-fifth.s.01
#   eightieth.s.01
#   thirty-third.s.01
#   hundred-and-eightieth.s.01
#   umpteenth.s.01
#   millionth.s.01
#   thirty-second.s.01
#   ninth.s.01
#   first.s.02
#   fifth.s.01
#   forty-third.s.01
#   forty-first.s.01
#   nineteenth.s.01
#   fortieth.s.01
#   twenty-sixth.s.01
#   fiftieth.s.01
#   forty-sixth.s.01
#   twenty-fourth.s.01
#   hundredth.s.01
#   hundred-and-first.s.01
#   hundred-and-thirtieth.s.01
#   seventh.s.01
#   thirteenth.s.01
#   twenty-seventh.s.01
#   thirty-eighth.s.01
#   thirty-ninth.s.01
#   sixtieth.s.01
#   ninety-fifth.s.01
#   nth.s.01
#   forty-second.s.01
#   seventieth.s.01
#   fifteenth.s.01
#   third.s.01
#   eighty-fifth.s.01
#   hundred-and-ninetieth.s.01
#   billionth.s.01
#   sixteenth.s.01
#   thirty-fourth.s.01
#   forty-seventh.s.01
#   hundred-and-fortieth.s.01
#   hundred-and-twenty-fifth.s.01
#   forty-fourth.s.01
#   zero.s.03
#   fourteenth.s.01
#   twenty-eighth.s.01
#   twentieth.s.01
#   two-hundredth.s.01
#   three-hundredth.s.01
#   twenty-third.s.01
#   eighth.s.01
#   quintillionth.s.01
#   thirtieth.s.01
#   sixty-fourth.s.01
#   hundred-and-thirty-fifth.s.01
#   hundred-and-seventieth.s.01
#   hundred-and-sixtieth.s.01
#   hundred-and-fifth.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# canty.s.01
# Head: energetic.a.01
# ====================
#   physical.s.05
#   vigorous.s.01
#   alert.s.02
#   canty.s.01
#   indefatigable.s.01
#   driving.s.02
#   strenuous.s.01
#   high-energy.s.02
#
# Head: lethargic.a.01
# ====================
#   dazed.s.02
#   listless.s.01
#   dreamy.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# off.s.04
# Head: soured.a.01
# =================
#   off.s.04
#
# Head: unsoured.a.01
# ===================
#   fresh.s.09
#
# ^^^^^^^^^^^^^^^^^^^^^^
# disbelieving.s.01
# Head: incredulous.a.01
# ======================
#   disbelieving.s.01
#
# Head: credulous.a.01
# ====================
#   overcredulous.s.01
#   unquestioning.s.01
#   credible.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# brassy.s.02
# Head: tasteless.a.02
# ====================
#   brassy.s.02
#   brummagem.s.01
#   indelicate.s.01
#   camp.s.01
#   barbaric.s.02
#   ostentatious.s.02
#
# Head: tasteful.a.01
# ===================
#   understated.s.01
#   aesthetic.s.03
#
# ^^^^^^^^^^^^^^^^^^^^^^
# handed-down.s.01
# Head: traditional.a.01
# ======================
#   handed-down.s.01
#   conventional.s.06
#   traditionalistic.s.01
#
# Head: nontraditional.a.01
# =========================
#
# ^^^^^^^^^^^^^^^^^^^^^^
# convertible.s.03
# Head: commutable.a.01
# =====================
#   convertible.s.03
#   alterable.s.02
#
# Head: incommutable.a.01
# =======================
#   inconvertible.s.02
#   unalterable.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# pointy-toed.s.01
# Head: toed.a.01
# ===============
#   pointy-toed.s.01
#   square-toed.s.02
#   two-toed.s.01
#
# Head: toeless.a.01
# ==================
#
# ^^^^^^^^^^^^^^^^^^^^^^
# velvet.s.01
# Head: smooth.a.01
# =================
#   even-textured.s.01
#   velvet.s.01
#   fine-textured.s.01
#   creaseless.s.01
#   seamless.s.02
#   fast.s.04
#   streamlined.s.02
#   glassy.s.01
#
# Head: rough.a.01
# ================
#   scabby.s.01
#   saw-like.s.01
#   squamulose.s.01
#   abrasive.s.01
#   crushed.s.01
#   bumpy.s.02
#   verrucose.s.01
#   pocked.s.01
#   broken.s.06
#   lined.s.02
#   lepidote.s.01
#   cragged.s.01
#   gravelly.s.01
#   homespun.s.01
#   rocky.s.01
#   roughish.s.01
#   textured.s.01
#   imbricate.s.01
#   sandpapery.s.01
#   bullate.s.01
#   shagged.s.01
#   chapped.s.01
#   alligatored.s.01
#   costate.s.01
#   rugose.s.01
#   barky.s.01
#   corded.s.01
#   rock-ribbed.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# incautious.s.02
# Head: careless.a.01
# ===================
#   casual.s.05
#   offhand.s.02
#   heedless.s.02
#   haphazard.s.02
#   incautious.s.02
#
# Head: careful.a.01
# ==================
#   certain.s.07
#   close.s.04
#   conscientious.s.01
#   particular.s.06
#   detailed.s.01
#   minute.s.02
#   blow-by-blow.s.01
#   overcareful.s.01
#   protective.s.03
#   thorough.s.01
#   studious.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# allowable.s.01
# Head: deductible.a.01
# =====================
#   allowable.s.01
#
# Head: nondeductible.a.01
# ========================
#
# ^^^^^^^^^^^^^^^^^^^^^^
# palsied.s.01
# Head: ill.a.01
# ==============
#   delirious.s.01
#   paralytic.s.02
#   afflicted.s.01
#   dyspeptic.s.01
#   scrofulous.s.01
#   gouty.s.01
#   milk-sick.s.01
#   dizzy.s.01
#   airsick.s.01
#   nauseated.s.01
#   paraplegic.s.01
#   tubercular.s.04
#   upset.s.04
#   bronchitic.s.01
#   laid_up.s.01
#   aguish.s.01
#   bedfast.s.01
#   diabetic.s.02
#   feverish.s.03
#   funny.s.04
#   laid_low.s.01
#   unhealed.s.01
#   palsied.s.01
#   spastic.s.02
#   autistic.s.01
#   convalescent.s.01
#   consumptive.s.02
#   rickety.s.02
#   sneezy.s.01
#   bilious.s.02
#   faint.s.04
#   green.s.04
#   ailing.s.01
#
# Head: well.a.01
# ===============
#   cured.s.01
#   asymptomatic.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# bronzed.s.01
# Head: brunet.a.01
# =================
#   bronzed.s.01
#   brown.s.02
#   nutbrown.s.01
#   dark-skinned.s.02
#   grizzled.s.01
#   dark.s.03
#   dark-haired.s.01
#   adust.s.02
#
# Head: blond.a.01
# ================
#   ash-blonde.s.01
#   flaxen.s.01
#   fair.s.10
#   nordic.s.03
#   redheaded.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# foliolate.s.01
# Head: leafy.a.01
# ================
#   leafed.s.01
#   leaflike.s.01
#   foliaceous.s.02
#   two-leaved.s.01
#   large-leaved.s.01
#   ivied.s.01
#   bifoliate.s.01
#   pinnate-leaved.s.01
#   bowery.s.01
#   silky-leaved.s.01
#   fan-leaved.s.01
#   leather-leaved.s.01
#   silver-leaved.s.01
#   spiny-leaved.s.01
#   unifoliate.s.01
#   fine-leaved.s.01
#   foliolate.s.01
#   petallike.s.01
#   prickly-leaved.s.01
#   curly-leaved.s.01
#   grassy-leaved.s.01
#   foliate.s.02
#
# Head: leafless.a.01
# ===================
#   scapose.s.01
#   aphyllous.s.01
#   defoliate.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# blase.s.01
# Head: sophisticated.a.01
# ========================
#   blase.s.01
#   intelligent.s.02
#   polished.s.02
#   worldly-wise.s.01
#
# Head: naive.a.01
# ================
#   fleeceable.s.01
#   credulous.s.02
#   simple-minded.s.01
#   childlike.s.02
#   unsophisticated.s.01
#   innocent.s.04
#
# ^^^^^^^^^^^^^^^^^^^^^^
# imprudent.s.02
# Head: indiscreet.a.01
# =====================
#   imprudent.s.02
#   bigmouthed.s.01
#
# Head: discreet.a.01
# ===================
#
# ^^^^^^^^^^^^^^^^^^^^^^
# big-shouldered.s.01
# Head: robust.a.01
# =================
#   big-boned.s.01
#   vigorous.s.02
#   half-hardy.s.01
#   heavy-armed.s.01
#   big-shouldered.s.01
#   big-chested.s.01
#   hardy.s.02
#   square-built.s.01
#   cast-iron.s.01
#   beefy.s.01
#   hardy.s.01
#
# Head: frail.a.01
# ================
#   light-boned.s.01
#   decrepit.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# first-string.s.01
# Head: regular.a.01
# ==================
#   official.s.04
#   timed.s.01
#   weak.s.08
#   well-ordered.s.01
#   first-string.s.01
#   lawful.s.02
#   standard.s.05
#   uniform.s.04
#
# Head: irregular.a.01
# ====================
#   randomized.s.01
#   asymmetrical.s.02
#   casual.s.06
#   strong.s.07
#   improper.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# constricting.s.01
# Head: narrow.a.01
# =================
#   slender.s.02
#   tapered.s.01
#   narrow-mouthed.s.01
#   narrowed.s.01
#   straplike.s.01
#   strait.s.01
#   constricting.s.01
#
# Head: wide.a.01
# ===============
#   broad-brimmed.s.01
#   wide-screen.s.01
#   deep.s.09
#   fanlike.s.01
#   beamy.s.01
#   sweeping.s.01
#   bird's-eye.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# made.s.03
# Head: successful.a.01
# =====================
#   in.s.01
#   booming.s.01
#   triple-crown.s.02
#   boffo.s.01
#   no-hit.s.01
#   self-made.s.01
#   productive.s.03
#   made.s.03
#   triple-crown.s.01
#   sure-fire.s.01
#   victorious.s.01
#
# Head: unsuccessful.a.01
# =======================
#   unfulfilled.s.01
#   unplaced.s.01
#   winless.s.01
#   scoreless.s.01
#   hitless.s.01
#   self-defeating.s.01
#   done_for.s.02
#   defeated.s.02
#   no-win.s.01
#   out.s.04
#   down-and-out.s.01
#   attempted.s.01
#   empty-handed.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# available.s.02
# Head: free.a.01
# ===============
#   out-of-school.s.01
#   at_large.s.01
#   unconstrained.s.01
#   autonomous.s.01
#   available.s.02
#   unhampered.s.02
#   unrestricted.s.02
#   footloose.s.01
#   aweigh.s.02
#   clear.s.05
#   emancipated.s.01
#   unconfined.s.02
#
# Head: unfree.a.02
# =================
#   captive.s.01
#   serflike.s.01
#   at_bay.s.01
#   entangled.s.03
#   nonautonomous.s.01
#   apprenticed.s.01
#   adscript.s.02
#   prisonlike.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# narrow.s.02
# Head: limited.a.01
# ==================
#   minor.s.10
#   narrow.s.02
#
# Head: unlimited.a.01
# ====================
#   bottomless.s.03
#   oceanic.s.02
#   untrammeled.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# husbandly.s.02
# Head: domestic.a.03
# ===================
#   housewifely.s.01
#   home-loving.s.01
#   husbandly.s.02
#   home-style.s.01
#   domesticated.s.02
#
# Head: undomestic.a.01
# =====================
#   undomesticated.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# rough-spoken.s.01
# Head: unrefined.a.02
# ====================
#   coarse.s.02
#   low.s.04
#   rough.s.02
#   crass.s.01
#   artless.s.04
#   boorish.s.01
#   agrestic.s.02
#   ungentlemanly.s.01
#   unladylike.s.01
#   robust.s.04
#   rough-spoken.s.01
#   ill-bred.s.01
#
# Head: refined.a.01
# ==================
#   patrician.s.01
#   dainty.s.01
#   well-bred.s.01
#   civilized.s.02
#   ladylike.s.01
#   couth.s.01
#   gentlemanlike.s.01
#   finespun.s.01
#   overrefined.s.01
#   debonair.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# cold.s.05
# Head: perfect.a.01
# ==================
#   idealized.s.01
#   idyllic.s.01
#   clear.s.13
#   perfectible.s.01
#   pluperfect.s.01
#   cold.s.05
#   faultless.s.01
#   ideal.s.01
#   clean.s.05
#   mint.s.01
#   uncorrupted.s.01
#   errorless.s.01
#   complete.s.02
#   down.s.05
#   flawless.s.01
#
# Head: imperfect.a.01
# ====================
#   imperfectible.s.01
#   irregular.s.05
#   defective.s.01
#   corrupt.s.03
#   broken.s.07
#   blemished.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# catastrophic.s.01
# Head: harmful.a.01
# ==================
#   bad.s.11
#   counterproductive.s.01
#   nocent.s.01
#   abusive.s.02
#   calumniatory.s.01
#   bruising.s.01
#   catastrophic.s.01
#   insidious.s.03
#   stabbing.s.01
#   deleterious.s.01
#   damaging.s.01
#   ill.s.02
#   mischievous.s.02
#
# Head: harmless.a.01
# ===================
#   innocent.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# nonstick.s.01
# Head: slippery.a.01
# ===================
#   slick.s.01
#   nonstick.s.01
#   slithery.s.01
#   lubricious.s.01
#   slipping.s.01
#   sliding.s.01
#   slimed.s.01
#
# Head: nonslippery.a.01
# ======================
#   nonskid.s.01
#   nonslip.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# small.s.08
# Head: fine.a.05
# ===============
#   close-grained.s.01
#   floury.s.01
#   nongranular.s.01
#   close.s.09
#   small.s.08
#   superfine.s.01
#   dustlike.s.01
#   powdered.s.01
#
# Head: coarse.a.01
# =================
#   coarse-grained.s.02
#   plushy.s.01
#   farinaceous.s.02
#   loose.s.09
#   granulated.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# in.s.01
# Head: successful.a.01
# =====================
#   in.s.01
#   booming.s.01
#   triple-crown.s.02
#   boffo.s.01
#   no-hit.s.01
#   self-made.s.01
#   productive.s.03
#   made.s.03
#   triple-crown.s.01
#   sure-fire.s.01
#   victorious.s.01
#
# Head: unsuccessful.a.01
# =======================
#   unfulfilled.s.01
#   unplaced.s.01
#   winless.s.01
#   scoreless.s.01
#   hitless.s.01
#   self-defeating.s.01
#   done_for.s.02
#   defeated.s.02
#   no-win.s.01
#   out.s.04
#   down-and-out.s.01
#   attempted.s.01
#   empty-handed.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# flash-frozen.s.01
# Head: preserved.a.01
# ====================
#   smoked.s.01
#   potted.s.02
#   lyophilized.s.01
#   pickled.s.01
#   cured.s.04
#   freeze-dried.s.02
#   flash-frozen.s.01
#   sun-dried.s.01
#   corned.s.01
#   dried.s.02
#   salted.s.01
#   aged.s.05
#   canned.s.02
#   candied.s.02
#
# Head: fresh.a.05
# ================
#   unprocessed.s.03
#
# ^^^^^^^^^^^^^^^^^^^^^^
# empty.s.02
# Head: meaningless.a.01
# ======================
#   nonsense.s.01
#   empty.s.02
#   insignificant.s.02
#   mindless.s.01
#
# Head: meaningful.a.01
# =====================
#   purposeful.s.02
#   meaty.s.02
#   meaning.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# acrimonious.s.01
# Head: resentful.a.01
# ====================
#   acrimonious.s.01
#   rancorous.s.01
#
# Head: unresentful.a.01
# ======================
#   unbitter.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# many-lobed.s.01
# Head: multilateral.a.01
# =======================
#   tripartite.s.01
#   bipartite.s.02
#   eleven-sided.s.01
#   quadrilateral.s.01
#   palmately-lobed.s.01
#   deep-lobed.s.01
#   joint.s.03
#   six-sided.s.01
#   many-lobed.s.01
#   twelve-sided.s.01
#   multipartite.s.01
#   five-sided.s.01
#   ten-sided.s.01
#   bilateral.s.03
#   two-lobed.s.01
#   seven-sided.s.01
#   five-lobed.s.01
#   trilateral.s.02
#   eight-sided.s.01
#   tetramerous.s.01
#   three-cornered.s.02
#   three-lobed.s.02
#   nine-sided.s.01
#   quadripartite.s.01
#   four-lobed.s.01
#
# Head: unilateral.a.01
# =====================
#   one-party.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# wildcat.s.01
# Head: unsound.a.02
# ==================
#   long.s.07
#   wildcat.s.01
#   bad.s.09
#
# Head: sound.a.01
# ================
#   stable.s.02
#   healthy.s.02
#   solid.s.11
#   dependable.s.04
#
# ^^^^^^^^^^^^^^^^^^^^^^
# ironshod.s.01
# Head: shod.a.01
# ===============
#   roughshod.s.01
#   ironshod.s.01
#   slippered.s.01
#   sandaled.s.01
#   booted.s.01
#
# Head: unshod.a.02
# =================
#   barefoot.s.01
#   stockinged.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# acerb.s.02
# Head: unpleasant.a.01
# =====================
#   embarrassing.s.02
#   acerb.s.02
#   ungrateful.s.02
#   unhappy.s.03
#   afflictive.s.01
#   dreadful.s.03
#   dour.s.02
#   rebarbative.s.01
#   beastly.s.01
#   hot.s.12
#   sharp.s.05
#   harsh.s.01
#   harsh.s.02
#
# Head: pleasant.a.01
# ===================
#   enjoyable.s.01
#   grateful.s.02
#   idyllic.s.02
#   beautiful.s.02
#   dulcet.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# away.s.03
# Head: inaccurate.a.01
# =====================
#   away.s.03
#   wide.s.07
#   faulty.s.02
#   unfaithful.s.04
#
# Head: accurate.a.01
# ===================
#   veracious.s.02
#   high-fidelity.s.01
#   true.s.02
#   straight.s.05
#   surgical.s.03
#   close.s.05
#   dead-on.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# smooth-bodied.s.01
# Head: bodied.a.01
# =================
#   short-bodied.s.01
#   oval-bodied.s.01
#   narrow-bodied.s.01
#   incarnate.s.02
#   long-bodied.s.01
#   silver-bodied.s.01
#   smooth-bodied.s.01
#   slim-bodied.s.01
#   thick-bodied.s.01
#   lithe-bodied.s.01
#
# Head: unbodied.a.01
# ===================
#   bodiless.s.02
#   formless.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# absorbed.s.02
# Head: unreflected.a.01
# ======================
#   absorbed.s.02
#
# Head: reflected.a.01
# ====================
#   mirrored.s.01
#   echoic.s.02
#
# ^^^^^^^^^^^^^^^^^^^^^^
# male.s.02
# Head: masculine.a.02
# ====================
#   male.s.02
#   mannish.s.02
#   butch.s.01
#
# Head: feminine.a.01
# ===================
#   powder-puff.s.01
#   fair.s.06
#   female.s.02
#   maidenlike.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# fleeceable.s.01
# Head: naive.a.01
# ================
#   fleeceable.s.01
#   credulous.s.02
#   simple-minded.s.01
#   childlike.s.02
#   unsophisticated.s.01
#   innocent.s.04
#
# Head: sophisticated.a.01
# ========================
#   blase.s.01
#   intelligent.s.02
#   polished.s.02
#   worldly-wise.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^
# back.s.02
# Head: posterior.a.01
# ====================
#   retral.s.02
#   back.s.02
#   caudal.s.03
#
# Head: anterior.a.01
# ===================
#   prefrontal.s.01
#   frontal.s.01
#   frontal.s.04
#
# ^^^^^^^^^^^^^^^^^^^^^^
# neutral.s.07
# Head: uncharged.a.01
# ====================
#   dead.s.16
#   neutral.s.07
#
# Head: charged.a.01
# ==================
#   positive.s.10
#   hot.s.20
#   polar.s.01
#   negative.s.08
#
# ^^^^^^^^^^^^^^^^^^^^^^
# nibbed.s.01
# Head: pointed.a.01
# ==================
#   acanthoid.s.01
#   barreled.s.02
#   six-pointed.s.01
#   peaked.s.02
#   bristle-pointed.s.01
#   spiked.s.01
#   nibbed.s.01
#   spikelike.s.01
#   five-pointed.s.01
#   acuate.s.01
#   fusiform.s.01
#   sharpened.s.01
#   pyramidal.s.01
#
# Head: pointless.a.01
# ====================
#   blunt.s.01
#
# ^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# ## Lemmas and antonyms

# %% [markdown]
# Lemmas  are pairings of a synset with a word form (defining a particular **sense** of the word):

# %%
ss_happy = wn.synsets("happy","a")[0]
ss_happy
# Out:
# Synset('happy.a.01')

# %% [markdown]
# Most ss just have one lemma:

# %%
ss_happy.lemmas()
# Out:
# [Lemma('happy.a.01.happy')]

# %% [markdown]
# But many have more than one:

# %%
multi_form_ss = [ss for ss in all_ss if len(ss.lemmas())>1]
len(multi_form_ss)
# Out:
# 53811

# %% [markdown]
# So the synsets are the **concepts**. The **lemmas** are the pairings of concepts and forms.
# Two lemmas related to the same synsets are **synonnyms**.

# %%
relative_ss = multi_form_ss[8]
relative_ss.lemmas()
# Out:
# [Lemma('relative.a.01.relative'), Lemma('relative.a.01.comparative')]

# %% [markdown]
# The antonymy relation is not a purely semantic relation; it's a lemma-to-lemma relation:

# %%
print("ss", relative_ss)
print("  ", relative_ss.definition())
print()
for lm in relative_ss.lemmas():
    print("  ","lm", lm)
    for ant in lm.antonyms():
        print("      ","ant", ant)
    print()

#l0 = wn.synsets("happy","a")[0].lemmas()[0].antonyms()[0]
#l0
# Out:
# ss Synset('relative.a.01')
#    estimated by comparison; not absolute or complete
#
#    lm Lemma('relative.a.01.relative')
#        ant Lemma('absolute.a.01.absolute')
#
#    lm Lemma('relative.a.01.comparative')

# %% [markdown]
# Many concepts have only one lemma, meaning they don't license any synonymy relations.

# %%
l0.synset().lemmas()
# Out:
# [Lemma('unhappy.a.01.unhappy')]

# %% [markdown]
# ## Adjectives

# %% [markdown]
# It's pretty easy to find adjectives, but let's find them by semantic means:

# %% [markdown]
# Strategy find emotion nouns using hypernym relations.  Use stemmer to find related adjectives.
# This will involve going from adjectives to nouns.

# %%
#  Going from the noun to the adjection
stemmer.stem("sadness"),stemmer.stem("happiness")
# Out:
# ('sad', 'happi')

# %%
stemmer.stem("curiousity"),stemmer.stem("interesting")
# Out:
# ('curious', 'interest')

# %%
def get_definitions (ss_set,verbose = False):
    defs = [(ss.name(),ss.definition()) for ss in ss_set]
    if verbose:
        for (nm,df) in defs:
            print(f"{nm:>20}     {df}")
    return defs

# %%
sad_synsets = [ss for ss in wn.synsets('sad')]
sad_synsets
# Out:
# [Synset('sad.a.01'), Synset('sad.s.02'), Synset('deplorable.s.01')]

# %%
defs = get_definitions(sad_synsets,verbose=True)
# Out:
#             sad.a.01     experiencing or showing sorrow or unhappiness; ; - Christina Rossetti
#             sad.s.02     of things that make you feel sad; ; ; ; - Christina Rossetti
#      deplorable.s.01     bad; unfortunate

# %% [markdown]
# Within the adjectives the hypernym structure has not been done.
#
# There's a semantic reason that has to do with a basic assumption/limitation of wn.  There are no
# abstract nodes.  And since there is no adjective meaning "having an emotion" no adjective
# can have a synset corresponding to the sense "having an emotion" as a synset.

# %%
sad_synset_0 = sad_synsets[0]
sad_synset_0.hypernyms()
# Out:
# []

# %% [markdown]
# But there are lots of emotion nouns nd lots of related adjectives, so let's start there.

# %%
get_defs(emotion_ss.hyponyms())
# Out:
# emotional_state.n.01 the state of a person's emotions (especially with regard to pleasure or dejection)
# hate.n.01         the emotion of intense dislike; a feeling of dislike so strong that it demands action
# fear.n.03         a feeling of profound respect for someone or something
# joy.n.01          the emotion of great happiness
# love.n.01         a strong positive emotion of regard and affection
# anxiety.n.02      a vague unpleasant emotion that is experienced in anticipation of some (usually ill-defined) misfortune
# conditioned_emotional_response.n.01 an emotional response that has been acquired by conditioning
# anger.n.01        a strong emotion; a feeling that is oriented toward some real or supposed grievance
# fear.n.01         an emotion experienced in anticipation of some specific pain or danger (usually accompanied by a desire to flee or fight)

# %% [markdown]
# ## Get emotion noun synsets

# %%
#  find all the emotion bnoun synsets in the obvious way
anger_synsets = [ss for ss in wn.synsets('anger')]
anger_hypernyms = anger_synsets[0].hypernyms()
emotion_ss = anger_hypernyms[0]

def get_hypos (ss_set):
    return {hn for ss in ss_set for hn in ss.hyponyms()}

def get_hypos_iter (root):
    #global accumulated
    hl0 = root.hyponyms()
    accumulated = set(hl0)
    current = hl0
    while current:
        current = get_hypos(current)
        accumulated.update(current)
    return accumulated

def get_lemmas_iter(root):
    return {l for ss in get_hypos_iter(root) for l in ss.lemmas()}.union(root.lemmas())

def get_emotion_nouns(root = emotion_ss,hn_list=None):
    return get_hypos_iter (root)

def get_defs (ss_seq):
    for ss in ss_seq:
        print(f"{ss.name():<17} {ss.definition()}")

emotion_nouns = get_emotion_nouns()
len(emotion_nouns)
# Out:
# 129

# %% [markdown]
# The synset one up in the hierarchy (hypernym of "emotion.n.01") is actually what we
# want.  It's "feeling.n.01".

# %%
feeling_noun_ss = get_emotion_nouns(root = wn.synset("feeling.n.01"))

# %% [markdown]
# A set of syn sets

# %%
fni = feeling_noun_ss.__iter__()
next(fni)
# Out:
# Synset('heartstrings.n.01')

# %%
len(feeling_noun_ss)
# Out:
# 445

# %%
feeling_noun_lemmas = get_lemmas_iter(root = wn.synset("feeling.n.01"))

# %%
len(feeling_noun_lemmas)
# Out:
# 805

# %% [markdown]
# A set of lemmas:

# %%
fnli = feeling_noun_lemmas.__iter__()
print(next(fnli))
print(next(fnli))
# Out:
# Lemma('pleasure.n.01.pleasance')
# Lemma('appetite.n.01.appetite')

# %% [markdown]
# Let's grab the words from the lemmas (the set of nouns of which which sense is emotion-related):

# %%
feeling_noun_words = {l.name() for l in feeling_nouns2}
len(feeling_noun_words)
# Out:
# 805

# %%
wordset_i = wordset.__iter__()
print(next(wordset_i ))
print(next(wordset_i))
print(next(wordset_i ))
print(next(wordset_i ))
#wordset
# Out:
# pleasance
# appetite
# enragement
# unfriendliness

# %%
len(feeling_noun_ss)
# Out:
# 445

# %% [markdown]
# Find the emotional senese of drag:

# %%
for ss in wn.synsets("drag","n"):
    print(ss, ss.definition())
# Out:
# Synset('drag.n.01') the phenomenon of resistance to motion through a fluid
# Synset('drag.n.02') something that slows or delays progress
# Synset('drag.n.03') something tedious and boring
# Synset('drag.n.04') clothing that is conventionally worn by the opposite sex (especially women's clothing when worn by a man)
# Synset('puff.n.07') a slow inhalation (as of tobacco smoke)
# Synset('drag.n.06') the act of dragging (pulling with force)

# %% [markdown]
# Go up a few levels. Then get hypos:

# %%
powerlessness_ss = wn.synset("drag.n.03").hypernyms()[0].hypernyms()[0].hypernyms()[0].hypernyms()[0]
powerlessness_nouns = get_emotion_nouns(root = powerlessness_ss)
powerlessness_nouns
# Out:
# {Synset('boringness.n.01'),
#  Synset('drag.n.03'),
#  Synset('dullness.n.02'),
#  Synset('helplessness.n.01'),
#  Synset('ineffectiveness.n.01'),
#  Synset('inefficacy.n.01'),
#  Synset('jejunity.n.01'),
#  Synset('paper_tiger.n.01'),
#  Synset('ponderousness.n.01'),
#  Synset('tediousness.n.01'),
#  Synset('uninterestingness.n.01'),
#  Synset('unpersuasiveness.n.01'),
#  Synset('voicelessness.n.03')}

# %%
for ss in wn.synsets("anticipation","n"):
    print(ss, get_hypers_iter (ss))
    print()
# Out:
# Synset('anticipation.n.01') {Synset('feeling.n.01'), Synset('expectation.n.03'), Synset('attribute.n.02'), Synset('state.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')}
#
# Synset('anticipation.n.02') {Synset('psychological_feature.n.01'), Synset('expectation.n.01'), Synset('cognition.n.01'), Synset('abstraction.n.06'), Synset('entity.n.01'), Synset('content.n.05'), Synset('belief.n.01')}
#
# Synset('prediction.n.01') {Synset('higher_cognitive_process.n.01'), Synset('psychological_feature.n.01'), Synset('entity.n.01'), Synset('reasoning.n.01'), Synset('abstraction.n.06'), Synset('cognition.n.01'), Synset('process.n.02'), Synset('thinking.n.01')}
#
# Synset('anticipation.n.04') {Synset('attribute.n.02'), Synset('state.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01'), Synset('condition.n.01'), Synset('hopefulness.n.01')}

# %%
wn.synset('anticipation.n.02').lemma_names()
# Out:
# ['anticipation', 'expectancy']

# %%
# These are almost all mnames for religious doctrines but just to be confusing anticipation.n.02 is in there
# as is conviction, decuisuion
belief_nouns = sorted(ss.name() for ss in list(get_hypos_iter(root = wn.synset('belief.n.01'))))

# %%
belief_nouns2 = list(get_hypos_iter(root = wn.synset('belief.n.02')))

# %% [markdown]
# A little known fact about the `wn.synset()` function: the key `"belief.n.02"` retrieves the second synset
# associated with the noun *belief*, whether or not  the official name of that synset is `"belief.n.02"`.
# In fact, the "official" name for the second sense of "belief" is "impression.n.01",

# %%
wn.synset('belief.n.02').name()
# Out:
# 'impression.n.01'

# %% [markdown]
# The objects returned for both keys are the same object in memory:

# %%
wn.synset('belief.n.02') is wn.synset('impression.n.01')
# Out:
# True

# %% [markdown]
# And therefore the associated lemmas are the same:

# %%
wn.lemma('belief.n.02.belief') == wn.lemma('impression.n.01.belief')
# Out:
# True

# %% [markdown]
# It is an error however to ask for the nth synset when the number of senses for the
# for the form,pos pair is fewer than n.  Since `belief.n` has only two definitions,
# the following raises both a
#
# ```python
# WordNetError: Lemma 'belief' with part of speech 'n' only has 2 senses
# ```
#
# and an `IndexError`.

# %%
# WordNetError   
#wn.synset('belief.n.03')

# %% [markdown]
# There are 4 "synonymous" nouns related to this concept:

# %%
wn.synset('belief.n.02').lemmas()
# Out:
# [Lemma('impression.n.01.impression'),
#  Lemma('impression.n.01.feeling'),
#  Lemma('impression.n.01.belief'),
#  Lemma('impression.n.01.notion'),
#  Lemma('impression.n.01.opinion')]

# %%
get_defs(wn.synsets("belief","n"))
# Out:
# belief.n.01       any cognitive content held as true
# impression.n.01   a vague idea in which some confidence is placed

# %% [markdown]
# In Wordnet *ambition* is not an emotion.  It's a feeling.
#
# ```
# ambition -> desire -> feeling
# ```

# %% [markdown]
# The disctinction between feeling and emotion is made, for example. in the field of clinical counseling.  The [Wake Forest Page Counseling Blog Page on feelings and emotions](https://counseling.online.wfu.edu/blog/difference-feelings-emotions/#:~:text=A%20fundamental%20difference%20between%20feelings,the%20depths%20of%20their%20emotions.) says:
#
# >Many people use the terms “feeling” and “emotion” as synonyms, but they are not interchangeable. While they have similar elements, there is a marked difference between feelings and emotions.
#
# >**Feelings**. Both emotional experiences and physical sensations — such as hunger or pain — bring about feelings, according to Psychology Today. Feelings are a conscious experience, although not every conscious experience, such as seeing or believing, is a feeling, as explained in the article.
#
# >**Emotions**. According to Psychology Today, an emotion “can only ever be felt…through the emotional experiences it gives rise to, even though it might be discovered through its associated thoughts, beliefs, desires, and actions.” Emotions are not conscious but instead manifest in the unconscious mind. These emotions can be brought to the surface of the conscious state through extended psychotherapy.
#
# >A fundamental difference between feelings and emotions is that feelings are experienced consciously, while emotions manifest either consciously or subconsciously. Some people may spend years, or even a lifetime, not understanding the depths of their emotions.

# %%
ambition_ss.hypernyms()[0].hypernyms()
# Out:
# [Synset('feeling.n.01')]

# %%
intensity_words

# %% [markdown]
# ## hierarchy exploration

# %%
def get_hypos (ss_set):
    return {hn for ss in ss_set for hn in ss.hyponyms()}



def get_hypers_list (ss_set):
    return [hn for ss in ss_set for hn in ss.hypernyms()]

def get_hypers_iter_list (root):
    global accumulated
    hl0 = root.hypernyms()
    accumulated = hl0
    current = hl0
    while current:
        current = get_hypers_list(current)
        accumulated.extend(current)
    return accumulated

def get_hypers (ss_set):
    return {hn for ss in ss_set for hn in ss.hypernyms()}

def get_hypers_iter (root):
    global accumulated
    hl0 = root.hypernyms()
    accumulated = set(hl0)
    current = hl0
    while current:
        current = get_hypers(current)
        accumulated.update(current)
    return accumulated

def get_hypos_iter (root):
    global accumulated2
    hl0 = root.hyponyms()
    accumulated2 = set(hl0)
    current = hl0
    while current:
        current = get_hypos(current)
        accumulated2.update(current)
    return accumulated2

def get_hypos_gen (root):
    hl0 = root.hyponyms()
    accumulated2 = set(hl0)
    current = hl0
    while current:
        current = get_hypos(current)
        for hn in current:
            yield current

# %%
#all_ss = wn.all_eng_synsets()

# %% [markdown]
# Let's find out how deep "emotion.n.01" is and what its hhypernyms are.

# %% [markdown]
# Finding the root of the wn hoierarchy:

# %%
thing_list = [ss for ss in all_ss if "thing.n.01" == ss.name()]
thing_list
# Out:
# [Synset('thing.n.01')]

# %%
search_root = thing_list[0]
search_res = get_hypers_iter (search_root)
search_res
# Out:
# {Synset('abstraction.n.06'),
#  Synset('attribute.n.02'),
#  Synset('entity.n.01'),
#  Synset('situation.n.01'),
#  Synset('state.n.02')}

# %% [markdown]
# Unnecessary but perhaps a useful code model.

# %%
#root = wn.synset("entity.n.01")
##print(root.name())
#ctr = 0
#accum = [(ctr,root)]
#accum0 = [root]
#for ss_set in get_hypos_gen (root):
#    for ss in ss_set:
#        if ss not in accum0:
#            accum.append((ctr,ss))
#            accum0.append(ss)
#    ctr += 1
#    if ctr > 500:
#        break
#print(len(accum),len(accum0), ctr)
# Out:
# 2261 2261 501

# %% [markdown]
# Here are the hypernyms:

# %%
L = list(get_hypers_iter(emotion_ss))
# not in any use ful order
L
# Out:
# [Synset('entity.n.01'),
#  Synset('state.n.02'),
#  Synset('abstraction.n.06'),
#  Synset('feeling.n.01'),
#  Synset('attribute.n.02')]

# %% [markdown]
# The tree order from the root down

# %%
#  0           1              2          3         4          5
#entity -> abstraction -> attribute -> state -> feeling -> emotion

# %%
# depth = 5
get_hypers(get_hypers(get_hypers(get_hypers(get_hypers ({emotion_ss})))))
# Out:
# {Synset('entity.n.01')}

# %%
get_hypers(get_hypers(get_hypers (get_hypers ({emotion_ss}))))
# Out:
# {Synset('abstraction.n.06')}

# %%
get_hypers(get_hypers (get_hypers ({emotion_ss})))
# Out:
# {Synset('attribute.n.02')}

# %%
get_hypers (get_hypers ({emotion_ss}))
# Out:
# {Synset('state.n.02')}

# %%
get_hypers ({emotion_ss})
# Out:
# {Synset('feeling.n.01')}

# %%
get_hypers_iter (emotion_ss)
# Out:
# {Synset('abstraction.n.06'),
#  Synset('attribute.n.02'),
#  Synset('entity.n.01'),
#  Synset('feeling.n.01'),
#  Synset('state.n.02')}

# %% [markdown]
# Going downward

# %%
wn.synset('entity.n.01').hyponyms()
# Out:
# [Synset('physical_entity.n.01'),
#  Synset('thing.n.08'),
#  Synset('abstraction.n.06')]

# %%
print(wn.synset('physical_entity.n.01').definition())
wn.synset('physical_entity.n.01').hyponyms()
# Out:
# an entity that has physical existence
# [Synset('thing.n.12'),
#  Synset('object.n.01'),
#  Synset('process.n.06'),
#  Synset('causal_agent.n.01'),
#  Synset('substance.n.04'),
#  Synset('matter.n.03')]

# %%
wn.synset('process.n.06').hyponyms()
# Out:
# [Synset('irreversible_process.n.01'),
#  Synset('sensitization.n.02'),
#  Synset('operation.n.08'),
#  Synset('organic_process.n.01'),
#  Synset('photography.n.02'),
#  Synset('variation.n.07'),
#  Synset('encapsulation.n.02'),
#  Synset('economic_process.n.01'),
#  Synset('dealignment.n.01'),
#  Synset('iteration.n.02'),
#  Synset('degeneration.n.01'),
#  Synset('phenomenon.n.01'),
#  Synset('increase.n.03'),
#  Synset('shaping.n.01'),
#  Synset('chelation.n.01'),
#  Synset('reversible_process.n.01'),
#  Synset('industrial_process.n.01'),
#  Synset('development.n.02'),
#  Synset('iteration.n.01'),
#  Synset('human_process.n.01'),
#  Synset('natural_process.n.01'),
#  Synset('processing.n.01'),
#  Synset('execution.n.03'),
#  Synset('decrease.n.02')]

# %%
wn.synset('human_process.n.01').hyponyms()
# Out:
# [Synset('social_process.n.01'),
#  Synset('linguistic_process.n.01'),
#  Synset('psychoanalytic_process.n.01'),
#  Synset('ossification.n.03'),
#  Synset('uptake.n.02')]

# %%
from nltk import Tree

def extend_tree(t,start=0,max_dtrs=5,pass_max_dtrs=False):
    """
    Extends tree from frontier down
    Supports the convention that nltk node labels
    wll be names of synset instances (strings) rather than synset
    instances.
    
    Note that the recursive call to extend_tree does
    not by default pass max_dtrs values.  This is because
    in most cases the deeper parts of teh Wordnet tree
    do not have large numbers of daughters.  When
    inspecting the exceptions, the relevant mother
    node can be navigated to directly.
    """
    for (i,t0) in enumerate(t):
        if isinstance(t0,Tree):
            if pass_max_dtrs:
                extend_tree(t0,max_dtrs=max_dtrs)
            else:
                extend_tree(t0)
        else:
            t[i] = Tree(t0,convert_dtrs(wn.synset(t0).hyponyms()[start:start+max_dtrs]))

def convert_dtrs (dtrs):
    """
    ss_list to string_ist
    """
    return [n.name() for n in dtrs]


def make_trees(root_name,last=0,inc=5):
    """
    Return a list of non overlapping subtrees of the 
    tree rooted at rootname, each tree containing a subsequence 
    of inc of the dtrs of root_name.
    So if inc=5 the first subtree contains the first
    5 daughters, the next the next 5, and so on.
    """
    dtrs = wn.synset(root_name).hyponyms()
    trees = []
    for n in range(last, len(dtrs), inc):
        these_dtrs = dtrs[last:last+inc]
        trees.append(Tree(root_name,convert_dtrs(these_dtrs)))
        last += inc
    return trees

def make_tree(root_name):
    """
    Complete Wordnet tree starting at root_name.
    
    Note: the leaves will be trees with empty dtr lists.
    """
    #last,inc = 0,5
    dtrs_list = []
    tree = Tree(root_name, dtrs_list)
    dtrs = wn.synset(root_name).hyponyms()
    for n in range(len(dtrs)):
        this_dtr = dtrs[n].name()
        tree.append(make_tree(this_dtr))
    return tree

def sub_tree(tree0,start=0,end=None):
    """
    Just a convenience function for displaying
    part of tree0: show only the subtrees for
    dtrs at indices start up to end.
    
    Used for slicing & displaying 
    trees with many dtrs (e.g., "feeling.n.01").
    
    Note that tree[start:end] returns a list of
    trees, which then don't display nicely.
    This is a bandaid for that problem.
    """
    return Tree(tree0.label(), tree0[start:end])

def count_leaves (tree):
    if len(tree) == 0:
        return 1
    else:
        ct = 0
        for t in tree:
            ct += count_leaves(t)
        return ct

def get_leaves (tree):
    if len(tree) == 0:
        leaves = [tree.label()]
    else:
        leaves = []
        for t in tree:
            leaves.extend(get_leaves(t))
    return leaves

def get_nodes (tree):
    nodes  = [tree.label()]
    for t in tree:
        nodes.extend(get_nodes(t))
    return nodes

# %% [markdown]
# ## Every dog has its day

# %%
dog_tree = make_tree("dog.n.01")

# %%
count_leaves(dog_tree)
# Out:
# 147

# %%
dog_words = get_leaves(dog_tree)
print(len(dog_words))
dog_words[:10]
# Out:
# 147
# ['newfoundland.n.01',
#  'pug.n.01',
#  'cardigan.n.02',
#  'pembroke.n.01',
#  'liver-spotted_dalmatian.n.01',
#  'feist.n.01',
#  'pariah_dog.n.01',
#  'pooch.n.01',
#  'lapdog.n.01',
#  'samoyed.n.03']

# %%
dog_tree
# Out:
# Tree('dog.n.01', [Tree('newfoundland.n.01', []), Tree('pug.n.01', []), Tree('corgi.n.01', [Tree('cardigan.n.02', []), Tree('pembroke.n.01', [])]), Tree('dalmatian.n.02', [Tree('liver-spotted_dalmatian.n.01', [])]), Tree('cur.n.01', [Tree('feist.n.01', []), Tree('pariah_dog.n.01', [])]), Tree('pooch.n.01', []), Tree('lapdog.n.01', []), Tree('spitz.n.01', [Tree('samoyed.n.03', []), Tree('keeshond.n.01', []), Tree('chow.n.03', []), Tree('pomeranian.n.01', [])]), Tree('poodle.n.01', [Tree('miniature_poodle.n.01', []), Tree('large_poodle.n.01', []), Tree('toy_poodle.n.01', []), Tree('standard_poodle.n.01', [])]), Tree('griffon.n.02', [Tree('brabancon_griffon.n.01', [])]), Tree('toy_dog.n.01', [Tree('chihuahua.n.03', []), Tree('toy_spaniel.n.01', [Tree('papillon.n.01', []), Tree('king_charles_spaniel.n.01', []), Tree('english_toy_spaniel.n.01', [Tree('blenheim_spaniel.n.01', [])])]), Tree('shih-tzu.n.01', []), Tree('pekinese.n.01', []), Tree('toy_terrier.n.01', []), Tree('japanese_spaniel.n.01', []), Tree('maltese_dog.n.01', [])]), Tree('basenji.n.01', []), Tree('puppy.n.01', []), Tree('mexican_hairless.n.01', []), Tree('great_pyrenees.n.01', []), Tree('working_dog.n.01', [Tree('shepherd_dog.n.01', [Tree('border_collie.n.01', []), Tree('old_english_sheepdog.n.01', []), Tree('collie.n.01', []), Tree('belgian_sheepdog.n.01', [Tree('malinois.n.01', []), Tree('groenendael.n.01', [])]), Tree('bouvier_des_flandres.n.01', []), Tree('kelpie.n.02', []), Tree('rottweiler.n.01', []), Tree('briard.n.01', []), Tree('komondor.n.01', []), Tree('german_shepherd.n.01', []), Tree('shetland_sheepdog.n.01', [])]), Tree('bull_mastiff.n.01', []), Tree('saint_bernard.n.01', []), Tree('sled_dog.n.01', [Tree('siberian_husky.n.01', []), Tree('malamute.n.01', [])]), Tree('watchdog.n.02', [Tree('pinscher.n.01', [Tree('doberman.n.01', []), Tree('miniature_pinscher.n.01', []), Tree('affenpinscher.n.01', [])]), Tree('schipperke.n.01', []), Tree('attack_dog.n.01', []), Tree('housedog.n.01', []), Tree('kuvasz.n.01', [])]), Tree('eskimo_dog.n.01', []), Tree('mastiff.n.01', [Tree('tibetan_mastiff.n.01', [])]), Tree('bulldog.n.01', [Tree('french_bulldog.n.01', [])]), Tree('seizure-alert_dog.n.01', []), Tree('great_dane.n.01', []), Tree('hearing_dog.n.01', []), Tree('guide_dog.n.01', [Tree('seeing_eye_dog.n.01', [])]), Tree('boxer.n.04', []), Tree('sennenhunde.n.01', [Tree('appenzeller.n.01', []), Tree('bernese_mountain_dog.n.01', []), Tree('entlebucher.n.01', []), Tree('greater_swiss_mountain_dog.n.01', [])]), Tree('police_dog.n.01', [])]), Tree('hunting_dog.n.01', [Tree('courser.n.03', []), Tree('rhodesian_ridgeback.n.01', []), Tree('dachshund.n.01', [Tree('sausage_dog.n.01', [])]), Tree('hound.n.01', [Tree('harrier.n.02', []), Tree('afghan_hound.n.01', []), Tree('staghound.n.01', []), Tree('redbone.n.01', []), Tree('scottish_deerhound.n.01', []), Tree('bloodhound.n.01', []), Tree('saluki.n.01', []), Tree('foxhound.n.01', [Tree('walker_hound.n.01', []), Tree('american_foxhound.n.01', []), Tree('english_foxhound.n.01', [])]), Tree('greyhound.n.01', [Tree('italian_greyhound.n.01', []), Tree('whippet.n.01', [])]), Tree('plott_hound.n.01', []), Tree('otterhound.n.01', []), Tree('norwegian_elkhound.n.01', []), Tree('beagle.n.01', []), Tree('ibizan_hound.n.01', []), Tree('wolfhound.n.01', [Tree('borzoi.n.01', []), Tree('irish_wolfhound.n.01', [])]), Tree('weimaraner.n.01', []), Tree('boarhound.n.01', []), Tree('bluetick.n.01', []), Tree('coonhound.n.01', [Tree('coondog.n.01', []), Tree('black-and-tan_coonhound.n.01', [])]), Tree('basset.n.01', [])]), Tree('sporting_dog.n.01', [Tree('pointer.n.04', [Tree('vizsla.n.01', []), Tree('german_short-haired_pointer.n.01', [])]), Tree('setter.n.02', [Tree('english_setter.n.01', []), Tree('irish_setter.n.01', []), Tree('gordon_setter.n.01', [])]), Tree('retriever.n.01', [Tree('labrador_retriever.n.01', []), Tree('flat-coated_retriever.n.01', []), Tree('chesapeake_bay_retriever.n.01', []), Tree('golden_retriever.n.01', []), Tree('curl ...

# %%
hd = make_tree('shepherd_dog.n.01')
hd
# Out:
# Tree('shepherd_dog.n.01', [Tree('border_collie.n.01', []), Tree('old_english_sheepdog.n.01', []), Tree('collie.n.01', []), Tree('belgian_sheepdog.n.01', [Tree('malinois.n.01', []), Tree('groenendael.n.01', [])]), Tree('bouvier_des_flandres.n.01', []), Tree('kelpie.n.02', []), Tree('rottweiler.n.01', []), Tree('briard.n.01', []), Tree('komondor.n.01', []), Tree('german_shepherd.n.01', []), Tree('shetland_sheepdog.n.01', [])])

# %%
get_leaves(hd)
# Out:
# ['malinois.n.01',
#  'groenendael.n.01',
#  'kelpie.n.02',
#  'rottweiler.n.01',
#  'briard.n.01',
#  'komondor.n.01',
#  'bouvier_des_flandres.n.01',
#  'shetland_sheepdog.n.01',
#  'german_shepherd.n.01',
#  'border_collie.n.01',
#  'old_english_sheepdog.n.01',
#  'collie.n.01']

# %% [markdown]
# ## Nothing more than feelings

# %%
big_tree = make_tree("feeling.n.01")

# %%
big_tree
# Out:
# Tree('feeling.n.01', [Tree('sentiment.n.01', [Tree('razbliuto.n.01', []), Tree('sentimentality.n.02', [Tree('mawkishness.n.01', [])])]), Tree('pleasure.n.01', [Tree('sexual_pleasure.n.01', [Tree('sadism.n.01', [Tree('sadomasochism.n.01', [])]), Tree('masochism.n.01', [Tree('sadomasochism.n.01', [])]), Tree('algolagnia.n.01', [])]), Tree('pleasantness.n.01', [Tree('afterglow.n.02', [])]), Tree('delight.n.01', [Tree('schadenfreude.n.01', []), Tree('amusement.n.01', []), Tree('entrancement.n.01', [])]), Tree('comfort.n.02', [Tree('consolation.n.01', [Tree('silver_lining.n.01', []), Tree('cold_comfort.n.01', [])]), Tree('relief.n.01', [])]), Tree('enjoyment.n.01', [Tree('joie_de_vivre.n.01', []), Tree('gusto.n.01', [])])]), Tree('pang.n.01', [Tree('guilt_pang.n.01', [])]), Tree('humility.n.02', [Tree('self-depreciation.n.01', []), Tree('meekness.n.01', [])]), Tree('fearlessness.n.01', [Tree('security.n.03', [Tree('confidence.n.02', [])])]), Tree('sympathy.n.02', [Tree('concern.n.03', [Tree('softheartedness.n.01', []), Tree('solicitude.n.01', [])]), Tree('empathy.n.01', []), Tree('commiseration.n.01', []), Tree('compatibility.n.01', []), Tree('compassion.n.01', [Tree('tenderness.n.03', []), Tree('mercifulness.n.01', [Tree('forgiveness.n.01', [])]), Tree('heartstrings.n.01', [])]), Tree('kindheartedness.n.01', [Tree('mellowness.n.01', [])])]), Tree('emotion.n.01', [Tree('love.n.01', [Tree('amorousness.n.01', []), Tree('benevolence.n.01', [Tree('beneficence.n.01', [])]), Tree('puppy_love.n.01', []), Tree('loyalty.n.02', []), Tree('lovingness.n.01', [Tree('warmheartedness.n.01', [])]), Tree('ardor.n.02', []), Tree('agape.n.01', []), Tree('filial_love.n.01', []), Tree('worship.n.02', []), Tree('heartstrings.n.01', []), Tree('devotion.n.01', []), Tree('agape.n.02', [])]), Tree('anxiety.n.02', [Tree('jitteriness.n.01', []), Tree('concern.n.02', []), Tree('insecurity.n.02', []), Tree('anxiousness.n.02', []), Tree('angst.n.01', []), Tree('discomfiture.n.01', []), Tree('worry.n.02', []), Tree('sinking.n.03', []), Tree('edginess.n.01', [Tree('willies.n.01', [])]), Tree('scruple.n.02', [])]), Tree('anger.n.01', [Tree('annoyance.n.02', [Tree('displeasure.n.01', []), Tree('frustration.n.03', []), Tree('aggravation.n.01', []), Tree('harassment.n.01', []), Tree('pique.n.02', [])]), Tree('huffiness.n.01', []), Tree('umbrage.n.01', []), Tree('indignation.n.01', [Tree('dudgeon.n.01', [])]), Tree('dander.n.02', []), Tree('bad_temper.n.01', [Tree('fit.n.01', []), Tree('irascibility.n.01', [])]), Tree('fury.n.01', [Tree('lividity.n.01', []), Tree('wrath.n.01', [])]), Tree('infuriation.n.01', [])]), Tree('fear.n.01', [Tree('timidity.n.01', [Tree('diffidence.n.01', [Tree('unassertiveness.n.01', []), Tree('hesitance.n.01', [])]), Tree('cold_feet.n.01', []), Tree('shyness.n.01', [])]), Tree('apprehension.n.01', [Tree('foreboding.n.01', [Tree('shadow.n.04', []), Tree('presage.n.01', [])]), Tree('suspense.n.01', []), Tree('trepidation.n.01', []), Tree('chill.n.04', []), Tree('gloom.n.02', [])]), Tree('frisson.n.01', []), Tree('creeps.n.02', []), Tree('hysteria.n.02', []), Tree('horror.n.01', []), Tree('intimidation.n.03', []), Tree('alarm.n.01', []), Tree('panic.n.01', [Tree('swivet.n.01', [])]), Tree('stage_fright.n.01', []), Tree('scare.n.02', [])]), Tree('conditioned_emotional_response.n.01', []), Tree('emotional_state.n.01', [Tree('embarrassment.n.02', []), Tree('happiness.n.01', [Tree('blessedness.n.01', [Tree('nirvana.n.01', [])]), Tree('radiance.n.03', [])]), Tree('ecstasy.n.01', []), Tree('unhappiness.n.02', [Tree('sadness.n.02', [Tree('mourning.n.01', []), Tree('poignance.n.01', [])]), Tree('embitterment.n.01', [])]), Tree('gratification.n.01', [Tree('quality_of_life.n.01', []), Tree('comfort.n.05', [])]), Tree('state.n.06', [])]), Tree('hate.n.01', [Tree('misology.n.01', []), Tree('misoneism.n.01', [Tree('misocainea.n.01', [])]), Tree('misopedia.n.01', []), Tree('abhorrence.n.01', []), Tree('murderousness.n.01', []), Tree('malevolence.n.01', [Tree( ...

# %%
big_tree[4]
# Out:
# Tree('calmness.n.03', [Tree('coolness.n.01', []), Tree('tranquillity.n.02', [Tree('peace.n.03', []), Tree('easiness.n.01', [Tree('languor.n.01', [])])]), Tree('placidity.n.01', [])])

# %%
# A tree instance with no dtrs
print(type(big_tree[4][2]),big_tree[4][2])
len(big_tree[4][2])
# Out:
# <class 'nltk.tree.tree.Tree'> (placidity.n.01 )
# 0

# %% [markdown]
# ## from the nouns to the other parts of speech (a and v)
#
# We use the stemmer to get to synsets that are morphologically related to emotionm nouns
# and are adjectives.  Highly porous but a start.

# %% [markdown]
# nltk stemmers
#
# 1. ISRIStemmer: For Arabic
# 2. Lancaster stemmer:  agressive, recursive curious,curiousity,curio -> cury
# 3. Porter stemmer: popular Does work. curious,curiousity,curio -> cury

# %%
stemmers
# Out:
# ['ISRIStemmer',
#  'LancasterStemmer',
#  'PorterStemmer',
#  'RSLPStemmer',
#  'RegexpStemmer',
#  'SnowballStemmer',
#  'StemmerI']

# %% [markdown]
# The code below really doesnt work well since it assumes the output of the stemmer is a word,
# which it often isn't.  A better approach follows:

# %%
#pos="v"
#pos = "a"

stemmers = [nm for nm in dir(nltk) if "temmer" in nm]
#stemmer = nltk.PorterStemmer()
stemmer = nltk.LancasterStemmer()
# This needs a regexp that defines endings to be stripped
# but knows diddly aboiut English spelling rules
# so given "ed$" and "jarred" it will return "jarr"
#stemmer = nltk.RegexpStemmer()
# These both seem to be linguistically cautious stemmers.
# Not appropriate for this wild and wooly application.
#from nltk.stem import WordNetLemmatizer as wnl
#wnlstemmer = wnl()

def get_derivationally_related_words(ss_set, stemmer, pos="a"):
    new_pos_ss_set = []
    for ss1 in ss_set:
        #for ss2 in wn.synsets(stemmer.stem(ss1.name()),"a"):
        for l in ss1.lemmas():
            #[l.name() for l in sadness_ss.lemmas()]
            for ss_res in wn.synsets(stemmer.stem(l.name()),pos):
                new_pos_ss_set.append(ss_res)
    return new_pos_ss_set

def ss_set_to_word_set (ss_set):
    return sorted(list(set([nm for ss in ss_set for nm in ss.lemma_names()])))

# %%
emotion_adjectives_ss_set = get_derivationally_related_words(feeling_nouns, stemmer, pos="a")

emotion_verbs_ss_set = get_derivationally_related_words(feeling_nouns, stemmer, pos="v")

# %%
print(len(emotion_adjectives_ss_set))
# Out:
# 373

# %%
emotion_noun_words = ss_set_to_word_set(feeling_nouns)
emotion_adjective_words = ss_set_to_word_set(emotion_adjectives_ss_set)
emotion_verb_words = ss_set_to_word_set(emotion_verbs_ss_set)

# %%
len(emotion_noun_words), len(emotion_adjective_words), len(emotion_verb_words)
# Out:
# (804, 529, 985)

# %% [markdown]
# Observation: a lot of these verbs are of the "cause to have emotion" variety, like "aggravate".  Some are noise ("abandon").  Many are just puzzling

# %%
emotion_verb_words
# Out:
# ['abandon',
#  'abase',
#  'abash',
#  'abide',
#  'abide_by',
#  'accommodate',
#  'accomplish',
#  'accost',
#  'acerbate',
#  'ache',
#  'act',
#  'act_as',
#  'action',
#  'addict',
#  'adjourn',
#  'affect',
#  'affirm',
#  'affright',
#  'aggress',
#  'agitate',
#  'agree',
#  'ail',
#  'alarm',
#  'alert',
#  'alien',
#  'alienate',
#  'alight',
#  'allege',
#  'amaze',
#  'anger',
#  'angle',
#  'anguish',
#  'animate',
#  'anneal',
#  'annoy',
#  'anticipate',
#  'appal',
#  'appall',
#  'apprehend',
#  'arouse',
#  'ask',
#  'assault',
#  'assert',
#  'astonish',
#  'astound',
#  'atone',
#  'attach',
#  'attack',
#  'attaint',
#  'augur',
#  'auspicate',
#  'aver',
#  'avow',
#  'await',
#  'awe',
#  'back_away',
#  'back_out',
#  'badmouth',
#  'baffle',
#  'ball_over',
#  'bang',
#  'barrack',
#  'bash',
#  'bask',
#  'be',
#  'be_given',
#  'be_intimate',
#  'be_on_cloud_nine',
#  'beam',
#  'bear',
#  'bear_on',
#  'bear_upon',
#  'beat',
#  'beat_out',
#  'beatify',
#  'becalm',
#  'becharm',
#  'become_flat',
#  'bed',
#  'bedaze',
#  'bedazzle',
#  'bedevil',
#  'beg',
#  'begrudge',
#  'beguile',
#  'belong',
#  'belong_to',
#  'belt_along',
#  'beset',
#  'bet',
#  'betoken',
#  'bewitch',
#  'bid',
#  'bilk',
#  'bind',
#  'bitter',
#  'bless',
#  'block',
#  'blockade',
#  'blow_out_of_the_water',
#  'blush',
#  'bode',
#  'bond',
#  'bonk',
#  'boot',
#  'bop',
#  'bother',
#  'bow_out',
#  'break_down',
#  'bring',
#  'bring_up',
#  'brood',
#  'brook',
#  'bruise',
#  'buck',
#  'bucket_along',
#  'budge',
#  'bulk_large',
#  'bump_off',
#  'burden',
#  'burn',
#  'burn_down',
#  'burthen',
#  'bury',
#  'bust',
#  'call_back',
#  'call_down',
#  'call_forth',
#  'call_in',
#  'calm',
#  'calm_down',
#  'can',
#  'cannonball_along',
#  'captivate',
#  'capture',
#  'care',
#  'cark',
#  'carry',
#  'carry_out',
#  'carry_through',
#  'cast_down',
#  'catch',
#  'chafe',
#  'chagrin',
#  'channel',
#  'channelise',
#  'channelize',
#  'charge',
#  'charm',
#  'chasten',
#  'check',
#  'cheer',
#  'cheer_up',
#  'chevvy',
#  'chevy',
#  'chill',
#  'chill_out',
#  'chirk_up',
#  'chivvy',
#  'chivy',
#  'choke',
#  'choose',
#  'churn_up',
#  'circumnavigate',
#  'clear',
#  'clear_up',
#  'close',
#  'close_down',
#  'close_up',
#  'cloy',
#  'come_away',
#  'come_off',
#  'come_to',
#  'come_together',
#  'comfort',
#  'commit',
#  'compass',
#  'complain',
#  'comprehend',
#  'comprise',
#  'concern',
#  'conclude',
#  'confiscate',
#  'conflict',
#  'conform_to',
#  'confuse',
#  'congratulate',
#  'conjure',
#  'conjure_up',
#  'conk',
#  'consecrate',
#  'consider',
#  'console',
#  'constitute',
#  'contemn',
#  'contend',
#  'content',
#  'contest',
#  'contravene',
#  'cool',
#  'cool_down',
#  'cool_it',
#  'cool_off',
#  'correspond',
#  'cost',
#  'court',
#  'cover',
#  'covet',
#  'cower',
#  'crave',
#  'crawfish',
#  'crawfish_out',
#  'crawl',
#  'creep',
#  'crimson',
#  'cringe',
#  'cross',
#  'crossbreed',
#  'crow',
#  'crucify',
#  'crush',
#  'crystalise',
#  'crystalize',
#  'crystallise',
#  'crystallize',
#  'curve',
#  'cut_across',
#  'cut_through',
#  'dally',
#  'dash',
#  'daunt',
#  'daydream',
#  'daze',
#  'dazzle',
#  'deal',
#  'decompress',
#  'dedicate',
#  'defeat',
#  'deject',
#  'delight',
#  'demolish',
#  'demoralise',
#  'demoralize',
#  'deplumate',
#  'deplume',
#  'depress',
#  'desert',
#  'desire',
#  'desolate',
#  'despair',
#  'despise',
#  'despond',
#  'detach',
#  'detest',
#  'devil',
#  'devote',
#  'diddle',
#  'die',
#  'dig',
#  'digest',
#  'dip',
#  'disaffect',
#  'disappoint',
#  'discharge',
#  'discomfit',
#  'discompose',
#  'disconcert',
#  'discontent',
#  'disdain',
#  'disengage',
#  'disgrace',
#  'disgust',
#  'dishearten',
#  'dishonor',
#  'dishonour',
#  'dismay',
#  'dismiss',
#  'dismount',
#  'disorder',
#  'dispatch',
#  'dispirit',
#  'displace',
#  'displume',
#  'disquiet',
#  'dissemble',
#  'distract',
#  'distress',
#  'do_it',
#  'drag_through_the_mud',
#  'draw',
#  'draw_back',
#  'draw_off',
#  'dread',
#  'dream',
#  'drop',
#  'drop_down',
#  'dull',
#  'dun',
#  'dwarf',
#  'dwell',
#  'ease',
#  'eat_away',
#  'eat_into',
#  'edify',
#  'eff',
#  'elicit',
#  'elucidate',
#  'embarrass',
#  'embitter',
#  'embody',
#  'embolden',
#  'empty',
#  'enamor',
#  'enamour',
#  'enchant',
#  'encounter',
#  'endure',
#  'enjoy',
#  'enkindle',
#  'enlighten',
#  'enliven',
#  'enquire',
#  'enrapture',
#  'enthral',
#  'enthrall',
#  'entrance',
#  'envenom',
#  'equal',
#  'equip',
#  'erode',
#  'esteem',
#  'estrange',
#  'even',
#  'even_out',
#  'evoke',
#  'exalt',
#  'excite',
#  'excoriate',
#  'excruciate',
#  'execute',
#  'exhilarate',
#  'exhort',
#  'exist',
#  'expect',
#  'experience',
#  'express',
#  'extol',
#  'exuberate',
#  'exult',
#  'faint',
#  'fall',
#  'fall_off',
#  'fascinate',
#  'fatigue',
#  'favor',
#  'favour',
#  'fawn',
#  'fear',
#  'feel',
#  'feign',
#  'festinate',
#  'fiddle',
#  'fidget',
#  'fill',
#  'fill_up',
#  'find',
#  'finger',
#  'fire',
#  'fire_up',
#  'fit',
#  'fit_out',
#  'flicker',
#  'flirt',
#  'flitter',
#  'floor',
#  'flurry',
#  'flush',
#  'flutter',
#  'foil',
#  'fold',
#  'follow',
#  'force_out',
#  'forecast',
#  'foreshadow',
#  'foretell',
#  'forsake',
#  'fray',
#  'free',
#  'freeze_off',
#  'fret',
#  'fright',
#  'frighten',
#  'frighten_away',
#  'frighten_off',
#  'frustrate',
#  'fuck',
#  'fuel',
#  'fulfil',
#  'fulfill',
#  'fuss',
#  'gag',
#  'gall',
#  'gestate',
#  'get',
#  'get_across',
#  'get_at',
#  'get_down',
#  'get_it_on',
#  'get_laid',
#  'get_off',
#  'get_over',
#  'get_the_better_of',
#  'get_the_picture',
#  'get_to',
#  'gibe',
#  'give',
#  'give_care',
#  'give_notice',
#  'give_thanks',
#  'give_the_axe',
#  'give_the_sack',
#  'give_up',
#  'gladden',
#  'glamour',
#  'gloat',
#  'glorify',
#  'glow',
#  'go',
#  'go_down',
#  'go_for',
#  'go_off',
#  'go_under',
#  'grade',
#  'grasp',
#  'grate',
#  'gravel',
#  'grieve',
#  'grind',
#  'grizzle',
#  'grok',
#  'gross_out',
#  'grovel',
#  'grudge',
#  'hallow',
#  'handle',
#  'hanker',
#  'harass',
#  'harden',
#  'harry',
#  'hassle',
#  'hasten',
#  'hatch',
#  'hate',
#  'have',
#  'have-to_doe_with',
#  'have_a_bun_in_the_oven',
#  'have_a_go_at_it',
#  'have_intercourse',
#  'have_it_away',
#  'have_it_off',
#  'have_sex',
#  'hearten',
#  'hero-worship',
#  'hex',
#  'hie',
#  'hinder',
#  'hit',
#  'hoist',
#  'honor',
#  'honour',
#  'hook',
#  'hope',
#  'horrify',
#  'hotfoot',
#  'hover',
#  'humble',
#  'humiliate',
#  'humor',
#  'humour',
#  'hump',
#  'hunger',
#  'hurry',
#  'hurt',
#  'hush',
#  'hybridise',
#  'hybridize',
#  'idolise',
#  'idolize',
#  'ignite',
#  'illume',
#  'illuminate',
#  'illumine',
#  'impact',
#  'impound',
#  'impress',
#  'incline',
#  'incubate',
#  'induce',
#  'inebriate',
#  'infringe',
#  'injure',
#  'inquire',
#  'inspire',
#  'inspirit',
#  'interbreed',
#  'interest',
#  'intersect',
#  'invigorate',
#  'invoke',
#  'involve',
#  'irk',
#  'irradiate',
#  'irritate',
#  'itch',
#  'jab',
#  'jade',
#  'jam',
#  'jazz',
#  'jibe',
#  'jinx',
#  'jolly_along',
#  'jolly_up',
#  'joy',
#  'jubilate',
#  'jump_for_joy',
#  'keen',
#  'kick',
#  'kick_back',
#  'kill',
#  'kindle',
#  'knife',
#  'know',
#  'kvetch',
#  'lament',
#  'languish',
#  'lapse',
#  'laud',
#  'lean',
#  'leave_office',
#  'let_down',
#  'level',
#  'lie_with',
#  'lift',
#  'light',
#  'light_up',
#  'like',
#  'list',
#  'live',
#  'live_up_to',
#  'long',
#  'look',
#  'look_on',
#  'look_sharp',
#  'look_upon',
#  'loom',
#  'loose',
#  'loosen',
#  'loosen_up',
#  'lose',
#  'love',
#  'low',
#  'lower',
#  'lull',
#  'lust',
#  'make',
#  'make_for',
#  'make_love',
#  'make_out',
#  'make_relaxed',
#  'make_up',
#  'malign',
#  'manage',
#  'mangle',
#  'mark',
#  'marvel',
#  'mash',
#  'match',
#  'meander',
#  'meet',
#  'mellow',
#  'mellow_out',
#  'melt',
#  'moderate',
#  'molest',
#  'mollify',
#  'moo',
#  'mortify',
#  'mourn',
#  'mouse',
#  'move',
#  'move_back',
#  'murder',
#  'mutilate',
#  'nark',
#  'nauseate',
#  'need',
#  'nettle',
#  'niggle',
#  'nock',
#  'normalize',
#  'nose',
#  'observe',
#  'obstruct',
#  'occupy',
#  'off',
#  'offend',
#  'offer',
#  'omen',
#  'open_fire',
#  'oppress',
#  'opt',
#  'outfit',
#  'outrage',
#  'overcome',
#  'overshadow',
#  'pain',
#  'pall',
#  'palpate',
#  'palpitate',
#  'panic',
#  'pass',
#  'pass_out',
#  'pass_over',
#  'pay',
#  'pelt_along',
#  'pep_up',
#  'perch',
#  'persecute',
#  'personify',
#  'pertain',
#  'perturb',
#  'pet',
#  'pine',
#  'pipe_down',
#  'plague',
#  'plain',
#  'play',
#  'playact',
#  'please',
#  'pluck',
#  'plume',
#  'poke',
#  'polish_off',
#  'pooh-pooh',
#  'portend',
#  'posit',
#  'pout',
#  'predict',
#  'prefer',
#  'prefigure',
#  'presage',
#  'press_down',
#  'pretend',
#  'prevail',
#  'pride',
#  'prise',
#  'privilege',
#  'prize',
#  'proclaim',
#  'prod',
#  'prognosticate',
#  'protect',
#  'provoke',
#  'pull',
#  'pull_away',
#  'pull_back',
#  "pull_in_one's_horns",
#  'pulsate',
#  'purge',
#  'pussyfoot',
#  'put_forward',
#  'put_off',
#  'put_up',
#  'quake',
#  'queer',
#  'question',
#  'quetch',
#  'quiesce',
#  'quiet',
#  'quiet_down',
#  'quieten',
#  'quit',
#  'quiver',
#  'race',
#  'rack',
#  'rack_up',
#  'radiate',
#  'rag',
#  'rage',
#  'raise',
#  'ramp',
#  'rankle',
#  'rape',
#  'ravish',
#  'reboot',
#  'recall',
#  'recede',
#  'reckon',
#  'recoil',
#  'reconcile',
#  'recreate',
#  'redden',
#  'refer',
#  'regard',
#  'regard_as',
#  'regret',
#  'reject',
#  'rejoice',
#  'relate',
#  'relax',
#  'release',
#  'relinquish',
#  'relish',
#  'remove',
#  'renounce',
#  'repel',
#  'repent',
#  'represent',
#  'repugn',
#  'repute',
#  'require',
#  'resent',
#  'resign',
#  'respect',
#  'retire',
#  'retreat',
#  'revel',
#  'revere',
#  'reverence',
#  'revolt',
#  'rile',
#  'roleplay',
#  'roll',
#  'roll_in_the_hay',
#  'romance',
#  'root_on',
#  'rub',
#  'rue',
#  'run',
#  'run_afoul',
#  'rupture',
#  'rush',
#  'rush_along',
#  'sack',
#  'sanctify',
#  'satisfy',
#  'savor',
#  'savour',
#  'savvy',
#  'say',
#  'scandalise',
#  'scandalize',
#  'scare',
#  'scare_away',
#  'scare_off',
#  'scent',
#  'score',
#  'scorn',
#  'scotch',
#  'scour',
#  'scrape',
#  'scratch',
#  'screw',
#  'season',
#  'seclude',
#  'sedate',
#  'seduce',
#  'see',
#  'see_red',
#  'seize',
#  'send',
#  'send_away',
#  'sense',
#  'sequester',
#  'sequestrate',
#  'settle',
#  'settle_down',
#  'sex',
#  'shade',
#  'shade_off',
#  'shadow',
#  'shake',
#  'shake_up',
#  'sham',
#  'shame',
#  'shed_light_on',
#  'shell',
#  'shift',
#  'shine',
#  'ship',
#  'shiver',
#  'shock',
#  'shoot',
#  'shoot_down',
#  'shudder',
#  'shut',
#  'shut_down',
#  'sicken',
#  'sign',
#  'simmer_down',
#  'sink',
#  'slack',
#  'slack_up',
#  'slacken',
#  'slam',
#  'slant',
#  'slay',
#  'sleep_together',
#  'sleep_with',
#  'slide_down',
#  'slow_down',
#  'sluice',
#  'slump',
#  'smart',
#  'smash',
#  'snap',
#  'sneak',
#  'sock',
#  'solace',
#  'solicit',
#  'soothe',
#  'sorrow',
#  'sort_out',
#  'sound_off',
#  'span',
#  'spang',
#  'speed',
#  'spice',
#  'spice_up',
#  'spiel',
#  'spirit',
#  'spirit_up',
#  'spite',
#  'spoil',
#  'spurn',
#  'squash',
#  'squeeze',
#  'squelch',
#  'stab',
#  'stand',
#  'stargaze',
#  'starve',
#  'state',
#  'steady',
#  'step_down',
#  'step_on_it',
#  'stew',
#  'stick_out',
#  'still',
#  'stimulate',
#  'stir',
#  'stomach',
#  'storm',
#  'straighten_out',
#  'straiten',
#  'strike',
#  'stun',
#  'stymie',
#  'stymy',
#  'submit',
#  'subside',
#  'suffer',
#  'suit',
#  'sulk',
#  'support',
#  'suppress',
#  'sustain',
#  'swallow',
#  'swan',
#  'swear',
#  'sweep',
#  'swoon',
#  'take',
#  'take_aback',
#  'take_away',
#  'take_back',
#  'take_on',
#  'take_out',
#  'take_to_be',
#  'tally',
#  'tap',
#  'tear',
#  'tell',
#  'temper',
#  'tend',
#  'tender',
#  'tenderise',
#  'tenderize',
#  'terminate',
#  'thank',
#  'think_of',
#  'thirst',
#  'thread',
#  'thrill',
#  'throb',
#  'thwart',
#  'tickle',
#  'tickle_pink',
#  'tie',
#  'tilt',
#  'tip',
#  'tire',
#  'tolerate',
#  'torment',
#  'torture',
#  'touch',
#  'touch_on',
#  'toy',
#  'track',
#  'traduce',
#  'trance',
#  'tranquilize',
#  'tranquillise',
#  'tranquillize',
#  'transfer',
#  'transmit',
#  'transport',
#  'traumatise',
#  'traumatize',
#  'traverse',
#  'trifle',
#  'triumph',
#  'trouble',
#  'trounce',
#  'trust',
#  'turn_down',
#  'turn_on',
#  'twine',
#  'twist',
#  'unbend',
#  'unhinge',
#  'unhorse',
#  'unlax',
#  'unsay',
#  'unstrain',
#  'untune',
#  'unwind',
#  'upset',
#  'urge',
#  'urge_on',
#  'vacate',
#  'value',
#  'vanquish',
#  'venerate',
#  'verify',
#  'vex',
#  'vibrate',
#  'view',
#  'violate',
#  'vote_down',
#  'vote_out',
#  'wager',
#  'wait',
#  'walk_on_air',
#  'wallow',
#  'wander',
#  'want',
#  'warm',
#  'warm_up',
#  'waver',
#  'weary',
#  'weave',
#  'weight',
#  'weight_down',
#  'whap',
#  'whop',
#  'wind',
#  'wind_up',
#  'wish',
#  'wish_well',
#  'witch',
#  'withdraw',
#  'wonder',
#  'woo',
#  'woolgather',
#  'work',
#  'worry',
#  'worship',
#  'wound',
#  'wrap',
#  'wreak',
#  'wreathe',
#  'yearn',
#  'yen',
#  'zest']

# %% [markdown]
# ## Stemmers redux

# %% [markdown]
# A more realistic picture of what the stemmers do:

# %%
examples = ("destruction destroy destructible indestructible curiousity curious emblematic" +\
            " emblem orientation orient furious fury abstemious abstain" +\
            " fleece undoable government govern aviate aviator aviation").split()
port,snow,lanc = nltk.PorterStemmer(),nltk.SnowballStemmer("english"),nltk.LancasterStemmer()
banner = f" {'Word':<15}  {'Port':<15}  {'Snow':<15} {'Lanc':<15} "
print(banner)
print("="*len(banner))
for wd in examples:
    #print(wd)
    print(f"{wd:<15} {port.stem(wd):<15}  {snow.stem(wd):<15} {lanc.stem(wd):<15}")
# Out:
#  Word             Port             Snow            Lanc
# ===================================================================
# destruction     destruct         destruct        destruct
# destroy         destroy          destroy         destroy
# destructible    destruct         destruct        destruct
# indestructible  indestruct       indestruct      indestruct
# curiousity      curious          curious         cury
# curious         curiou           curious         cury
# emblematic      emblemat         emblemat        emblem
# emblem          emblem           emblem          emblem
# orientation     orient           orient          ory
# orient          orient           orient          ory
# furious         furiou           furious         fury
# fury            furi             furi            fury
# abstemious      abstemi          abstemi         abstemy
# abstain         abstain          abstain         abstain
# fleece          fleec            fleec           fleec
# undoable        undoabl          undoabl         undo
# government      govern           govern          govern
# govern          govern           govern          govern
# aviate          aviat            aviat           avy
# aviator         aviat            aviat           avy
# aviation        aviat            aviat           avy

# %%
from collections import defaultdict
stem_dict = defaultdict(set)
#stemmer = nltk.PorterStemmer()
#stemmer = nltk.LancasterStemmer()

def update_stem_dict (ss_container):
    for ss in ss_container:
        for lname in ss.lemma_names():
            stem_name = stemmer.stem(lname)
            stem_dict[stem_name].add(lname)
            
            
def update_stem_dict_all_pos ():
    wn_nouns = wn.all_synsets('n')
    update_stem_dict (wn_nouns)
    wn_verbs = wn.all_synsets('v')
    update_stem_dict (wn_verbs)
    wn_adjectives = wn.all_synsets('a')
    update_stem_dict (wn_adjectives)

# %%
update_stem_dict_all_pos ()

# %% [markdown]
# Overstemming examples:

# %%
stemmer.stem("elation")
# Out:
# 'el'

# %% [markdown]
# The word *ell* is a former unit of length used mainly in the textile industry.

# %% [markdown]
# Good class: {element', 'elemental', 'elementary', 'elements'}
# Not in the same class :  "ell", "elated", "elan"

# %%
stem_dict["el"]
# Out:
# {'EL',
#  'ELA',
#  'Elagatis',
#  'Elia',
#  'Elul',
#  'el',
#  'elan',
#  'elate',
#  'elated',
#  'elater',
#  'elating',
#  'elation',
#  'element',
#  'elemental',
#  'elementary',
#  'elements',
#  'ell'}

# %% [markdown]
# Correct: classing "error" with "err".  Error: Classing "error" with "era".

# %%
stem_dict["er"]
# Out:
# {'ER',
#  'ERA',
#  'Er',
#  'Ericales',
#  'Eris',
#  'Erivan',
#  'era',
#  'eristic',
#  'eristical',
#  'err',
#  'errancy',
#  'errant',
#  'erratic',
#  'erring',
#  'error'}

# %% [markdown]
# ```
# stem:  depress
# Good:  depressing depression depressive Depression depress depressed depressor depressant
# Bad:   depressurize
# ```

# %%
L = sorted(list(stem_dict.items()))#,key = lambda x: x[1]
for (k,v) in L:
    if len(v) > 6 and len(k) > 4:
        print(f"{k:<10} {len(v):>2}  {" ".join(v)}")
# Out:
# absorb      9  absorbed absorbance absorber absorbable absorbency absorbing absorb absorbate absorbent
# accept     10  acceptation acceptability acceptive acceptableness accepted acceptable acceptance accept accepting acceptant
# accus       8  accusal accusive accused accusing accuse accuser accusative accusation
# activ       9  activate activity activator activation activeness activating active activated activism
# adapt      10  adapt adapted adaptation adaptability adaption adaptative adaptational adapter adaptable adaptive
# admir       8  admired admire admirability admirableness admirable admiration admirer admiral
# adulter     8  adulterating adulterous adulterant adulterated adulterer adulterator adulterate adulteration
# advert      7  advertizer advertence advertent advert advertency advertize advertizing
# affect      7  affected affect affectation affectional affecting affective affection
# affirm      7  affirmable affirmative affirmation affirmer affirm Affirmed affirmativeness
# alien       8  alienism alienate alienated alienable alienation alienator alien alienating
# alphabet    7  alphabetized alphabetize alphabetical alphabetization alphabetizer alphabetic alphabet
# alter       7  alterable alterability altering alteration alterative alter altered
# appreci     7  appreciated appreciable appreciate appreciative appreciativeness appreciator appreciation
# arbitr      8  arbitrator arbitrement arbitrate arbitrational arbitral arbitrative arbitrable arbitration
# ascend     11  ascendence ascending ascender ascendant ascendancy ascendent ascendible ascend ascendency ascendance ascendable
# aspir       7  aspirer aspirate aspire aspiring aspirant aspirator aspiration
# assert      8  assertiveness assertive assertable assert asserting asserted asserter assertion
# associ      7  associable associative associableness associability association associational associate
# author      7  authorization authorized authority author authorize authorities authorizer
# barbar      7  barbarousness barbarize barbarous barbarity barbaric barbarism barbarization
# brown       7  brown Browne browning browned brownness Brown Browning
# calcul      8  calculator calculating calculative calculate calculation calculated calculous calculable
# capit       7  capitalism capitate capitation capitalization Capital capital capitalize
# carbon      8  carbonize carbonate carbonization carbon carbonic carbonation carbonous carbonated
# central     7  centralization centralize centralism centralized centrality central centralizing
# collect     7  collective collect collectable collecting collectible collected collection
# colon       7  colonization colon colonized colonizer colonic Colon colonize
# color       7  colors coloration colorize coloring colored color colorful
# colour      7  coloured colouring colour colourize colourful colours colouration
# combin      7  combined combinable combinative combination combine combining combinational
# comfort     7  comforted comfort comfortableness comforting comforts comfortable comforter
# commun     16  communication communications communalism communicator communization communal communism communicativeness communize communicative communalize community commune communicate communicational communicating
# commut      9  commutator commuter commutability commutative commutable commutation commuting commutate commute
# concentr    7  concentrate concentrated concentric concentre concentration concentrical concentricity
# conform     7  conforming conformity conformism conformable conform conformance conformation
# conserv     8  conserved conserves conservation conservator conservative Conservative conservancy conserve
# continu    11  continual continuity continuation continuant continued continuing continuousness continuance continue continuative continuous
# convers     7  conversant conversational conversion converse conversancy conversance conversation
# cooper      7  cooperativeness cooperative cooper cooperation cooperate Cooper cooperator
# correct     8  corrective correctable correct correction correctional correctness corrected corrections
# corrupt     8  corruption corrupting corruptible corrupt corruptive corruptibility corrupted corruptness
# crimin      8  criminality criminative criminalization criminate criminalism criminal criminalize criminalness
# crystal     7  crystallize crystal crystalize crystallized crystallization crystallizing crystalized
# decor       9  decorous decoration decorator decorousness decorate decorative decor decorated decorativeness
# demonstr    8  demonstrative demonstrate demonstration demonstrability demonstrativeness demonstrable demonstrator demonstrated
# depend      9  dependence dependant dependance depend dependableness dependable dependability dependent dependency
# depress     7  depressive depressed depression depressant depressing Depression depress
# deriv       7  derivation derive derivative derived derivational derivable deriving
# design      7  designed design designing designation designative designer designate
# determin   11  determinable determinate determinant determine determined determination determinateness determinative determiner determining determinism
# diffus      7  diffusing diffused diffusion diffuseness diffuser diffusive diffuse
# digest      7  digestibleness digestible digestion digest digestibility digestive digester
# digit       8  digitalization digitate digit digitize digitization digital digitizer digitalize
# direct      9  directing directive direct directness directiveness directed direction directional directivity
# dispens     7  dispensed dispensation dispensableness dispensable dispense dispensability dispenser
# domin      11  dominated domination dominating domine Dominic domineer domineering dominant dominance dominical dominate
# effect      7  effect effected effective effectiveness effects effecter effectivity
# excit      10  excitable excitant excited excitative excitement excitation excitableness excitability exciting excite
# execut      8  execution executability executive execute executable executed executing executant
# feder       8  federalize federation federal federate federalization federalism federated Federal
# figur       7  figure figuring figurative figurer figured figuration figural
# formal      8  formalism formal formalized formality formalize formalization formalities formalness
# gener      13  generous general generalization generalized generation generate generic generality generative generousness generalize generational generator
# habit       7  habited habitant habitability habitable habitation habitableness habit
# harmon      7  harmonics harmonical harmonic harmonize harmonizer harmonized harmonization
# hesit       7  hesitant hesitance hesitating hesitator hesitate hesitancy hesitation
# homogen     8  homogenize homogenate homogenized homogeneity homogenization homogeneous homogenous homogeneousness
# human      10  humane humaneness humanism humanity humanize human humanities humanness humans humanization
# illumin     7  illumination illumine illuminated illuminant illuminance illuminate illuminating
# import      7  import importance importer importation imported important importing
# impress     7  impress impression impressible impressment impressiveness impressive impressed
# improv      7  improve improver improvement improving improvable improvize improved
# individu    8  individualism individuality individualize individualization individuate individualized individual individuation
# industri    8  industrious industrialized industrial industrialism industrialization industry industrialize industriousness
# inform     10  information informational informed informative informal informality informant informer informing inform
# initi       7  initiate initialization initiator initiative initiation initialize initial
# instil      7  instillation instilment instil instill instillator instilling instillment
# integr      9  integrality integrator integrative integral integrity integrated integrating integration integrate
# intern      9  International internment internality interne internal intern international internalize internalization
# interpret   8  interpretation interpreter interpretable interpreting interpretive interpreted interpretative interpret
# invalid     9  invalidator invalidating invalidation invalidness invalidism invalidate invalidated invalid invalidity
# irrit       8  irritative irritating irritation irritant irritated irritability irritable irritate
# lament      7  lament lamenter lamented lamentation lamenting Lamentations lamentable
# liber      10  liberalization liberality liberalism liberal liberated liberalness liberalize liberate liberation liberator
# liquid      8  liquidation liquidizer liquidness liquidity liquidize liquidator liquidate liquid
# local       7  local locale localization localize localism localized locality
# luxuri      7  luxuriation luxuriant luxurious luxury luxuriousness luxuriate luxuriance
# magnet      7  magnet magnetized magnetization magnetic magnetism magnetics magnetize
# malign      7  malignant malignancy malignity malignment maligner malignance malign
# matur       8  mature maturity maturational matureness maturate maturation maturement matured
# maxim       7  maximize maximizing maximization maxim maximation Maxim maximal
# measur      7  measurement measuring measurer measured measurability measure measurable
# mechan      7  mechanize mechanization mechanism mechanics mechanized mechanical mechanic
# mesmer      7  mesmeric Mesmer mesmerize mesmerizing mesmerizer mesmerized mesmerism
# modern      9  modern modernity modernization modernism modernized Modern modernness moderne modernize
# moral       8  morals moralism moral morality moralization moralize moralizing morale
# motiv       9  motive motivity motivate motivated motivating motivator motivative motivation motivational
# nation      7  nation nationalism national Nation nationality nationalize nationalization
# natur       8  naturalization natural naturalism naturalness nature naturism naturalize naturalized
# nomin       7  nominative nominalism nomination nominate nominated nominal nominator
# numer       9  numeration numerator numeral numerable numerousness numerate numerical numerous numeric
# oblig       8  obligated obligate obliging oblige obligational obliger obligation obliged
# observ      9  observant observing observation observed observe observance observer observable observational
# offici      8  official officiate officiousness officiant officious officialize officiating officiation
# organ       8  organic organizer organ organism organized organize organs organization
# orient     13  orienting Orient orientate oriented orientating orientation orientalism orientalize oriental Orientalism orientated orient Oriental
# origin      8  originator originality origination origin originalism original originative originate
# palat       7  palatalize palatability palatal palatable palatableness palatalized palate
# penetr      7  penetrator penetrative penetrating penetrability penetration penetrable penetrate
# percept     7  perceptivity perceptiveness percept perception perceptive perceptibility perceptible
# perfect     7  perfection perfectibility perfecter perfective perfectible perfected perfect
# person      9  personal personality personate personable personableness personation person personalized personalize
# posit       7  positiveness position positioning posit positive positional positivity
# practic     7  practicality practice practicability practicable practiced practical practicableness
# precipit   10  precipitator precipitant precipitancy precipitating precipitous precipitation precipitance precipitate precipitousness precipitateness
# present     8  presentness present presenter presentation presentism presentable presentational presentment
# preserv     7  preservative preservation preserves preserver preserved preservable preserve
# privat      7  privateness privates privatization privatize private privateer privation
# procur      7  procurer procurator procural procurance procurement procurable procure
# public      7  publicizing publicizer publication public publicity publicize publicized
# ration      9  rationed ration rationing rationalness rationalization rationalize rationalism rational rationality
# reflect     8  reflection reflectiveness reflectance reflectivity reflective reflecting reflect reflected
# reform      9  reformed Reformation reformable reform Reformed reformation reformer reformism reformative
# resist      7  resistance resistant resister resist resistive resistivity resistible
# respect     9  respectability respective respectfulness respected respecter respects respectable respectful respect
# revers      7  reversed reverse reversibility reversal reversive reversible reversion
# roman       7  Romanize Romanal Romanic Roman Romans Romanism roman
# season      7  seasonal seasoned seasonableness season seasonable seasoning seasoner
# sensit      8  sensitization sensitizer sensitize sensitizing sensitivity sensitized sensitiveness sensitive
# sentiment   7  sentiment sentimentalize sentimentality sentimentalism sentimentize sentimental sentimentalization
# separ       8  separator separable separation separative separate separateness separability separated
# servic      7  Service serviceable serviceability service services servicing serviceableness
# sever      10  severity severe severable severeness severance severed severalize several sever severing
# social      8  socializing socialize socialized socializer sociality social socialism socialization
# sophist     7  sophisticated sophisticate sophistic sophistical sophistication Sophist sophist
# special     8  specialism specialize specializer specialness speciality specialized specialization special
# stabil      7  stability stabile stabilizer stabilization stabilized stabilizing stabilize
# steril      7  sterilization sterilizer sterilize sterility sterilized sterile sterileness
# subsid      7  subsidization subsidizer subsidize subside subsidence subsidized subsiding
# substanti   7  substantiation substantiate substantiating substantiality substantiative substantialness substantial
# symbol      8  symbolization symbol symbolical symbolizer symbolism symbolize symbolic symbolizing
# synchron   11  synchronized synchroneity synchronism synchronal synchronization synchronicity synchronizer synchronous synchronizing synchronize synchronic
# termin      7  terminative termination terminator terminable terminate terminated terminal
# tranquil    9  tranquillizer tranquilize tranquil tranquillity tranquilizer tranquillizing tranquility tranquillize tranquilizing
# travel      8  traveled traveling travelled traveller travelable traveler travelling travel
# valid       7  validate validation valid validness validated validity validating
# vapor       9  vaporing vaporous vaporized vaporization vapors vaporizer vaporize vaporousness vapor
# veget       7  vegetate vegetation vegetative vegetational vegetive vegetable vegetal
# vener       8  venereal venerator veneration venerableness venerate venerating venerability venerable
# vital       9  vitalizer vitalness vitals vitalization vitalizing vital vitality vitalism vitalize
# vocal       7  vocalize vocalizer vocalic vocalization vocal vocalism vocalizing

# %% [markdown]
# Next step: filter results back to word, pos pairs known in WordNet

# %%
legal_poses = ("a","v", "n")

def make_word2stem_dict():
    """
    key is a word pos pairs; val is the unique stem
    for that pair.
    """
    word2stem_dict = dict()
    for (stem0, word_set) in stem_dict.items():
        if len(stem0) < 3:
            continue
        for word in word_set:
            for pos in legal_poses:
                if wn.synsets(word,pos):
                    if (word,pos) in word2stem_dict:
                        raise Exception("Ambiguous stem for {word} {pos} {stem0} {word2stem_dict[(word,pos)]}")
                    word2stem_dict[(word,pos)] = stem0
    return word2stem_dict 

word2stem_dict  = make_word2stem_dict()

# %%
word2stem_dict[("aviation","n")]
# Out:
# 'aviat'

# %% [markdown]
# Demoing the idea of the above mapping:

# %%
def find_poses(word):
    return [pos for pos in "a v n".split() if wn.synsets(word,pos)]
    
for stem in ["commun","fruit", "intern", "interpret"]:
    for word in sorted(list(stem_dict[stem])):
        pos_list = find_poses(word)
        print(f"{word:<20}   {stem:<10} {' '.join(pos_list)}")
    print()
# Out:
# communal               commun     a
# communalism            commun     n
# communalize            commun     v
# commune                commun     v n
# communicate            commun     v
# communicating          commun     v n
# communication          commun     n
# communicational        commun     a
# communications         commun     n
# communicative          commun     a
# communicativeness      commun     n
# communicator           commun     n
# communism              commun     n
# community              commun     n
# communization          commun     n
# communize              commun     v
#
# fruit                  fruit      v n
# fruitful               fruit      a
# fruitfulness           fruit      n
# fruiting               fruit      a v
#
# International          intern     a n
# intern                 intern     v n
# internal               intern     a
# internality            intern     n
# internalization        intern     n
# internalize            intern     v
# international          intern     a n
# interne                intern     n
# internment             intern     n
#
# interpret              interpret  v
# interpretable          interpret  a
# interpretation         interpret  n
# interpretative         interpret  a
# interpreted            interpret  a v
# interpreter            interpret  n
# interpreting           interpret  v n
# interpretive           interpret  a

# %% [markdown]
# ```
# word2stem_dict: word |-> stem
# stem_dict:  stem |-> words
# ```
#
# Use this pairing to find verbs related to the noun aviation:

# %%
st_avy = word2stem_dict[("aviation","n")]
for wd in stem_dict[st_avy]:
    for ss in wn.synsets(wd,"v"):
        for l in ss.lemmas():
            print(l.name())
        #print(lem.lemmas())
# Out:
# fly
# aviate
# pilot

# %%
wn_absolute_root = wn.synset("entity.n.01")

def get_related_lemmas(word,pos1,pos2,upper_bound=None):
    results = set()
    try:
        st_avy = word2stem_dict[(word,pos1)]
    except KeyError:
        return []
    for wd in stem_dict[st_avy]:
        for ss in wn.synsets(wd,pos2):
            if upper_bound is not None and upper_bound in get_hypers_iter(ss):
                for l in ss.lemmas():
                    results.add(l)
            elif upper_bound is None:
                for l in ss.lemmas():
                    results.add(l)
    return results

# %%
get_related_lemmas("happiness","n","a")
# Out:
# {Lemma('felicitous.s.02.felicitous'),
#  Lemma('glad.s.02.glad'),
#  Lemma('happy.a.01.happy'),
#  Lemma('happy.s.04.well-chosen')}

# %%
get_related_lemmas("aviation","n","v")
# Out:
# {Lemma('fly.v.03.aviate'), Lemma('fly.v.03.fly'), Lemma('fly.v.03.pilot')}

# %%
get_related_lemmas("fly","v","a")
# Out:
# {Lemma('flying.s.02.fast'),
#  Lemma('fast-flying.s.01.fast-flying'),
#  Lemma('fly.s.01.fly'),
#  Lemma('fast-flying.s.01.flying'),
#  Lemma('flying.s.02.quick')}

# %%
get_related_lemmas("aviate","v","n")
# Out:
# {Lemma('aviator.n.01.aeronaut'),
#  Lemma('air_travel.n.01.air'),
#  Lemma('aviation.n.01.air_power'),
#  Lemma('air_travel.n.01.air_travel'),
#  Lemma('aviator.n.01.airman'),
#  Lemma('aviation.n.03.airmanship'),
#  Lemma('aviation.n.01.aviation'),
#  Lemma('aviator.n.01.aviator'),
#  Lemma('aviator.n.01.flier'),
#  Lemma('aviator.n.01.flyer')}

# %%
noun2related_adj_dict22 = make_noun2related_adj_dict()

# %% [markdown]
# # Framenet

# %%
from nltk.corpus import framenet as fn

fn.lu(256).name
#'foresee.v'
# Out:
# 'foresee.v'

# %%
fn.lu(256).definition
#'COD: be aware of beforehand; predict.'
# Out:
# 'COD: be aware of beforehand; predict.'

# %%
fn.lu(256).frame.name
#'Expectation'
# Out:
# 'Expectation'

# %%
f_exp = fn.frame("Expectation")
f_exp
# Out:
# frame (26): Expectation
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Expectation.xml
#
# [definition]
#   Words in this frame have to do with a Cognizer believing that
#   some Phenomenon will take place in the future.  Some words in the
#   frame (e.g. foresee.v) indicate that the Phenomenon is asserted
#   also to be true, while others do not.  'Michael expected Abby to
#   demand examples.' 'From the look on her face Michael expected
#   that she would say she got the job.'
# [semTypes] 0 semantic types
#
# [frameRelations] 3 frame relations
#   <Parent=Awareness -- Inheritance -> Child=Expectation>
#   <Parent=Expectation -- Using -> Child=Predicting>
#   <MainEntry=Omen -- See_also -> ReferringEntry=Expectation>
#
# [lexUnit] 14 lexical units
#   anticipate.v (253), await.v (254), expect.v (255), expectation.n
#   (13081), foresee.v (256), foreseeable.a (3588), predict.v (257),
#   predictable.a (3585), prediction.n (13082), premonition.n
#   (13083), unexpected.a (13928), unforeseeable.a (3587),
#   unpredictable.a (3586), wait.v (16597)
#
# [FE] 10 frame elements
#             Core: Cognizer (109), Phenomenon (110), Topic (9837)
#       Peripheral: Degree (1029), Evidence (1041), Manner (1033), Place (9835), Time (9836), Time_of_phenomenon (16124)
#   Extra-Thematic: Depictive (1030)
#
# [FEcoreSets] 1 frame element core sets
#   Topic, Phenomenon

# %%
f_exp.lexUnit
# Out:
# {'anticipate.v': <lu ID=253 name=anticipate.v>, 'await.v': <lu ID=254 name=await.v>, 'expect.v': <lu ID=255 name=expect.v>, 'expectation.n': <lu ID=13081 name=expectation.n>, 'foresee.v': <lu ID=256 name=foresee.v>, 'foreseeable.a': <lu ID=3588 name=foreseeable.a>, 'predict.v': <lu ID=257 name=predict.v>, 'predictable.a': <lu ID=3585 name=predictable.a>, 'prediction.n': <lu ID=13082 name=prediction.n>, 'premonition.n': <lu ID=13083 name=premonition.n>, 'unexpected.a': <lu ID=13928 name=unexpected.a>, 'unforeseeable.a': <lu ID=3587 name=unforeseeable.a>, 'unpredictable.a': <lu ID=3586 name=unpredictable.a>, 'wait.v': <lu ID=16597 name=wait.v>}

# %%
# lexUnit in frame
anticipate_v = f_exp.lexUnit['anticipate.v']
anticipate_v
# Out:
# lexical unit (253): anticipate.v
#
# [definition]
#   COD: regard as probable
# [frame] Expectation(26)
#
# [POS] V
#
# [status] FN1_Sent
#
# [lexemes] anticipate/V
#
# [semTypes] 0 semantic types
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/lu/lu253.xml
#
# [subCorpus] 19 subcorpora
#   V-420-that-sfin, V-430-sfin, V-480-swh, V-570-np-ppfor,
#   V-570-np-ppfrom, V-570-np-ppwith, V-620-np-ppother,
#   V-650-np-pother, V-660-trans-simple, V-670-pass-by,
#   V-680-pass, V-690-trans-other, V-730-ppfor, V-730-ppfrom,
#   V-730-ppwith, V-780-ppother, V-810-pother, V-890-intrans-
#   adverb, V-900-other
#
# [exemplars] 58 sentences across all subcorpora

# %% [markdown]
# Retrieving an example

# %%
sent0 = anticipate_v.subCorpus[0].sentence[0]

sent0.POS
# Out:
# [(0, 3, 'AT0'),
#  (4, 8, 'NN1'),
#  (9, 13, 'AV0'),
#  (14, 25, 'VVD-VVN'),
#  (26, 30, 'CJT'),
#  (31, 36, 'EX0'),
#  (37, 42, 'VM0'),
#  (43, 45, 'VBI'),
#  (46, 53, 'DT0'),
#  (54, 59, 'NN2'),
#  (60, 62, 'PRP'),
#  (63, 68, 'DTQ'),
#  (69, 71, 'TO0'),
#  (72, 76, 'VVI'),
#  (77, 80, 'AT0'),
#  (81, 92, 'AJ0-NN1'),
#  (93, 103, 'NN1'),
#  (104, 108, 'CJT'),
#  (109, 111, 'AT0'),
#  (112, 118, 'NN1'),
#  (119, 121, 'PRF'),
#  (122, 135, 'NN1'),
#  (136, 139, 'VBD'),
#  (140, 145, 'AVP'),
#  (146, 148, 'TO0'),
#  (149, 155, 'VVI'),
#  (156, 157, 'PUN')]

# %%
sent0.FE
# Out:
# ([(0, 8, 'Cognizer'), (26, 155, 'Phenomenon')], {})

# %%
print(sent0._ascii())
# Out:
# The CEGB also anticipated that there would be several hours in
# --------      *********** -------------------------------------
# Cognizer                  Phenomenon
#
# which to warn the surrounding population that an escape of
# -----------------------------------------------------------
#
#
# radioactivity was about to happen .
# ---------------------------------

# %%
sep = ("="*80)+"\n"
def get_example_corpus (word,n=10):
    frames = fn.frames_by_lemma(word)
    for fm in frames[:n]:
        print(sep)
        print(f"Begin {fm.name.upper()}",end="\n\n")
        #print(f'***{fm.name.upper()} ***')
        il = list(fm.lexUnit.items())
        for (lex_str, lu_dict) in il[:n]:
            for sc in lu_dict.subCorpus[:n]:
                for sent in sc.sentence[:n]:
                    print(sent._ascii())
        print(f"End {fm.name.upper()}",end="\n\n")
        print(sep)

# %%
get_example_corpus ("expect",n=1)
# Out:
# ================================================================================
#
# Begin EXPECTATION
#
# The CEGB also anticipated that there would be several hours in
# --------      *********** -------------------------------------
# Cognizer                  Phenomenon
#
# which to warn the surrounding population that an escape of
# -----------------------------------------------------------
#
#
# radioactivity was about to happen .
# ---------------------------------
#
#
#
# End EXPECTATION
#
# ================================================================================

# %% [markdown]
# #### The key steps LUs -> frame and frame -> LUs

# %%
from operator import itemgetter
PrettyList(sorted(fn.frames_by_lemma(r'(?i)a little'), key=itemgetter('ID')))
# Out:
# [<frame ID=189 name=Quantified_mass>, <frame ID=2001 name=Degree>]

# %%
from operator import itemgetter
#Here is form to frame functionality
L=sorted(fn.frames_by_lemma("inquire"), key=itemgetter('ID'))
L
# Out:
# [frame (40): Questioning
#
#  [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Questioning.xml
#
#  [definition]
#    The words in this frame have to do with a Speaker asking an
#    Addressee a question which calls for a reply (as opposed to
#    making a request which calls for an action on the part of the
#    Addressee).  '' 'We asked Ruby what kind of food they ate.'
#    'Yeats was able to interrogate the spirit world about his
#    relationship with Maude.'
#  [semTypes] 0 semantic types
#
#  [frameRelations] 3 frame relations
#    <Parent=Communication -- Using -> Child=Questioning>
#    <Parent=Questioning -- Using -> Child=Court_examination>
#    <Source=Request -- ReFraming_Mapping -> Target=Questioning>
#
#  [lexUnit] 12 lexical units
#    ask.v (8421), grill.v (627), inquire.v (628), inquiry.n (629),
#    interrogate.v (630), interrogation.n (631), query.n (632),
#    query.v (633), question.n (634), question.v (635), questioning.n
#    (636), quiz.v (637)
#
#  [FE] 9 frame elements
#              Core: Addressee (168), Message (169), Speaker (167), Topic (170)
#        Peripheral: Manner (1483), Medium (171), Time (6310)
#    Extra-Thematic: Internal_cause (1525), Iterations (15712)
#
#  [FEcoreSets] 1 frame element core sets
#    Topic, Message,
#  frame (500): Criminal_investigation
#
#  [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Criminal_investigation.xml
#
#  [definition]
#    This frame describes the process that involves the inquiry and
#    determination by an authority, the Investigator, of the
#    circumstances surrounding an Incident perpetrated by a Suspect.
#    'The police are investigating the bank's reported loss of several
#    thousand dollars from their downtown branch's top security vault.
#    DNI ' 'Authorities are investigating several murders. DNI'
#  [semTypes] 0 semantic types
#
#  [frameRelations] 5 frame relations
#    <Complex=Crime_scenario -- Subframe -> Component=Criminal_investigation>
#    <Parent=Criminal_investigation -- Using -> Child=Suspicion>
#    <Parent=Seeking -- Using -> Child=Criminal_investigation>
#    <Earlier=Committing_crime -- Precedes -> Later=Criminal_investigation>
#    <Earlier=Criminal_investigation -- Precedes -> Later=Criminal_process>
#
#  [lexUnit] 9 lexical units
#    case.n (18702), clue.n (8403), inquire.v (7965), inquiry.n
#    (7958), investigate.v (7963), investigation.n (8046), lead.n
#    (8402), probe.n (7959), probe.v (7966)
#
#  [FE] 5 frame elements
#              Core: Incident (4045), Investigator (4041), Suspect (4693)
#        Peripheral: Time (4075)
#    Extra-Thematic: Duration (4096)
#
#  [FEcoreSets] 0 frame element core sets
#    ]

# %% [markdown]
# The lexunit object has valence info (under `subCorpus`:

# %%
def lex2colexes (lex,result=None,allowed=None):
    if result is None:
        result = dict()
    frames = fn.frames_by_lemma(lex)
    if allowed is not None:
        frames = [frame for frame in frames if frame.name in allowed]
    for frame in frames:
        result[frame.name] = list(frame.lexUnit.keys())
    return result

# %% [markdown]
# The words that share frame (and therefore frame-properties) with "inquire".

# %%
lex2colexes("inquire.v")
# Out:
# {'Criminal_investigation': ['inquiry.n',
#   'probe.n',
#   'investigate.v',
#   'inquire.v',
#   'probe.v',
#   'investigation.n',
#   'lead.n',
#   'clue.n',
#   'case.n'],
#  'Questioning': ['grill.v',
#   'inquire.v',
#   'inquiry.n',
#   'interrogate.v',
#   'interrogation.n',
#   'query.n',
#   'query.v',
#   'question.n',
#   'question.v',
#   'questioning.n',
#   'quiz.v',
#   'ask.v']}

# %% [markdown]
# noun_sample =[]
# for (i,x) in enumerate(feeling_nouns):
#     noun_sample.append(x.name()[:-3])

# %%
feeling_frames = "Judgment Contrition Experiencer_focus Desiring Stimulus_focus".split()
colex_dicts = [lex2colexes (lex,allowed=feeling_frames) for lex in noun_sample]

# %%
form_yield = [form for  colex_dict in colex_dicts for form_list in colex_dict.values() for form in form_list]
len(form_yield),len(set(form_yield))
# Out:
# (4004, 366)

# %%
adj_list = [adj[:-2] for  colex_dict in colex_dicts for form_list in colex_dict.values() for adj in form_list if adj.endswith(".a")]
adj_yield = set(adj_list)
len(adj_list),len(set(adj_yield))
# Out:
# (2570, 221)

# %%
adj_yield
# Out:
# {'abominable',
#  'absorbing',
#  'admiring',
#  'agape',
#  'aggravating',
#  'agonizing',
#  'agreeable',
#  'alarming',
#  'alienating',
#  'amazing',
#  'amusing',
#  'annoying',
#  'appalling',
#  'appreciative',
#  'apprehensive',
#  'approving',
#  'astonishing',
#  'astounding',
#  'baffling',
#  'beguiling',
#  'bewildering',
#  'bewitching',
#  'blood-curdling',
#  'boring',
#  'bothersome',
#  'breathtaking',
#  'calm',
#  'calming',
#  'captivating',
#  'charming',
#  'cheering',
#  'chilling',
#  'comforting',
#  'comical',
#  'confusing',
#  'consoling',
#  'contemptuous',
#  'contrite',
#  'cool',
#  'covetous',
#  'critical',
#  'dear',
#  'delightful',
#  'depressing',
#  'derisive',
#  'desired',
#  'desirous',
#  'devastating',
#  'disagreeable',
#  'disappointing',
#  'disapproving',
#  'discomfiting',
#  'discomforting',
#  'disconcerting',
#  'discouraging',
#  'disdainful',
#  'disgusting',
#  'disheartening',
#  'disillusioning',
#  'dismaying',
#  'disorientating',
#  'displeasing',
#  'dissatisfied',
#  'distasteful',
#  'distressing',
#  'disturbing',
#  'dreadful',
#  'droll',
#  'dull',
#  'dying',
#  'eager',
#  'earth-shattering',
#  'easy',
#  'electrifying',
#  'embarrassing',
#  'embittering',
#  'empty',
#  'enchanting',
#  'encouraging',
#  'engrossing',
#  'enjoyable',
#  'enraging',
#  'entertaining',
#  'enthralling',
#  'exasperating',
#  'exciting',
#  'exhilarating',
#  'fascinating',
#  'fazed',
#  'fed up',
#  'feverish',
#  'fond',
#  'formidable',
#  'frightening',
#  'fulfilled',
#  'fulfilling',
#  'full',
#  'funny',
#  'galling',
#  'ghastly',
#  'gratifying',
#  'gripping',
#  'guilty',
#  'hair-raising',
#  'harrowing',
#  'heart-rending',
#  'heart-stopping',
#  'heart-warming',
#  'heartbreaking',
#  'heartening',
#  'hilarious',
#  'humorous',
#  'hungry',
#  'impressive',
#  'infuriating',
#  'insulting',
#  'interested',
#  'intimidated',
#  'intimidating',
#  'intriguing',
#  'invigorating',
#  'irksome',
#  'irritated',
#  'irritating',
#  'jaw-dropping',
#  'jolly',
#  'loath',
#  'maddening',
#  'mind-boggling',
#  'mind-numbing',
#  'mortifying',
#  'mystifying',
#  'nerve-racking',
#  'nervous',
#  'nettled',
#  'nice',
#  'offensive',
#  'pacifying',
#  'pathetic',
#  'penitent',
#  'perplexing',
#  'pitiful',
#  'placating',
#  'pleasant',
#  'pleasing',
#  'pleasurable',
#  'poignant',
#  'raring',
#  'reassuring',
#  'relaxing',
#  'reluctant',
#  'remorseful',
#  'remorseless',
#  'repellent',
#  'repentant',
#  'reprehensible',
#  'reproachful',
#  'revolting',
#  'rich',
#  'rousing',
#  'rueful',
#  'sad',
#  'saddening',
#  'satisfied',
#  'satisfying',
#  'scary',
#  'scornful',
#  'shocking',
#  'sickening',
#  'side-splitting',
#  'sobering',
#  'solemn',
#  'soothing',
#  'sorry',
#  'spine-chilling',
#  'spine-tingling',
#  'spoiling',
#  'startling',
#  'stimulating',
#  'stinging',
#  'stirring',
#  'stressful',
#  'striking',
#  'stupefying',
#  'surprising',
#  'suspenseful',
#  'taken',
#  'tear-jerking',
#  'tedious',
#  'terrifying',
#  'thirsty',
#  'thorny',
#  'thrilling',
#  'tiresome',
#  'tiring',
#  'tormenting',
#  'touching',
#  'traumatic',
#  'traumatising',
#  'troublesome',
#  'troubling',
#  'uncritical',
#  'unexciting',
#  'unfazed',
#  'unfulfilling',
#  'unfunny',
#  'unnerving',
#  'unpleasant',
#  'unpleasing',
#  'unrepentant',
#  'unsettling',
#  'uplifting',
#  'upset',
#  'upsetting',
#  'vexatious',
#  'vexing',
#  'white-knuckle',
#  'worked up',
#  'worried',
#  'worrisome',
#  'worrying'}

# %% [markdown]
# The right way to add adjectives using FN.

# %%
feeling_frames = "Judgment Contrition Experiencer_focus Desiring Stimulus_focus".split()
all_lexes =  {lex for frame in feeling_frames for lex in list(fn.frame(frame).lexUnit.keys())}
adj_yield = {lex[:-2] for lex in all_lexes if lex.endswith(".a")}
noun_yield = {lex[:-2] for lex in all_lexes if lex.endswith(".n")}
verb_yield = {lex[:-2] for lex in all_lexes if lex.endswith(".v")}
len(adj_yield),len(noun_yield),len(verb_yield)
# Out:
# (221, 74, 67)

# %%
noun_set = {n[:-2] for n in noun_sample}

# %%
len(noun_sample),len(noun_yield.intersection(noun_set))
# Out:
# (445, 29)

# %%
len(noun_set)
# Out:
# 424

# %%
len(noun_yield.union(noun_set))
# Out:
# 469

# %% [markdown]
# What Framenet added:

# %%
(noun_yield - noun_set)
# Out:
# {'accolade',
#  'adoration',
#  'appreciation',
#  'aspiration',
#  'blame',
#  'charm [count]',
#  'charm [mass]',
#  'color',
#  'contrition',
#  'damnation',
#  'desperation',
#  'detestation',
#  'disdain',
#  'disrespect',
#  'esteem',
#  'exaltation',
#  'fault',
#  'hatred',
#  'hunger',
#  'impulse',
#  'loathing',
#  'lust',
#  'mockery',
#  'penitence',
#  'pity',
#  'recreation',
#  'regret',
#  'relaxation',
#  'relish',
#  'remorse',
#  'reproach',
#  'respect',
#  'rest',
#  'reverence',
#  'scorn',
#  'solace',
#  'stigma',
#  'stricture',
#  'thirst',
#  'vexation',
#  'vilification',
#  'wants',
#  'will',
#  'yearning',
#  'yen'}

# %%
len(adj_yield_merged),len(adj_yield_merged|adj_yield)
# Out:
# (2444, 2524)

# %% [markdown]
# What Framenet added (with what is sure an incomplete list of relevant frames)

# %%
adj_yield-adj_yield_merged
# Out:
# {'admiring',
#  'agreeable',
#  'baffling',
#  'bewildering',
#  'blood-curdling',
#  'breathtaking',
#  'calming',
#  'charming',
#  'critical',
#  'derisive',
#  'disagreeable',
#  'discomfiting',
#  'discomforting',
#  'disillusioning',
#  'disorientating',
#  'droll',
#  'earth-shattering',
#  'electrifying',
#  'embittering',
#  'empty',
#  'enraging',
#  'entertaining',
#  'fazed',
#  'fed up',
#  'formidable',
#  'fulfilling',
#  'full',
#  'ghastly',
#  'hair-raising',
#  'heart-rending',
#  'heart-stopping',
#  'heart-warming',
#  'impressive',
#  'intriguing',
#  'invigorating',
#  'jaw-dropping',
#  'mind-boggling',
#  'mind-numbing',
#  'mystifying',
#  'nerve-racking',
#  'nice',
#  'pacifying',
#  'placating',
#  'reassuring',
#  'reluctant',
#  'reprehensible',
#  'reproachful',
#  'rich',
#  'saddening',
#  'satisfied',
#  'side-splitting',
#  'sobering',
#  'soothing',
#  'spine-chilling',
#  'spine-tingling',
#  'spoiling',
#  'startling',
#  'stinging',
#  'stressful',
#  'striking',
#  'taken',
#  'tear-jerking',
#  'thorny',
#  'thrilling',
#  'tiring',
#  'tormenting',
#  'traumatic',
#  'traumatising',
#  'troublesome',
#  'uncritical',
#  'unexciting',
#  'unfazed',
#  'unfulfilling',
#  'unfunny',
#  'unnerving',
#  'unrepentant',
#  'unsettling',
#  'uplifting',
#  'white-knuckle',
#  'worked up'}

# %%
verb_yield
# Out:
# {'abhor',
#  'abominate',
#  'accuse',
#  'ache',
#  'admire',
#  'adore',
#  'applaud',
#  'appreciate',
#  'approve',
#  'aspire',
#  'blame',
#  'boo',
#  'care',
#  'covet',
#  'crave',
#  'deify',
#  'delight',
#  'deplore',
#  'desire',
#  'despair',
#  'despise',
#  'detest',
#  'disapprove',
#  'disdain',
#  'dislike',
#  'dread',
#  'envy',
#  'esteem',
#  'exalt',
#  'fancy',
#  'fault',
#  'fear',
#  'feel like',
#  'grieve',
#  'hanker',
#  'hate',
#  'hope',
#  'hunger',
#  'itch',
#  'like',
#  'loathe',
#  'long',
#  'love',
#  'lust',
#  'mock',
#  'mourn',
#  'pine',
#  'pity',
#  'prize',
#  'regret',
#  'repent',
#  'resent',
#  'respect',
#  'revere',
#  'rue',
#  'scorn',
#  'set store',
#  'stigmatize',
#  'strike a chord',
#  'thirst',
#  'value',
#  'want',
#  'will',
#  'wish',
#  'wish (that)',
#  'yearn',
#  'yen'}

# %%
def make_noun2related_verb_dict():
    noun2related_verb_dict = defaultdict(set)
      
    for ss in feeling_nouns:
        #for ss in [wn.synset('happiness.n.01')]:
        nm = ss.name()
        for ln in ss.lemma_names():
            #print(nm, ln,file=ofh,end="\n   ")
            for rel_l in get_related_lemmas(ln,"n","v"):
                #print(rel_l.name(),file=ofh,end=" ")
                noun2related_verb_dict[nm].add(rel_l)
            #print("\n",end="",file=ofh)
        # Guarantees at least an empoty set entry for ln
        noun2related_verb_dict[nm]
    return noun2related_verb_dict

noun2related_verb_dict = make_noun2related_verb_dict()

# %%
verb_yield22 = get_dict_yield(noun2related_verb_dict)
len(verb_yield22)
verb_set = {v.name() for v in verb_yield22}

# %%
len(verb_set)
# Out:
# 2017

# %% [markdown]
# Only 12 verbs were added:

# %% [markdown]
# The multi word expressions *feel like*, *strike a chord*, *set store*  are the best.

# %%
verb_yield  - verb_set
# Out:
# {'adore',
#  'applaud',
#  'boo',
#  'deify',
#  'deplore',
#  'fault',
#  'feel like',
#  'mock',
#  'set store',
#  'stigmatize',
#  'strike a chord',
#  'wish (that)'}

# %%
fer = fn.lus("stream")[1].frame.frameRelations[1]
fer.keys()
# Out:
# dict_keys(['subID', 'supID', 'subFrameName', 'superFrameName', 'ID', '_type', 'feRelations', 'type', 'superFrame', 'Neutral', 'subFrame', 'Perspectivized'])

# %%
fer['subFrameName'],fer['superFrameName'],fer["Perspectivized"],fer["Neutral"]
# Out:
# ('Quantified_mass',
#  'Measure_scenario',
#  frame (189): Quantified_mass
#
#  [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Quantified_mass.xml
#
#  [definition]
#    This frame contains transparent nouns (and some adjectives)
#    denoting quantities of a Mass or of Individuals. As opposed to
#    aggregate words such as group, set, these Quantity do not have a
#    status as Wholes on their own.   'He found them in the deluge of
#    papers on his desk.'  Initially, at least, we have annotated both
#    Quantity of Masses and of Individuals in this frame, though we
#    may split the frame along these lines later on.
#  [semTypes] 0 semantic types
#
#  [frameRelations] 2 frame relations
#    <MainEntry=Quantified_mass -- See_also -> ReferringEntry=Quantity>
#    <Neutral=Measure_scenario -- Perspective_on -> Perspectivized=Quantified_mass>
#
#  [lexUnit] 58 lexical units
#    a bit.n (13797), a few.art (13370), a little.n (14733), a lot.n
#    (13232), abundance.n (3333), all.a (13747), amount.n (3381),
#    any.a (13745), avalanche.n (3836), billions.n (3330), both.a
#    (14734), deal.n (17269), degree.n (3420), deluge.n (3837), dose.n
#    (14165), dozens.n (3331), fair.a (15420), few.a (13369), few.n
#    (13276), flood.n (3839), handful.n (11730), heap.n (3321),
#    hundreds.n (3327), load.n (3322), many.a (13746), many.n (13277),
#    mass.n (3325), measure.n (3369), millions.n (3329), mite.n
#    (3324), modicum.n (3323), mountain.n (11729), multiple.a (13874),
#    myriad.n (3335), no.a (13869), number.n (3338), numerous.a
#    (13751), oodles.n (3318), ounce.n (3342), pile.n (3319), pinch.n
#    (3339), plethora.n (3336), quantity.n (3337), raft.n (7451),
#    scads.n (3326), scores.n (3419), several.a (13368), several.n
#    (13339), shitload.n (3332), smattering.n (15231), stream.n
#    (3841), thousands.n (3328), ton.n (3320), torrent.n (3838),
#    touch.n (3343), trace.n (16191), trickle.n (3840), wave.n (3842)
#
#  [FE] 5 frame elements
#              Core: Individuals (1552), Mass (1551), Quantity (1550)
#        Peripheral: Degree (11951), Q_prop (1553)
#
#  [FEcoreSets] 1 frame element core sets
#    Mass, Individuals,
#  frame (1687): Measure_scenario
#
#  [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Measure_scenario.xml
#
#  [definition]
#    An Entity has a particular Value for an Attribute which may be
#    described in several different ways, including: '' Degree of
#    deviation from the Value expected for the kind of Entity seen in
#    a particular instance, or in comparison to some other explicit
#    comparison set. '' Absolute quantification in terms of the number
#    of Counts of a particular Unit which equal the Value for the
#    Attribute.
#  [semTypes] 1 semantic types
#    Non-Lexical Frame(16)
#
#  [frameRelations] 5 frame relations
#    <Parent=Measure_scenario -- Inheritance -> Child=Duration_scenario>
#    <Neutral=Measure_scenario -- Perspective_on -> Perspectivized=Dimension>
#    <Neutral=Measure_scenario -- Perspective_on -> Perspectivized=Measurable_attributes>
#    <Neutral=Measure_scenario -- Perspective_on -> Perspectivized=Measures>
#    <Neutral=Measure_scenario -- Perspective_on -> Perspectivized=Quantified_mass>
#
#  [lexUnit] 0 lexical units
#
#
#  [FE] 8 frame elements
#              Core: Attribute (9691), Count (9698), Degree (9693), Entity (9690), Unit (9697), Value (9692)
#    Extra-Thematic: Circumstances (9695), Time (9694)
#
#  [FEcoreSets] 0 frame element core sets
#    )

# %%
#fn.lus("stream.n")[1].frame.keys()
#dict_keys(['cBy', 'cDate', 'name', 'ID', '_type', 'definition', 'definitionMarkup', 'FE', 
#'FEcoreSets', 'lexUnit', 'semTypes', 'frameRelations', 'URL'])
qtfd_mass = fn.lus("stream.n")[1].frame
qtfd_mass["frameRelations"]
# Out:
# [<MainEntry=Quantified_mass -- See_also -> ReferringEntry=Quantity>, <Neutral=Measure_scenario -- Perspective_on -> Perspectivized=Quantified_mass>]

# %% [markdown]
# ### All frames

# %%
all_frames = fn.frames()

# %% [markdown]
# FrameNet 1.7

# %%
len(all_frames)
# Out:
# 1221

# %% [markdown]
# ## Lexicon

# %% [markdown]
# A lemma is a sense form pair as in WordNet, but a sense here means an assignment of roles
# within a frame.   In Framenet lemmas are called **lexUnits**.  So when we note that a lexical form, even
# a lexical form with an assigned part of speech, may have several frames, we are saying it has several lexical
# units (several senses) each with an assigned frame.
#
# Note there are 7,000 or so frames yielding only 10,000 or so lexunit names but there are actually 13,500 or so
# lex units.

# %%
vocab_list = [fn.lexUnit[lu] for fn in all_frames for lu in fn.lexUnit]
vocab = {lu.name for lu in vocab_list}

# %%
len(vocab_list)
# Out:
# 13572

# %%
vocab_list[0].name
# Out:
# 'abandon.v'

# %%
len(vocab)
# Out:
# 10462

# %%
import re
from collections import Counter,defaultdict

pos_part = (r"(\..*)$")
pos_part_re = re.compile(pos_part)
ctr = Counter(pos_part_re.findall(lu.name)[0] for lu in vocab)
vocab_dict = defaultdict(set)
for v in vocab:
    vocab_dict[pos_part_re.findall(v.name)[0][1:]].add(v.name)

# %%
vocab_dict.keys()
# Out:
# dict_keys(['v', 'n', 'a', 'prep', 'adv', 'idio', 'intj', 'num', 'c', 'scon', 'art', 'pron'])

# %%
vocab_dict["idio"]
# Out:
# {'ago.idio',
#  'be symbol.idio',
#  'do time.idio',
#  "dog (someone's) steps.idio",
#  'from to.idio',
#  'gain ground.idio',
#  'give job.idio',
#  'give notice.idio',
#  'give thought.idio',
#  'give try.idio',
#  "hold (one's) tongue.idio",
#  'in amount.idio',
#  'in terms.idio',
#  "jump (someone's) bones.idio",
#  "make (someone's) acquaintance.idio",
#  'make arrangements.idio',
#  'make history.idio',
#  'not a word.idio',
#  'on authority.idio',
#  'place weight.idio',
#  'point out.idio',
#  "pull (someone's) leg.idio",
#  "pull the wool over (someone's) eyes.idio",
#  'set ablaze.idio',
#  'set alight.idio',
#  "take (someone's) life.idio",
#  "tip (someone's) hand.idio",
#  'wait tables.idio',
#  'with on.idio'}

# %% [markdown]
# ## Corpus

# %%
vocab_list  = list(vocab)

# %%
lu0= vocab_list[0]
lu0.name
# Out:
# 'abandon.v'

# %%
lu0.frame.name
# Out:
# 'Abandonment'

# %%
lu0.exemplars
# Out:
# exemplar sentences for abandon.v in Abandonment:
#
# [0] The bank has abandoned all plans to finance roads or logging in Cameroon 's forests , in keeping with its ` stringent policy to protect the rights of indigenous people . "
# [1] Jamie Hill , prosecuting , said Stevenson and a friend took a Nova car from North Skelton and abandoned it in Nottingham .
# [2] She had seen no reason to abandon it when she came to Medewich two years ago , even though she might now have been able to afford a car .
# [3] Unfortunately , as a result of other priorities following the fall of France in June 1940 , the project was abandoned .
# [4] Leeds Education Authority has abandoned plans for ` drastic " cuts in travel subsidies for some Catholic students .
# [5] Moved to rectify this situation , he abandoned plans of working in the missionary field , and offered his services to the Netherlands Indies civil service .
# [6] The council later abandoned its plans to widen the highway and the reversion passed to the first defendants , who were not a highway authority .
# [7] It was Osman 's father Mohamed who had returned in his car for the clothes for Mrs Zamzam 's children just before Um Al-Farajh was finally abandoned by the Palestinian Arabs in 1948 .
# [8] Lola is waiting loyally , if not faithfully , for the lover , Michel ( Jacques Harden ) , who fathered her child and abandoned her seven years before .
# [9] A pistol was found in a garden at Ava Parade , off Ormeau Road , by police searching the area yesterday after a car was abandoned by two men .
# [10] That project will then be abandoned in favour of some other quickly completable component elsewhere , so that even relatively minor works can take years to finish .
# [11] What this argument suggests in Gandhi 's case is that he does not abandon his commitment to the principle of non-violence or qualify it in any way when he approves the destruction of life .
# [12] There were , ultimately , some findings that were distinctly incompatible with the theory and it was abandoned by its originators .
# [13] Ironically , Mrs Neil Lyndon has now revealed she was abandoned by her husband last year and only managed to receive child support for their six-year-old son by obtaining a court order .
# [14] She had been abandoned by her family , seen as an unbearable embarrassment and disgrace , " the princess told a conference of medical researchers seeking a cure for AIDS .
# [15] The female eider duck is abandoned by her drake just as soon as she starts incubating the eggs .
# [16] Whatever social and political abuses Herod might perpetrate , these were seen merely as symptoms of a much more profound dilemma -- the dilemma of a people who had been abandoned by their God .
# [17] A woman abandoned by her husband found her wage of new and crucial importance and looked to the union for support .
# [18] Another vehicle was abandoned at Great Victoria Street .
# [19] Ultimately , therefore , such academics abandon the rigorous analysis of the current content of criminal law and substitute criticism for legal exposition .
# [20] He also fathered a child by Marevna ( Maria Vorobiev ) and abandoned both women when he left for Mexico in 1921 .
# [21] Mr. Gonzalez and his colleagues , particularly the finance minister , Carlos Solchaga , are charged with having abandoned their socialist principles and with having become arrogant elitists who refuse even to go on television ( controlled by the state ) to face their accusers .
# [22] It would be sad for Mr. Gonzalez to abandon them to appease his foes .
# [23] Their supplies scarce , their harvest meager , and their spirit broken , they abandoned the fort in 1858 .

# %%
lu0.exemplars[3]
# Out:
# exemplar sentence (1489323):
# [corpID] 111
# [docID] 421
# [paragNo] 216
# [sentNo] 4
# [aPos] 35759420
#
# [LU] (14839) abandon.v in Abandonment
#
# [frame] (2031) Abandonment
#
# [annotationSet] 2 annotation sets
#
# [POS] 22 tags
#
# [POS_tagset] PENN
#
# [GF] 2 relations
#
# [PT] 2 phrases
#
# [text] + [Target] + [FE]
#
# Unfortunately , as a result of other priorities following the
#                 ----------------------------------------------
#                 Explanation
#
# fall of France in June 1940 , the project was abandoned .
# ---------------------------   -----------     *********
#                               Theme
#
#
#
# [Agent:CNI]

# %% [markdown]
# POS asignments are by character spans (to allow for lex units with white space):

# %%
lu0.exemplars[3].POS
# Out:
# [(0, 13, 'rb'),
#  (14, 15, ','),
#  (16, 18, 'in'),
#  (19, 20, 'dt'),
#  (21, 27, 'nn'),
#  (28, 30, 'in'),
#  (31, 36, 'jj'),
#  (37, 47, 'nns'),
#  (48, 57, 'VVG'),
#  (58, 61, 'dt'),
#  (62, 66, 'nn'),
#  (67, 69, 'in'),
#  (70, 76, 'NP'),
#  (77, 79, 'in'),
#  (80, 84, 'NP'),
#  (85, 89, 'cd'),
#  (90, 91, ','),
#  (92, 95, 'dt'),
#  (96, 103, 'nn'),
#  (104, 107, 'VBD'),
#  (108, 117, 'VVN'),
#  (118, 119, 'sent')]

# %%
lu0.exemplars[3].text[21:27]
# Out:
# 'result'

# %% [markdown]
# #### Iterating through all frames
#
# Plan for Framenet
#
# 1)  Iterate through frame list to find roots relative to all fers.  That is, they are not the parent in any fer.

# %% [markdown]
# For example, abandonment is not a root.  It has a parent Intentionally affect.

# %%
# Abandonmentframe fers
IntentionallyAffect = fn.frames_by_lemma(lu0.name)[0]["frameRelations"][0]["Parent"]
IntentionallyAffect
# Out:
# frame (230): Intentionally_affect
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Intentionally_affect.xml
#
# [definition]
#   An Agent causes a Patient to be affected, sometimes by a
#   particular Means or by use of an Instrument.  'A professional
#   dishwasher doesn't do dishes with a rag anymore!'
# [semTypes] 0 semantic types
#
# [frameRelations] 52 frame relations
#   <Parent=Intentionally_act -- Inheritance -> Child=Intentionally_affect>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Abandonment>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Adjusting>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Apply_heat>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Appointing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Arranging>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Arrest>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Attaching>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Attack>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Breaking_out_captive>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Cause_emotion>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Cause_to_amalgamate>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Cause_to_experience>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Cause_to_make_progress>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Cause_to_perceive>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Change_accessibility>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Change_operational_state>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Closure>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Cutting>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Detaching>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Education_teaching>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Extradition>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Firing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Gathering_up>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Grooming>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Hiding_objects>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Hiring>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Hit_target>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Immobilization>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Inhibit_movement>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Limiting>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Making_arrangements>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Manipulate_into_doing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Manipulate_into_shape>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Processing_materials>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Publishing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Rape>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Releasing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Reparation>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Replacing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Rescuing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Rewards_and_punishments>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Separating>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Short_selling>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Silencing>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Soaking>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Taking>
#   <Parent=Intentionally_affect -- Inheritance -> Child=Using>
#   <Parent=Transitive_action -- Inheritance -> Child=Intentionally_affect>
#   <Parent=Intentionally_affect -- Using -> Child=Arson>
#   <Parent=Intentionally_affect -- Using -> Child=Bungling>
#   <Parent=Intentionally_affect -- Using -> Child=Import_export_scenario>
#
# [lexUnit] 3 lexical units
#   do something (to/with).v (14334), do what (to/with).v (14336),
#   do.v (4348)
#
# [FE] 12 frame elements
#             Core: Agent (2000), Patient (2006)
# Core-Unexpressed: Event (1999)
#       Peripheral: Manner (2583), Means (1997), Place (2003), Purpose (2004), Time (2005)
#   Extra-Thematic: Degree (5363), Event_description (12000), Explanation (3668), Instrument (2001)
#
# [FEcoreSets] 1 frame element core sets
#   Patient, Event

# %% [markdown]
# IntentionallyAffect is not a root either.

# %%
IntentionallyAffect["frameRelations"][0]["Parent"]
# Out:
# frame (198): Intentionally_act
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Intentionally_act.xml
#
# [definition]
#   This is an abstract frame for acts performed by sentient beings.
#   It exists mostly for FE inheritance.  'I carried out the deed
#   easily .'
# [semTypes] 0 semantic types
#
# [frameRelations] 59 frame relations
#   <Parent=Event -- Inheritance -> Child=Intentionally_act>
#   <Parent=Intentionally_act -- Inheritance -> Child=Activity_finish>
#   <Parent=Intentionally_act -- Inheritance -> Child=Assemble>
#   <Parent=Intentionally_act -- Inheritance -> Child=Assistance>
#   <Parent=Intentionally_act -- Inheritance -> Child=Atonement>
#   <Parent=Intentionally_act -- Inheritance -> Child=Attempt>
#   <Parent=Intentionally_act -- Inheritance -> Child=Attempting_and_resolving_scenario>
#   <Parent=Intentionally_act -- Inheritance -> Child=Attending>
#   <Parent=Intentionally_act -- Inheritance -> Child=Avoiding>
#   <Parent=Intentionally_act -- Inheritance -> Child=Bail_decision>
#   <Parent=Intentionally_act -- Inheritance -> Child=Becoming_a_member>
#   <Parent=Intentionally_act -- Inheritance -> Child=Change_posture>
#   <Parent=Intentionally_act -- Inheritance -> Child=Change_tool>
#   <Parent=Intentionally_act -- Inheritance -> Child=Choosing>
#   <Parent=Intentionally_act -- Inheritance -> Child=Clemency>
#   <Parent=Intentionally_act -- Inheritance -> Child=Collaboration>
#   <Parent=Intentionally_act -- Inheritance -> Child=Confronting_problem>
#   <Parent=Intentionally_act -- Inheritance -> Child=Contacting>
#   <Parent=Intentionally_act -- Inheritance -> Child=Daring>
#   <Parent=Intentionally_act -- Inheritance -> Child=Examination>
#   <Parent=Intentionally_act -- Inheritance -> Child=Exchange>
#   <Parent=Intentionally_act -- Inheritance -> Child=Execute_plan>
#   <Parent=Intentionally_act -- Inheritance -> Child=Exercising>
#   <Parent=Intentionally_act -- Inheritance -> Child=Forming_relationships>
#   <Parent=Intentionally_act -- Inheritance -> Child=Front_for>
#   <Parent=Intentionally_act -- Inheritance -> Child=Get_a_job>
#   <Parent=Intentionally_act -- Inheritance -> Child=Giving>
#   <Parent=Intentionally_act -- Inheritance -> Child=Heralding>
#   <Parent=Intentionally_act -- Inheritance -> Child=Hostile_encounter>
#   <Parent=Intentionally_act -- Inheritance -> Child=Ingest_substance>
#   <Parent=Intentionally_act -- Inheritance -> Child=Intentionally_affect>
#   <Parent=Intentionally_act -- Inheritance -> Child=Intentionally_create>
#   <Parent=Intentionally_act -- Inheritance -> Child=Intercepting>
#   <Parent=Intentionally_act -- Inheritance -> Child=Legal_rulings>
#   <Parent=Intentionally_act -- Inheritance -> Child=Manipulation>
#   <Parent=Intentionally_act -- Inheritance -> Child=Military_operation>
#   <Parent=Intentionally_act -- Inheritance -> Child=Name_conferral>
#   <Parent=Intentionally_act -- Inheritance -> Child=Passing_off>
#   <Parent=Intentionally_act -- Inheritance -> Child=Perception_active>
#   <Parent=Intentionally_act -- Inheritance -> Child=Piracy>
#   <Parent=Intentionally_act -- Inheritance -> Child=Practice>
#   <Parent=Intentionally_act -- Inheritance -> Child=Quitting>
#   <Parent=Intentionally_act -- Inheritance -> Child=Resolve_problem>
#   <Parent=Intentionally_act -- Inheritance -> Child=Self_motion>
#   <Parent=Intentionally_act -- Inheritance -> Child=Visiting>
#   <Parent=Intentionally_act -- Inheritance -> Child=Working_a_post>
#   <Parent=Intentionally_act -- Using -> Child=Accomplishment>
#   <Parent=Intentionally_act -- Using -> Child=Assistance>
#   <Parent=Intentionally_act -- Using -> Child=Bungling>
#   <Parent=Intentionally_act -- Using -> Child=Competition>
#   <Parent=Intentionally_act -- Using -> Child=Conduct>
#   <Parent=Intentionally_act -- Using -> Child=Deciding>
#   <Parent=Intentionally_act -- Using -> Child=Experience_bodily_harm>
#   <Parent=Intentionally_act -- Using -> Child=Reason>
#   <Parent=Intentionally_act -- Using -> Child=Remembering_to_do>
#   <Parent=Intentionally_act -- Using -> Child=Responsibility>
#   <Parent=Intentionally_act -- Using -> Child=Rite>
#   <Parent=Intentionally_act -- Using -> Child=Subjective_influence>
#   <Parent=Intentionally_act -- Using -> Child=Waiting>
#
# [lexUnit] 17 lexical units
#   act.n (13488), act.v (10614), action.n (10611), activity.n
#   (10616), actor.n (14863), agent.n (14864), carry out.v (11705),
#   conduct.v (11736), deed.n (17271), do.v (10612), doing.n (10615),
#   engage.v (12777), execute.v (11839), measures.n (12778), move.n
#   (14600), perform.v (10912), step.n (10613)
#
# [FE] 15 frame elements
#             Core: Agent (1610)
# Core-Unexpressed: Act (1609)
#       Peripheral: Manner (2574), Means (2573), Place (1613), Purpose (1614), Time (1616)
#   Extra-Thematic: Apparent_conclusion (16874), Domain (7982), Event_description (12001), Explanation (11991), Frequency (7983), Particular_iteration (11863), Period_of_iterations (11078), Result (11079)
#
# [FEcoreSets] 0 frame element core sets

# %% [markdown]
# And so on:

# %% [markdown]
# The complete set of frame relation types.

# %%
[fr_rel.name for fr_rel in (fn.frame_relation_types())]
# Out:
# ['Causative_of',
#  'Inchoative_of',
#  'Inheritance',
#  'Metaphor',
#  'Perspective_on',
#  'Precedes',
#  'ReFraming_Mapping',
#  'See_also',
#  'Subframe',
#  'Using']

# %% [markdown]
# The next two frame relation types capture the State -> Inchoative -> Causative
# relation (cool.a, cool.v.intr, cool.v.tr).

# %%
[fr_rel for fr_rel in fn.frame_relations() if fr_rel.type.name == "Causative_of"][:5]
# Out:
# [<Causative=Apply_heat -- Causative_of -> Inchoative/state=Absorb_heat>,
#  <Causative=Attaching -- Causative_of -> Inchoative/state=Becoming_attached>,
#  <Causative=Cause_bodily_experience -- Causative_of -> Inchoative/state=Perception_body>,
#  <Causative=Cause_change -- Causative_of -> Inchoative/state=Undergo_change>,
#  <Causative=Cause_change_of_consistency -- Causative_of -> Inchoative/state=Change_of_consistency>]

# %%
[fr_rel for fr_rel in fn.frame_relations() if fr_rel.type.name == "Inchoative_of"][:5]
# Out:
# [<Inchoative=Becoming_a_member -- Inchoative_of -> Stative=Membership>,
#  <Inchoative=Becoming_attached -- Inchoative_of -> Stative=Being_attached>,
#  <Inchoative=Becoming_detached -- Inchoative_of -> Stative=Being_detached>,
#  <Inchoative=Becoming_dry -- Inchoative_of -> Stative=Being_dry>,
#  <Inchoative=Cause_change_of_phase -- Inchoative_of -> Stative=Substance_by_phase>]

# %%
[fr_rel for fr_rel in fn.frame_relations() if fr_rel.type.name == "ReFraming_Mapping"][:5]
# Out:
# [<Source=Activity_finish -- ReFraming_Mapping -> Target=Activity_stop>,
#  <Source=Activity_start -- ReFraming_Mapping -> Target=Cause_to_start>,
#  <Source=Adding_up -- ReFraming_Mapping -> Target=Amounting_to>,
#  <Source=Appeal -- ReFraming_Mapping -> Target=Entering_of_plea>,
#  <Source=Apply_heat -- ReFraming_Mapping -> Target=Soaking>]

# %%
[fr_rel for fr_rel in fn.frame_relations() if fr_rel.type.name == "Precedes"][:5]
# Out:
# [<Earlier=Achieving_first -- Precedes -> Later=Product_development>,
#  <Earlier=Activity_finish -- Precedes -> Later=Activity_done_state>,
#  <Earlier=Activity_ongoing -- Precedes -> Later=Activity_finish>,
#  <Earlier=Activity_ongoing -- Precedes -> Later=Activity_pause>,
#  <Earlier=Activity_ongoing -- Precedes -> Later=Activity_stop>]

# %%
[fr_rel for fr_rel in fn.frame_relations() if fr_rel.type.name == "See_also"][:5]
# Out:
# [<MainEntry=Appellations -- See_also -> ReferringEntry=Kinship>,
#  <MainEntry=Appellations -- See_also -> ReferringEntry=Leadership>,
#  <MainEntry=Apply_heat -- See_also -> ReferringEntry=Cooking_creation>,
#  <MainEntry=Attempt_means -- See_also -> ReferringEntry=Attempt>,
#  <MainEntry=Awareness -- See_also -> ReferringEntry=Certainty>]

# %%
from nltk.corpus import framenet as fn
#all_frames = fn.frames()
vocab_list = [fn.lexUnit[lu] for fn in fn.frames() for lu in fn.lexUnit]
#vocab = {lu.name for lu in vocab_list}
event = fn.frame("Event")

def parent_closure (frame,n=0,bd=100):
    res = [frame.name]
    for fer in frame.frameRelations:
        parent = fer.get("Parent", None)
        if parent is None:
            return res
        elif parent.name == frame.name:
            return res
        elif n > bd:
            return res
        else:
            res.extend(parent_closure(parent,n+1))
    return res

def is_root_old(frame):
    #parents = [fer.get("Parent", None) for fer in frame.frameRelations if fer.get("Parent", None).name != frame]
    parents=[]
    for fr_rel in frame.frameRelations:
        p  = fr_rel.get("Parent", None)
        if p is not None:
            # It IS a parent-child type fr_rel
            p_name = p.name
            if p_name != frame.name:
                # It's the child
                parents.append(p_name)
    if parents:
        return False
    else:
        return True
    
def is_root (frame):
    is_child = False
    for fr_rel in frame.frameRelations:
        
        p  = fr_rel.get("Child", None)
        if p is not None and p.name == frame.name:
            is_child=True
    if is_child:
        return False
    else:
        return True
    
    
def lex2colexes (lex,result=None,allowed=None):
    if result is None:
        result = dict()
    frames = fn.frames_by_lemma(lex)
    if allowed is not None:
        frames = [frame for frame in frames if frame.name in allowed]
    for frame in frames:
        result[frame.name] = list(frame.lexUnit.keys())
    return result

# %%
lu0=vocab_list[0]
v_frame = lu0.frame
#v_frame = fn.frame("Transitive_action")
cl = parent_closure (v_frame)

# %%
cl
# Out:
# ['Abandonment', 'Intentionally_affect', 'Intentionally_act', 'Event']

# %%
v_frame
# Out:
# frame (2031): Abandonment
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Abandonment.xml
#
# [definition]
#   An Agent leaves behind a Theme effectively rendering it no longer
#   within their control or of the normal security as one's property.
#   'Carolyn abandoned her car and jumped on a red double decker
#   bus.'  'Perhaps he left the key in the ignition'  'Abandonment of
#   a child is considered to be a serious crime in many
#   jurisdictions.'  There are also metaphorically used examples:
#   'She left her old ways behind .'
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Intentionally_affect -- Inheritance -> Child=Abandonment>
#
# [lexUnit] 5 lexical units
#   abandon.v (14839), abandoned.a (14843), abandonment.n (14842),
#   forget.v (15317), leave.v (14841)
#
# [FE] 12 frame elements
#             Core: Agent (12338), Theme (12339)
#       Peripheral: Degree (14482), Duration (12343), Manner (12342), Means (15920), Place (12340), Purpose (15921), Time (12341)
#   Extra-Thematic: Depictive (12862), Event_description (15962), Explanation (12861)
#
# [FEcoreSets] 0 frame element core sets

# %%
#roots = [rt for fm in fn.frames() for rt in parent_closure(fm)[-1:]]
roots = [fm.name for fm in fn.frames() if is_root(fm)]

# %%
len(set(roots))
# Out:
# 201

# %%
#'Awareness_situation',
#roots[50:100]
# "Event",'Experiencer_focus', 'Importance',
#roots[50:100]
# 'Mental_activity','Mental_stimulus_stimulus_focus', "Possession", "Opinion"
#roots[100:150]
# 'Reciprocality','Stimulus_focus','Subjective_temperature','Undergoing_scenario'
#roots[150:201]
def get_lexes_from_frame_list (frame_list):
    return {frame_name: get_lexes_from_frame(fn.frame(frame_name))}

def get_lexes_from_frame_old(frame,seen=None,n=0):
    
    print(frame.name)
    if seen is None:
        seen=[]
    #if frame.name in seen:
    #    return []
    if n > 2:
        return []
    res = []
    for (lu_name, lu) in frame.lexUnit.items():
        res.append(lu_name)
        #res.extend([frame2 for fr_rel in frame.frameRelations 
        #           for frame2 in get_lexes_from_frame(fr_rel.Child)])
        for fr_rel in frame.frameRelations:
            if "Child" in fr_rel and fr_rel["Parent"].name not in seen and fr_rel["Child"].name not in seen:
                new_seen = seen + [frame.name]
                res.extend(get_lexes_from_frame(fr_rel.Child,seen=new_seen,n=n+1))
    return res


def get_lexes_from_frame(frame,res=None,seen=None,n=0):
    
    #print(n,frame.name)
    if res is None:
        res =[]
    if seen is None:
        seen = []
    seen.append(frame.name)
    #if n > 2:
    #    return res
    for (lu_name, lu) in frame.lexUnit.items():
        res.append(lu_name)
        #res.extend([frame2 for fr_rel in frame.frameRelations 
        #           for frame2 in get_lexes_from_frame(fr_rel.Child)])
        #print("Len fr_rels", len(frame.frameRelations))
    for fr_rel in frame.frameRelations:
        if "Child" in fr_rel and fr_rel["Child"].name not in seen:
            res = get_lexes_from_frame(frame=fr_rel.Child,res=res,seen=seen,n=n+1)
    return res
        
def find_path_from_frame(frame,target, path = None, seen=None,n=0):
    """
    Find parent-child loinks from frame to target lu:
    Example:
     
     find_path_from_frame(fn.frame("Experiencer_focus"), "enemy.n")
    """

    if seen is None:
        seen = []
    if path is None:
        path = []
    seen.append(frame.name)
    
    for (lu_name, lu) in frame.lexUnit.items():
        if lu_name == target:
            return ' '.join(path + [frame.name])
    for fr_rel in frame.frameRelations:
        if "Child" in fr_rel and fr_rel["Child"].name not in seen:
            new_path = path + [frame.name,fr_rel.type.name]
            res = find_path_from_frame(frame=fr_rel.Child,target=target,path=new_path,seen=seen,n=n+1)
            if res is not None:
                return res

# %%
Experiencer_focus_words = get_lexes_from_frame(fn.frame('Experiencer_focus'),res=None,n=0)
print(len(Experiencer_focus_words))
Experiencer_focus_words = set(Experiencer_focus_words)
# Out:
# 455

# %%
Experiencer_focus_words
# Out:
# {'abhor.v',
#  'abhorrence.n',
#  'ablution.n',
#  'abominate.v',
#  'absorbed.a',
#  'ache.v',
#  'acquiesce.v',
#  'adoration.n',
#  'adore.v',
#  'affray.n',
#  'against.prep',
#  'agape.a',
#  'aim.n',
#  'aim.v',
#  'airman.n',
#  'altercation.n',
#  'amazing.a',
#  'ambition.n',
#  'antipathy.n',
#  'appalling.a',
#  'apprehensive.a',
#  'aspiration.n',
#  'aspire.v',
#  'astonishing.a',
#  'astounding.a',
#  'atrocious.a',
#  'attack.v',
#  'average.a',
#  'awesome.a',
#  'awful.a',
#  'back.v',
#  'backing.n',
#  'bad idea.n',
#  'bad.a',
#  'bathe.v',
#  'battle.n',
#  'battle.v',
#  'be supposed to.v',
#  'bear.v',
#  'beautiful.a',
#  'believe (in).v',
#  'belligerent.n',
#  'bent.a',
#  'best thing since sliced bread.n',
#  'bias.n',
#  'bias.v',
#  'biased.a',
#  'bout.n',
#  'brawl.n',
#  'brawl.v',
#  'brush [hair].v',
#  'brush [teeth].v',
#  'bw.n',
#  'calm.a',
#  'capitulate.v',
#  'captivated.a',
#  'care.v',
#  'cave in.v',
#  'cave.v',
#  'clash.n',
#  'clash.v',
#  'cleanse.v',
#  'comb.v',
#  'combat.n',
#  'combatant.n',
#  'comfort.n',
#  'commando.n',
#  'common.a',
#  'compassion.n',
#  'compromise.v',
#  'conflict.n',
#  'confront.v',
#  'confrontation.n',
#  'control.v',
#  'cool.a',
#  'count.v',
#  'covet.v',
#  'covetous.a',
#  'crap.n',
#  'crappy.a',
#  'crave.v',
#  'craving.n',
#  'curious.a',
#  'cw.n',
#  'decent.a',
#  'delight.v',
#  'demonstrate.v',
#  'demonstration.n',
#  'depend.v',
#  'dependence.n',
#  'dependency.n',
#  'desirable.a',
#  'desire.n',
#  'desire.v',
#  'desired.a',
#  'desirous.a',
#  'despair.v',
#  'desperation.n',
#  'despise.v',
#  'determined.a',
#  'detest.v',
#  'detestation.n',
#  'discomfort.n',
#  'dislike.n',
#  'dislike.v',
#  'disprefer.v',
#  'dissatisfied.a',
#  'do.v',
#  'donnybrook.n',
#  'dread.v',
#  'dreadful.a',
#  'duel.n',
#  'duel.v',
#  'dust-up.n',
#  'dying.a',
#  'eager.a',
#  'easy.a',
#  'elegant.a',
#  'elude.v',
#  'empathy.n',
#  'endorse.v',
#  'endure.v',
#  'enemy.n',
#  'engage.v',
#  'engagement.n',
#  'engrossed.a',
#  'enthralled.a',
#  'envy.n',
#  'envy.v',
#  'escape.v',
#  'evade.v',
#  'excellence.n',
#  'excellent.a',
#  'execrable.a',
#  'extraordinary.a',
#  'fabulous.a',
#  'facial.n',
#  'fair.a',
#  'fancy.v',
#  'fantastic.a',
#  'fare.v',
#  'fascinated.a',
#  'favor.v',
#  'fazed.a',
#  'fear.v',
#  'fed up.a',
#  'feel like.v',
#  'feverish.a',
#  'feverishly.adv',
#  'fight.n',
#  'fight.v',
#  'fighter.n',
#  'fighting.n',
#  'file.v',
#  'fine.a',
#  'fire fighting.n',
#  'firefight.n',
#  'first-rate.a',
#  'fistfight.n',
#  'floss.v',
#  'flourish.v',
#  'fold [to demands].v',
#  'fond.a',
#  'for.prep',
#  'forget.v',
#  'fracas.n',
#  'fray.n',
#  'free-for-all.n',
#  'friendly.a',
#  'friendly.n',
#  'fulfilled.a',
#  'fulfillment.n',
#  'function.n',
#  'gain ground.idio',
#  'garbage.n',
#  'gem.n',
#  'give in.v',
#  'give way.v',
#  'goal.n',
#  'gold.n',
#  'good idea.n',
#  'good.a',
#  'great.a',
#  'grieve.v',
#  'groom.v',
#  'guerrilla.n',
#  'gunfight.n',
#  'gunner.n',
#  'handsome.a',
#  'hanker.v',
#  'hankering.n',
#  'happily.adv',
#  'hate.v',
#  'hatred.n',
#  'have to.v',
#  'hideous.a',
#  'hope.n',
#  'hope.v',
#  'horrible.a',
#  'hostile.a',
#  'hostile.n',
#  'hostility.n',
#  'hot.a',
#  'humble.a',
#  'hunger.n',
#  'hunger.v',
#  'hungry.a',
#  'idyllic.a',
#  'impartial.a',
#  'impartiality.n',
#  'impulse.n',
#  'in demand.a',
#  'in favor.prep',
#  'in hopes of.prep',
#  'in order.adv',
#  'in the hope of.prep',
#  'in.a',
#  'incredible.a',
#  'infantryman.n',
#  'infatuated.a',
#  'inferior.a',
#  'infighting.n',
#  'intend.v',
#  'intent.a',
#  'intention.n',
#  'interested.a',
#  'intimidated.a',
#  'irritated.a',
#  'itch.v',
#  'junk.n',
#  'killer.a',
#  'lame.a',
#  'lamer.n',
#  'languish.v',
#  'lave.v',
#  'left.a',
#  'like.v',
#  'live.v',
#  'loath.a',
#  'loathe.v',
#  'loathing.n',
#  'long.v',
#  'longing.n',
#  'look.n',
#  'lost (in).a',
#  'love.v',
#  'lovely.a',
#  'low.a',
#  'lust.n',
#  'lust.v',
#  'magnificent.a',
#  'manicure.n',
#  'manicure.v',
#  'marine.n',
#  'marvellous.a',
#  'mean.v',
#  'mediocre.a',
#  'melee.n',
#  'militant.n',
#  'miserable.a',
#  'moisturize.v',
#  'mourn.v',
#  'nasty.a',
#  'need.n',
#  'need.v',
#  'nervous.a',
#  'nettled.a',
#  'neutral.a',
#  'neutrality.n',
#  'object.n',
#  'objective.n',
#  'okay.a',
#  'opponent.n',
#  'oppose.v',
#  'opposition [act].n',
#  'opposition [entity].n',
#  'order.n',
#  'ought to.v',
#  'outstanding.a',
#  'part.n',
#  'partial.a',
#  'partiality.n',
#  'pathetic.a',
#  'pedestrian.a',
#  'pedicure.n',
#  'pine.v',
#  'pitiful.a',
#  'pity.n',
#  'pity.v',
#  'plait.v',
#  'plan.n',
#  'plan.v',
#  'pleasure.n',
#  'plebeian.a',
#  'pluck.v',
#  'poor.a',
#  'popular.a',
#  'prefer.v',
#  'prejudge.v',
#  'prejudice.n',
#  'prejudiced.a',
#  'pro.adv',
#  'program.n',
#  'project.n',
#  'proletarian.a',
#  'prosper.v',
#  'prosperity.n',
#  'protest.n',
#  'protest.v',
#  'protester.n',
#  'purpose.n',
#  'raring.a',
#  'regret.n',
#  'regret.v',
#  'relent.v',
#  'reliance.n',
#  'relish.n',
#  'reluctant.a',
#  'rely.v',
#  'remain.v',
#  'remainder.n',
#  'remember.v',
#  'require.v',
#  'resent.v',
#  'resentment.n',
#  'rock.v',
#  'rotten.a',
#  'row.n',
#  'rue.v',
#  'rueful.a',
#  'sacrifice.v',
#  'sailor.n',
#  'satisfaction.n',
#  'satisfied.a',
#  'scheme.n',
#  'scuffle.n',
#  'scuffle.v',
#  'second-rate.a',
#  'sensational.a',
#  'service member.n',
#  'shampoo.v',
#  'shave.v',
#  'shit.n',
#  'shitty.a',
#  'shootout.n',
#  'should.v',
#  'showdown.n',
#  'shower.v',
#  'side.n',
#  'side.v',
#  'signaller.n',
#  'skirmish.n',
#  'skirmish.v',
#  'slump.n',
#  'smart.a',
#  'smitten.a',
#  'sniper.n',
#  'so-so.a',
#  'soap.v',
#  'solace.n',
#  'soldier.n',
#  'sound.n',
#  'spat.n',
#  'splendid.a',
#  'spoiling.a',
#  'squabble.n',
#  'stalemate.n',
#  'stand.v',
#  'standoff.n',
#  'standout.n',
#  'strife.n',
#  'struggle.n',
#  'struggle.v',
#  'stupendous.a',
#  'style.n',
#  'submit.v',
#  'substandard.a',
#  'suck.v',
#  'super.a',
#  'superb.a',
#  'superlative.a',
#  'support.v',
#  'supporter.n',
#  'supportive.a',
#  'suspicious.a',
#  'sweet.a',
#  'tackle.v',
#  'taken.a',
#  'target.n',
#  'tasty.a',
#  'terrible.a',
#  'terrific.a',
#  'third-rate.a',
#  'thirst.n',
#  'thirst.v',
#  'thirsty.a',
#  'thrive.v',
#  'tiff.n',
#  'tip-top.a',
#  'tolerable.a',
#  'tolerant.a',
#  'tolerate.v',
#  'toleration.n',
#  'top-notch.a',
#  'tremendous.a',
#  'troop.n',
#  'tussle.n',
#  'ugly.a',
#  'uncool.a',
#  'unfazed.a',
#  'unfortunate.a',
#  'upper-class.a',
#  'upset.a',
#  'urge.n',
#  'use.n',
#  'vulgar.a',
#  'want.v',
#  'wants.n',
#  'war.n',
#  'war.v',
#  'warfare.n',
#  'wash.v',
#  'wax.v',
#  'well.adv',
#  'will.n',
#  'will.v',
#  'wish (that).v',
#  'wish.n',
#  'wish.v',
#  'wonderful.a',
#  'worked up.a',
#  'working-class.a',
#  'worried.a',
#  'worthless.a',
#  'wrangling.n',
#  'wrapped up (in).a',
#  'yearn.v',
#  'yearning.n',
#  'yen.n',
#  'yen.v',
#  'yield.v'}

# %% [markdown]
# Why is *enemy.n* in this list?  What does it have to do with experiencer focus predicates?

# %%
find_path_from_frame(fn.frame("Experiencer_focus"), "enemy.n", path = None, seen=None,n=0)
# Out:
# 'Experiencer_focus Using Desirability Inheritance Desirable_event Using Taking_sides Using Hostile_encounter Using Friendly_or_hostile'

# %%
fn.frame("Desirable_event").frameRelations[1]
# Out:
# <Parent=Desirable_event -- Using -> Child=Taking_sides>

# %%
fn.frame("Desirable_event")
# Out:
# frame (1383): Desirable_event
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Desirable_event.xml
#
# [definition]
#   A particular State_of_affairs is desirable.  The State_of_affairs
#   may be required to achieve a Purpose.  A set of Circumstances may
#   be specified under which the assessment of desirability holds.
#   'You should take the doses about 12 hours apart and at the same
#   time each day.' ' If the metal is seriously rusted or warped, it
#   should be repaired or replaced with a chimney top damper.' 'To
#   ensure that, you should have no CLASSPATH set.'
# [semTypes] 0 semantic types
#
# [frameRelations] 5 frame relations
#   <Parent=Desirability -- Inheritance -> Child=Desirable_event>
#   <Parent=Desirable_event -- Using -> Child=Taking_sides>
#   <Parent=Required_event -- Using -> Child=Desirable_event>
#   <Source=Required_event -- ReFraming_Mapping -> Target=Desirable_event>
#   <Neutral=Preferred_alternative_scenario -- Perspective_on -> Perspectivized=Desirable_event>
#
# [lexUnit] 6 lexical units
#   bad idea.n (11822), be supposed to.v (17416), good idea.n
#   (11823), have to.v (17415), ought to.v (11821), should.v (11820)
#
# [FE] 4 frame elements
#             Core: State_of_affairs (7756)
#       Peripheral: Degree (9674), Purpose (7758)
#   Extra-Thematic: Circumstances (7757)
#
# [FEcoreSets] 0 frame element core sets

# %%
fn.frame("Taking_sides")
# Out:
# frame (1306): Taking_sides
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Taking_sides.xml
#
# [definition]
#   A Cognizer has a relatively fixed positive or negative point of
#   view towards an Issue.  A Side in a debate concerning an Issue or
#   an Action of a Side may stand in for the Issue.  The Cognizer's
#   Degree of alignment may also be specified.  'In interviews , it
#   seems like everyone is completely against this expenditure .'
# [semTypes] 0 semantic types
#
# [frameRelations] 6 frame relations
#   <Parent=Desirable_event -- Using -> Child=Taking_sides>
#   <Parent=Opinion -- Using -> Child=Taking_sides>
#   <Parent=Taking_sides -- Using -> Child=Giving_in>
#   <Parent=Taking_sides -- Using -> Child=Hostile_encounter>
#   <Parent=Taking_sides -- Using -> Child=Partiality>
#   <Parent=Taking_sides -- Using -> Child=Protest>
#
# [lexUnit] 18 lexical units
#   against.prep (11499), back.v (13989), backing.n (14562), believe
#   (in).v (15794), endorse.v (13711), for.prep (11498), in
#   favor.prep (11505), opponent.n (13140), oppose.v (11496),
#   opposition [act].n (11504), opposition [entity].n (13389), part.n
#   (17329), pro.adv (11500), side.n (11503), side.v (11502),
#   support.v (11501), supporter.n (13141), supportive.a (11506)
#
# [FE] 12 frame elements
#             Core: Action (9155), Cognizer (7433), Issue (7434), Side (7435)
#       Peripheral: Degree (7436), Manner (10453), Place (11886), Time (8160)
#   Extra-Thematic: Concessive (10941), Descriptor (10443), Explanation (8161), Particular_iteration (10452)
#
# [FEcoreSets] 1 frame element core sets
#   Side, Issue, Action

# %% [markdown]
# The Step from *Taking_sides* to *Hostile_encounter* is the step that loses the Cognizer frame element:

# %%
#fn.lexUnit("enemy.n")
Friendly_or_hostile = fn.frames_by_lemma("enemy.n")[0].frameRelations[0].Parent
Friendly_or_hostile
# Out:
# frame (93): Hostile_encounter
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Hostile_encounter.xml
#
# [definition]
#   This frame consists of words that describe a hostile encounter
#   between opposing forces (Side_1 and Side_2, collectively
#   conceptualizable as Sides) over a disputed Issue and/or in order
#   to reach a specific  Purpose. '' 'He still wants to fight Mike
#   Tyson in about 8 months.'  'Dennis Andries's European
#   cruiserweight title clash against Akim Tafer of France in
#   Beausoleil last February has been voted as the EBU's fight of the
#   year.'
# [semTypes] 0 semantic types
#
# [frameRelations] 9 frame relations
#   <Parent=Hostile_encounter -- Inheritance -> Child=Fighting_activity>
#   <Parent=Intentionally_act -- Inheritance -> Child=Hostile_encounter>
#   <Parent=Hostile_encounter -- Using -> Child=Firefighting>
#   <Parent=Hostile_encounter -- Using -> Child=Friendly_or_hostile>
#   <Parent=Hostile_encounter -- Using -> Child=Irregular_combatants>
#   <Parent=Hostile_encounter -- Using -> Child=Member_of_military>
#   <Parent=Taking_sides -- Using -> Child=Hostile_encounter>
#   <Neutral=Hostile_encounter -- Perspective_on -> Perspectivized=Attack>
#   <Source=Hostile_encounter -- Metaphor -> Target=Firefighting>
#
# [lexUnit] 47 lexical units
#   altercation.n (1913), battle.n (1909), battle.v (1931), bout.n
#   (1920), brawl.n (1928), brawl.v (1935), bw.n (11623), clash.n
#   (1916), clash.v (1933), combat.n (1925), conflict.n (10638),
#   confront.v (1938), confrontation.n (1917), cw.n (11611), duel.n
#   (1914), duel.v (1932), dust-up.n (10917), engage.v (16741),
#   engagement.n (16742), fight.n (1910), fight.v (1930), fighting.n
#   (1919), firefight.n (10458), fistfight.n (10457), gunfight.n
#   (3803), hostility.n (1922), infighting.n (14981), row.n (1918),
#   scuffle.n (1911), scuffle.v (1937), shootout.n (3804), showdown.n
#   (3806), skirmish.n (1924), skirmish.v (1936), spat.n (1912),
#   squabble.n (1926), stalemate.n (1927), standoff.n (3805),
#   strife.n (1929), struggle.n (1921), struggle.v (14676), tiff.n
#   (5149), tussle.n (13315), war.n (1939), war.v (1940), warfare.n
#   (11600), wrangling.n (3807)
#
# [FE] 17 frame elements
#             Core: Issue (442), Purpose (443), Side_1 (439), Side_2 (440), Sides (441)
#       Peripheral: Degree (710), Duration (718), Instrument (1523), Manner (445), Means (444), Place (446), Time (447)
#   Extra-Thematic: Depictive (711), Explanation (1097), Internal_cause (1526), Particular_iteration (13320), Result (716)
#
# [FEcoreSets] 1 frame element core sets
#   Issue, Purpose

# %% [markdown]
# All this suggests teh frame relation based approach should give way to an fe-based
# approach.  Find expressive-related fes.  Fiund associated frames.  Just
# use the lexunits in that fra,e/  Dont do a recursive parent-to-child
# search to find the lex units associated with frames, because , as demonstrated in the discussion
# above, that introduces noise.

# %%
Stimulus_focus_words = get_lexes_from_frame(fn.frame('Stimulus_focus'),res=None,n=0)

# %%
len(Experiencer_focus_words)
# Out:
# 441

# %%
Experiencer_focus_words
# Out:
# {'abhor.v',
#  'abhorrence.n',
#  'ablution.n',
#  'abominate.v',
#  'absorbed.a',
#  'ache.v',
#  'acquiesce.v',
#  'adoration.n',
#  'adore.v',
#  'affray.n',
#  'against.prep',
#  'agape.a',
#  'aim.n',
#  'aim.v',
#  'airman.n',
#  'altercation.n',
#  'amazing.a',
#  'ambition.n',
#  'antipathy.n',
#  'appalling.a',
#  'apprehensive.a',
#  'aspiration.n',
#  'aspire.v',
#  'astonishing.a',
#  'astounding.a',
#  'atrocious.a',
#  'attack.v',
#  'average.a',
#  'awesome.a',
#  'awful.a',
#  'back.v',
#  'backing.n',
#  'bad idea.n',
#  'bad.a',
#  'bathe.v',
#  'battle.n',
#  'battle.v',
#  'be supposed to.v',
#  'bear.v',
#  'beautiful.a',
#  'believe (in).v',
#  'belligerent.n',
#  'bent.a',
#  'best thing since sliced bread.n',
#  'bias.n',
#  'bias.v',
#  'biased.a',
#  'bout.n',
#  'brawl.n',
#  'brawl.v',
#  'brush [hair].v',
#  'brush [teeth].v',
#  'bw.n',
#  'calm.a',
#  'capitulate.v',
#  'captivated.a',
#  'care.v',
#  'cave in.v',
#  'cave.v',
#  'clash.n',
#  'clash.v',
#  'cleanse.v',
#  'comb.v',
#  'combat.n',
#  'combatant.n',
#  'comfort.n',
#  'commando.n',
#  'common.a',
#  'compassion.n',
#  'compromise.v',
#  'conflict.n',
#  'confront.v',
#  'confrontation.n',
#  'control.v',
#  'cool.a',
#  'count.v',
#  'covet.v',
#  'covetous.a',
#  'crap.n',
#  'crappy.a',
#  'crave.v',
#  'craving.n',
#  'curious.a',
#  'cw.n',
#  'decent.a',
#  'delight.v',
#  'demonstrate.v',
#  'demonstration.n',
#  'depend.v',
#  'dependence.n',
#  'dependency.n',
#  'desirable.a',
#  'desire.n',
#  'desire.v',
#  'desired.a',
#  'desirous.a',
#  'despair.v',
#  'desperation.n',
#  'despise.v',
#  'determined.a',
#  'detest.v',
#  'detestation.n',
#  'discomfort.n',
#  'dislike.n',
#  'dislike.v',
#  'disprefer.v',
#  'dissatisfied.a',
#  'do.v',
#  'donnybrook.n',
#  'dread.v',
#  'dreadful.a',
#  'duel.n',
#  'duel.v',
#  'dust-up.n',
#  'dying.a',
#  'eager.a',
#  'easy.a',
#  'elegant.a',
#  'elude.v',
#  'empathy.n',
#  'endorse.v',
#  'endure.v',
#  'enemy.n',
#  'engage.v',
#  'engagement.n',
#  'engrossed.a',
#  'enthralled.a',
#  'envy.n',
#  'envy.v',
#  'escape.v',
#  'evade.v',
#  'excellence.n',
#  'excellent.a',
#  'execrable.a',
#  'extraordinary.a',
#  'fabulous.a',
#  'facial.n',
#  'fair.a',
#  'fancy.v',
#  'fantastic.a',
#  'fare.v',
#  'fascinated.a',
#  'favor.v',
#  'fazed.a',
#  'fear.v',
#  'fed up.a',
#  'feel like.v',
#  'feverish.a',
#  'feverishly.adv',
#  'fight.n',
#  'fight.v',
#  'fighter.n',
#  'fighting.n',
#  'file.v',
#  'fine.a',
#  'fire fighting.n',
#  'firefight.n',
#  'first-rate.a',
#  'fistfight.n',
#  'floss.v',
#  'flourish.v',
#  'fold [to demands].v',
#  'fond.a',
#  'for.prep',
#  'forget.v',
#  'fracas.n',
#  'fray.n',
#  'free-for-all.n',
#  'friendly.a',
#  'friendly.n',
#  'fulfilled.a',
#  'fulfillment.n',
#  'function.n',
#  'gain ground.idio',
#  'garbage.n',
#  'gem.n',
#  'give in.v',
#  'give way.v',
#  'goal.n',
#  'gold.n',
#  'good idea.n',
#  'good.a',
#  'great.a',
#  'grieve.v',
#  'groom.v',
#  'guerrilla.n',
#  'gunfight.n',
#  'gunner.n',
#  'handsome.a',
#  'hanker.v',
#  'hankering.n',
#  'happily.adv',
#  'hate.v',
#  'hatred.n',
#  'have to.v',
#  'hideous.a',
#  'hope.n',
#  'hope.v',
#  'horrible.a',
#  'hostile.a',
#  'hostile.n',
#  'hostility.n',
#  'hot.a',
#  'humble.a',
#  'hunger.n',
#  'hunger.v',
#  'hungry.a',
#  'idyllic.a',
#  'impartial.a',
#  'impartiality.n',
#  'impulse.n',
#  'in demand.a',
#  'in favor.prep',
#  'in hopes of.prep',
#  'in order.adv',
#  'in the hope of.prep',
#  'in.a',
#  'incredible.a',
#  'infantryman.n',
#  'infatuated.a',
#  'inferior.a',
#  'infighting.n',
#  'intend.v',
#  'intent.a',
#  'intention.n',
#  'interested.a',
#  'intimidated.a',
#  'irritated.a',
#  'itch.v',
#  'junk.n',
#  'killer.a',
#  'lame.a',
#  'lamer.n',
#  'languish.v',
#  'lave.v',
#  'left.a',
#  'like.v',
#  'live.v',
#  'loath.a',
#  'loathe.v',
#  'loathing.n',
#  'long.v',
#  'longing.n',
#  'look.n',
#  'lost (in).a',
#  'love.v',
#  'lovely.a',
#  'low.a',
#  'lust.n',
#  'lust.v',
#  'magnificent.a',
#  'manicure.n',
#  'manicure.v',
#  'marine.n',
#  'marvellous.a',
#  'mean.v',
#  'mediocre.a',
#  'melee.n',
#  'militant.n',
#  'miserable.a',
#  'moisturize.v',
#  'mourn.v',
#  'nasty.a',
#  'need.n',
#  'need.v',
#  'nervous.a',
#  'nettled.a',
#  'neutral.a',
#  'neutrality.n',
#  'object.n',
#  'objective.n',
#  'okay.a',
#  'opponent.n',
#  'oppose.v',
#  'opposition [act].n',
#  'opposition [entity].n',
#  'order.n',
#  'ought to.v',
#  'outstanding.a',
#  'part.n',
#  'partial.a',
#  'partiality.n',
#  'pathetic.a',
#  'pedestrian.a',
#  'pedicure.n',
#  'pine.v',
#  'pitiful.a',
#  'pity.n',
#  'pity.v',
#  'plait.v',
#  'plan.n',
#  'plan.v',
#  'pleasure.n',
#  'plebeian.a',
#  'pluck.v',
#  'poor.a',
#  'popular.a',
#  'prefer.v',
#  'prejudge.v',
#  'prejudice.n',
#  'prejudiced.a',
#  'pro.adv',
#  'program.n',
#  'project.n',
#  'proletarian.a',
#  'prosper.v',
#  'prosperity.n',
#  'protest.n',
#  'protest.v',
#  'protester.n',
#  'purpose.n',
#  'raring.a',
#  'regret.n',
#  'regret.v',
#  'relent.v',
#  'reliance.n',
#  'relish.n',
#  'reluctant.a',
#  'rely.v',
#  'remain.v',
#  'remainder.n',
#  'remember.v',
#  'require.v',
#  'resent.v',
#  'resentment.n',
#  'rock.v',
#  'rotten.a',
#  'row.n',
#  'rue.v',
#  'rueful.a',
#  'sacrifice.v',
#  'sailor.n',
#  'satisfaction.n',
#  'satisfied.a',
#  'scheme.n',
#  'scuffle.n',
#  'scuffle.v',
#  'second-rate.a',
#  'sensational.a',
#  'service member.n',
#  'shampoo.v',
#  'shave.v',
#  'shit.n',
#  'shitty.a',
#  'shootout.n',
#  'should.v',
#  'showdown.n',
#  'shower.v',
#  'side.n',
#  'side.v',
#  'signaller.n',
#  'skirmish.n',
#  'skirmish.v',
#  'slump.n',
#  'smart.a',
#  'smitten.a',
#  'sniper.n',
#  'so-so.a',
#  'soap.v',
#  'solace.n',
#  'soldier.n',
#  'sound.n',
#  'spat.n',
#  'splendid.a',
#  'spoiling.a',
#  'squabble.n',
#  'stalemate.n',
#  'stand.v',
#  'standoff.n',
#  'standout.n',
#  'strife.n',
#  'struggle.n',
#  'struggle.v',
#  'stupendous.a',
#  'style.n',
#  'submit.v',
#  'substandard.a',
#  'suck.v',
#  'super.a',
#  'superb.a',
#  'superlative.a',
#  'support.v',
#  'supporter.n',
#  'supportive.a',
#  'suspicious.a',
#  'sweet.a',
#  'tackle.v',
#  'taken.a',
#  'target.n',
#  'tasty.a',
#  'terrible.a',
#  'terrific.a',
#  'third-rate.a',
#  'thirst.n',
#  'thirst.v',
#  'thirsty.a',
#  'thrive.v',
#  'tiff.n',
#  'tip-top.a',
#  'tolerable.a',
#  'tolerant.a',
#  'tolerate.v',
#  'toleration.n',
#  'top-notch.a',
#  'tremendous.a',
#  'troop.n',
#  'tussle.n',
#  'ugly.a',
#  'uncool.a',
#  'unfazed.a',
#  'unfortunate.a',
#  'upper-class.a',
#  'upset.a',
#  'urge.n',
#  'use.n',
#  'vulgar.a',
#  'want.v',
#  'wants.n',
#  'war.n',
#  'war.v',
#  'warfare.n',
#  'wash.v',
#  'wax.v',
#  'well.adv',
#  'will.n',
#  'will.v',
#  'wish (that).v',
#  'wish.n',
#  'wish.v',
#  'wonderful.a',
#  'worked up.a',
#  'working-class.a',
#  'worried.a',
#  'worthless.a',
#  'wrangling.n',
#  'wrapped up (in).a',
#  'yearn.v',
#  'yearning.n',
#  'yen.n',
#  'yen.v',
#  'yield.v'}

# %%
print(len(Stimulus_focus_words))
Stimulus_focus_words = set(Stimulus_focus_words)
Stimulus_focus_words
# Out:
# 186
# {'abominable.a',
#  'absorbing.a',
#  'aggravating.a',
#  'aggravation.n',
#  'agonizing.a',
#  'agreeable.a',
#  'alarming.a',
#  'alienating.a',
#  'amazing.a',
#  'amusing.a',
#  'annoyance.n',
#  'annoying.a',
#  'appalling.a',
#  'astonishing.a',
#  'astounding.a',
#  'baffling.a',
#  'beguiling.a',
#  'bewildering.a',
#  'bewitching.a',
#  'blood-curdling.a',
#  'boring.a',
#  'bothersome.a',
#  'breathtaking.a',
#  'calming.a',
#  'captivating.a',
#  'charm [count].n',
#  'charm [mass].n',
#  'charming.a',
#  'cheering.a',
#  'chilling.a',
#  'color.n',
#  'comforting.a',
#  'comical.a',
#  'confusing.a',
#  'consoling.a',
#  'cool.a',
#  'dear.a',
#  'delight.n',
#  'delightful.a',
#  'depressing.a',
#  'devastating.a',
#  'disagreeable.a',
#  'disappointing.a',
#  'discomfiting.a',
#  'discomforting.a',
#  'disconcerting.a',
#  'discouraging.a',
#  'disgusting.a',
#  'disheartening.a',
#  'disillusioning.a',
#  'dismaying.a',
#  'disorientating.a',
#  'displeasing.a',
#  'distasteful.a',
#  'distressing.a',
#  'disturbing.a',
#  'dreadful.a',
#  'droll.a',
#  'dull.a',
#  'earth-shattering.a',
#  'electrifying.a',
#  'embarrassing.a',
#  'embittering.a',
#  'empty.a',
#  'enchanting.a',
#  'encouraging.a',
#  'engrossing.a',
#  'enjoyable.a',
#  'enraging.a',
#  'entertaining.a',
#  'enthralling.a',
#  'exasperating.a',
#  'exciting.a',
#  'exhilarating.a',
#  'fascinating.a',
#  'formidable.a',
#  'frightening.a',
#  'fulfilling.a',
#  'full.a',
#  'funny.a',
#  'galling.a',
#  'ghastly.a',
#  'gratifying.a',
#  'gripping.a',
#  'hair-raising.a',
#  'harrowing.a',
#  'heart-rending.a',
#  'heart-stopping.a',
#  'heart-warming.a',
#  'heartbreaking.a',
#  'heartening.a',
#  'hilarious.a',
#  'humorous.a',
#  'impressive.a',
#  'ineffability.n',
#  'ineffable.a',
#  'infuriating.a',
#  'insulting.a',
#  'intimidating.a',
#  'intriguing.a',
#  'invigorating.a',
#  'irksome.a',
#  'irritating.a',
#  'jaw-dropping.a',
#  'je ne sais quoi.n',
#  'jolly.a',
#  'maddening.a',
#  'magic.a',
#  'magic.n',
#  'magical.a',
#  'magicalness.n',
#  'mind-boggling.a',
#  'mind-numbing.a',
#  'mortifying.a',
#  'mystifying.a',
#  'nerve-racking.a',
#  'nice.a',
#  'offensive.a',
#  'pacifying.a',
#  'pathetic.a',
#  'perplexing.a',
#  'pitiful.a',
#  'placating.a',
#  'pleasant.a',
#  'pleasing.a',
#  'pleasurable.a',
#  'poignant.a',
#  'reassuring.a',
#  'recreation.n',
#  'relaxation.n',
#  'relaxing.a',
#  'repellent.a',
#  'rest.n',
#  'revolting.a',
#  'rich.a',
#  'rousing.a',
#  'sad.a',
#  'saddening.a',
#  'satisfying.a',
#  'scary.a',
#  'shocking.a',
#  'sickening.a',
#  'side-splitting.a',
#  'sobering.a',
#  'solemn.a',
#  'soothing.a',
#  'spine-chilling.a',
#  'spine-tingling.a',
#  'startling.a',
#  'stimulating.a',
#  'stinging.a',
#  'stirring.a',
#  'stressful.a',
#  'strike a chord.v',
#  'striking.a',
#  'stupefying.a',
#  'surprising.a',
#  'suspenseful.a',
#  'tear-jerking.a',
#  'tedious.a',
#  'terrifying.a',
#  'thorny.a',
#  'thrilling.a',
#  'tiresome.a',
#  'tiring.a',
#  'tormenting.a',
#  'touching.a',
#  'traumatic.a',
#  'traumatising.a',
#  'troublesome.a',
#  'troubling.a',
#  'unexciting.a',
#  'unfulfilling.a',
#  'unfunny.a',
#  'unnerving.a',
#  'unpleasant.a',
#  'unpleasing.a',
#  'unsettling.a',
#  'uplifting.a',
#  'upsetting.a',
#  'vexation.n',
#  'vexatious.a',
#  'vexing.a',
#  'white-knuckle.a',
#  'worrisome.a',
#  'worrying.a'}

# %%
Experiencer_words = set(Experiencer_focus_words).union(Stimulus_focus_words)
len(Experiencer_words)
# Out:
# 619

# %%
Experiencer_words
# Out:
# {'abhor.v',
#  'abhorrence.n',
#  'ablution.n',
#  'abominable.a',
#  'abominate.v',
#  'absorbed.a',
#  'absorbing.a',
#  'ache.v',
#  'acquiesce.v',
#  'adoration.n',
#  'adore.v',
#  'affray.n',
#  'against.prep',
#  'agape.a',
#  'aggravating.a',
#  'aggravation.n',
#  'agonizing.a',
#  'agreeable.a',
#  'aim.n',
#  'aim.v',
#  'airman.n',
#  'alarming.a',
#  'alienating.a',
#  'altercation.n',
#  'amazing.a',
#  'ambition.n',
#  'amusing.a',
#  'annoyance.n',
#  'annoying.a',
#  'antipathy.n',
#  'appalling.a',
#  'apprehensive.a',
#  'aspiration.n',
#  'aspire.v',
#  'astonishing.a',
#  'astounding.a',
#  'atrocious.a',
#  'attack.v',
#  'average.a',
#  'awesome.a',
#  'awful.a',
#  'back.v',
#  'backing.n',
#  'bad idea.n',
#  'bad.a',
#  'baffling.a',
#  'bathe.v',
#  'battle.n',
#  'battle.v',
#  'be supposed to.v',
#  'bear.v',
#  'beautiful.a',
#  'beguiling.a',
#  'believe (in).v',
#  'belligerent.n',
#  'bent.a',
#  'best thing since sliced bread.n',
#  'bewildering.a',
#  'bewitching.a',
#  'bias.n',
#  'bias.v',
#  'biased.a',
#  'blood-curdling.a',
#  'boring.a',
#  'bothersome.a',
#  'bout.n',
#  'brawl.n',
#  'brawl.v',
#  'breathtaking.a',
#  'brush [hair].v',
#  'brush [teeth].v',
#  'bw.n',
#  'calm.a',
#  'calming.a',
#  'capitulate.v',
#  'captivated.a',
#  'captivating.a',
#  'care.v',
#  'cave in.v',
#  'cave.v',
#  'charm [count].n',
#  'charm [mass].n',
#  'charming.a',
#  'cheering.a',
#  'chilling.a',
#  'clash.n',
#  'clash.v',
#  'cleanse.v',
#  'color.n',
#  'comb.v',
#  'combat.n',
#  'combatant.n',
#  'comfort.n',
#  'comforting.a',
#  'comical.a',
#  'commando.n',
#  'common.a',
#  'compassion.n',
#  'compromise.v',
#  'conflict.n',
#  'confront.v',
#  'confrontation.n',
#  'confusing.a',
#  'consoling.a',
#  'control.v',
#  'cool.a',
#  'count.v',
#  'covet.v',
#  'covetous.a',
#  'crap.n',
#  'crappy.a',
#  'crave.v',
#  'craving.n',
#  'curious.a',
#  'cw.n',
#  'dear.a',
#  'decent.a',
#  'delight.n',
#  'delight.v',
#  'delightful.a',
#  'demonstrate.v',
#  'demonstration.n',
#  'depend.v',
#  'dependence.n',
#  'dependency.n',
#  'depressing.a',
#  'desirable.a',
#  'desire.n',
#  'desire.v',
#  'desired.a',
#  'desirous.a',
#  'despair.v',
#  'desperation.n',
#  'despise.v',
#  'determined.a',
#  'detest.v',
#  'detestation.n',
#  'devastating.a',
#  'disagreeable.a',
#  'disappointing.a',
#  'discomfiting.a',
#  'discomfort.n',
#  'discomforting.a',
#  'disconcerting.a',
#  'discouraging.a',
#  'disgusting.a',
#  'disheartening.a',
#  'disillusioning.a',
#  'dislike.n',
#  'dislike.v',
#  'dismaying.a',
#  'disorientating.a',
#  'displeasing.a',
#  'disprefer.v',
#  'dissatisfied.a',
#  'distasteful.a',
#  'distressing.a',
#  'disturbing.a',
#  'do.v',
#  'donnybrook.n',
#  'dread.v',
#  'dreadful.a',
#  'droll.a',
#  'duel.n',
#  'duel.v',
#  'dull.a',
#  'dust-up.n',
#  'dying.a',
#  'eager.a',
#  'earth-shattering.a',
#  'easy.a',
#  'electrifying.a',
#  'elegant.a',
#  'elude.v',
#  'embarrassing.a',
#  'embittering.a',
#  'empathy.n',
#  'empty.a',
#  'enchanting.a',
#  'encouraging.a',
#  'endorse.v',
#  'endure.v',
#  'enemy.n',
#  'engage.v',
#  'engagement.n',
#  'engrossed.a',
#  'engrossing.a',
#  'enjoyable.a',
#  'enraging.a',
#  'entertaining.a',
#  'enthralled.a',
#  'enthralling.a',
#  'envy.n',
#  'envy.v',
#  'escape.v',
#  'evade.v',
#  'exasperating.a',
#  'excellence.n',
#  'excellent.a',
#  'exciting.a',
#  'execrable.a',
#  'exhilarating.a',
#  'extraordinary.a',
#  'fabulous.a',
#  'facial.n',
#  'fair.a',
#  'fancy.v',
#  'fantastic.a',
#  'fare.v',
#  'fascinated.a',
#  'fascinating.a',
#  'favor.v',
#  'fazed.a',
#  'fear.v',
#  'fed up.a',
#  'feel like.v',
#  'feverish.a',
#  'feverishly.adv',
#  'fight.n',
#  'fight.v',
#  'fighter.n',
#  'fighting.n',
#  'file.v',
#  'fine.a',
#  'fire fighting.n',
#  'firefight.n',
#  'first-rate.a',
#  'fistfight.n',
#  'floss.v',
#  'flourish.v',
#  'fold [to demands].v',
#  'fond.a',
#  'for.prep',
#  'forget.v',
#  'formidable.a',
#  'fracas.n',
#  'fray.n',
#  'free-for-all.n',
#  'friendly.a',
#  'friendly.n',
#  'frightening.a',
#  'fulfilled.a',
#  'fulfilling.a',
#  'fulfillment.n',
#  'full.a',
#  'function.n',
#  'funny.a',
#  'gain ground.idio',
#  'galling.a',
#  'garbage.n',
#  'gem.n',
#  'ghastly.a',
#  'give in.v',
#  'give way.v',
#  'goal.n',
#  'gold.n',
#  'good idea.n',
#  'good.a',
#  'gratifying.a',
#  'great.a',
#  'grieve.v',
#  'gripping.a',
#  'groom.v',
#  'guerrilla.n',
#  'gunfight.n',
#  'gunner.n',
#  'hair-raising.a',
#  'handsome.a',
#  'hanker.v',
#  'hankering.n',
#  'happily.adv',
#  'harrowing.a',
#  'hate.v',
#  'hatred.n',
#  'have to.v',
#  'heart-rending.a',
#  'heart-stopping.a',
#  'heart-warming.a',
#  'heartbreaking.a',
#  'heartening.a',
#  'hideous.a',
#  'hilarious.a',
#  'hope.n',
#  'hope.v',
#  'horrible.a',
#  'hostile.a',
#  'hostile.n',
#  'hostility.n',
#  'hot.a',
#  'humble.a',
#  'humorous.a',
#  'hunger.n',
#  'hunger.v',
#  'hungry.a',
#  'idyllic.a',
#  'impartial.a',
#  'impartiality.n',
#  'impressive.a',
#  'impulse.n',
#  'in demand.a',
#  'in favor.prep',
#  'in hopes of.prep',
#  'in order.adv',
#  'in the hope of.prep',
#  'in.a',
#  'incredible.a',
#  'ineffability.n',
#  'ineffable.a',
#  'infantryman.n',
#  'infatuated.a',
#  'inferior.a',
#  'infighting.n',
#  'infuriating.a',
#  'insulting.a',
#  'intend.v',
#  'intent.a',
#  'intention.n',
#  'interested.a',
#  'intimidated.a',
#  'intimidating.a',
#  'intriguing.a',
#  'invigorating.a',
#  'irksome.a',
#  'irritated.a',
#  'irritating.a',
#  'itch.v',
#  'jaw-dropping.a',
#  'je ne sais quoi.n',
#  'jolly.a',
#  'junk.n',
#  'killer.a',
#  'lame.a',
#  'lamer.n',
#  'languish.v',
#  'lave.v',
#  'left.a',
#  'like.v',
#  'live.v',
#  'loath.a',
#  'loathe.v',
#  'loathing.n',
#  'long.v',
#  'longing.n',
#  'look.n',
#  'lost (in).a',
#  'love.v',
#  'lovely.a',
#  'low.a',
#  'lust.n',
#  'lust.v',
#  'maddening.a',
#  'magic.a',
#  'magic.n',
#  'magical.a',
#  'magicalness.n',
#  'magnificent.a',
#  'manicure.n',
#  'manicure.v',
#  'marine.n',
#  'marvellous.a',
#  'mean.v',
#  'mediocre.a',
#  'melee.n',
#  'militant.n',
#  'mind-boggling.a',
#  'mind-numbing.a',
#  'miserable.a',
#  'moisturize.v',
#  'mortifying.a',
#  'mourn.v',
#  'mystifying.a',
#  'nasty.a',
#  'need.n',
#  'need.v',
#  'nerve-racking.a',
#  'nervous.a',
#  'nettled.a',
#  'neutral.a',
#  'neutrality.n',
#  'nice.a',
#  'object.n',
#  'objective.n',
#  'offensive.a',
#  'okay.a',
#  'opponent.n',
#  'oppose.v',
#  'opposition [act].n',
#  'opposition [entity].n',
#  'order.n',
#  'ought to.v',
#  'outstanding.a',
#  'pacifying.a',
#  'part.n',
#  'partial.a',
#  'partiality.n',
#  'pathetic.a',
#  'pedestrian.a',
#  'pedicure.n',
#  'perplexing.a',
#  'pine.v',
#  'pitiful.a',
#  'pity.n',
#  'pity.v',
#  'placating.a',
#  'plait.v',
#  'plan.n',
#  'plan.v',
#  'pleasant.a',
#  'pleasing.a',
#  'pleasurable.a',
#  'pleasure.n',
#  'plebeian.a',
#  'pluck.v',
#  'poignant.a',
#  'poor.a',
#  'popular.a',
#  'prefer.v',
#  'prejudge.v',
#  'prejudice.n',
#  'prejudiced.a',
#  'pro.adv',
#  'program.n',
#  'project.n',
#  'proletarian.a',
#  'prosper.v',
#  'prosperity.n',
#  'protest.n',
#  'protest.v',
#  'protester.n',
#  'purpose.n',
#  'raring.a',
#  'reassuring.a',
#  'recreation.n',
#  'regret.n',
#  'regret.v',
#  'relaxation.n',
#  'relaxing.a',
#  'relent.v',
#  'reliance.n',
#  'relish.n',
#  'reluctant.a',
#  'rely.v',
#  'remain.v',
#  'remainder.n',
#  'remember.v',
#  'repellent.a',
#  'require.v',
#  'resent.v',
#  'resentment.n',
#  'rest.n',
#  'revolting.a',
#  'rich.a',
#  'rock.v',
#  'rotten.a',
#  'rousing.a',
#  'row.n',
#  'rue.v',
#  'rueful.a',
#  'sacrifice.v',
#  'sad.a',
#  'saddening.a',
#  'sailor.n',
#  'satisfaction.n',
#  'satisfied.a',
#  'satisfying.a',
#  'scary.a',
#  'scheme.n',
#  'scuffle.n',
#  'scuffle.v',
#  'second-rate.a',
#  'sensational.a',
#  'service member.n',
#  'shampoo.v',
#  'shave.v',
#  'shit.n',
#  'shitty.a',
#  'shocking.a',
#  'shootout.n',
#  'should.v',
#  'showdown.n',
#  'shower.v',
#  'sickening.a',
#  'side-splitting.a',
#  'side.n',
#  'side.v',
#  'signaller.n',
#  'skirmish.n',
#  'skirmish.v',
#  'slump.n',
#  'smart.a',
#  'smitten.a',
#  'sniper.n',
#  'so-so.a',
#  'soap.v',
#  'sobering.a',
#  'solace.n',
#  'soldier.n',
#  'solemn.a',
#  'soothing.a',
#  'sound.n',
#  'spat.n',
#  'spine-chilling.a',
#  'spine-tingling.a',
#  'splendid.a',
#  'spoiling.a',
#  'squabble.n',
#  'stalemate.n',
#  'stand.v',
#  'standoff.n',
#  'standout.n',
#  'startling.a',
#  'stimulating.a',
#  'stinging.a',
#  'stirring.a',
#  'stressful.a',
#  'strife.n',
#  'strike a chord.v',
#  'striking.a',
#  'struggle.n',
#  'struggle.v',
#  'stupefying.a',
#  'stupendous.a',
#  'style.n',
#  'submit.v',
#  'substandard.a',
#  'suck.v',
#  'super.a',
#  'superb.a',
#  'superlative.a',
#  'support.v',
#  'supporter.n',
#  'supportive.a',
#  'surprising.a',
#  'suspenseful.a',
#  'suspicious.a',
#  'sweet.a',
#  'tackle.v',
#  'taken.a',
#  'target.n',
#  'tasty.a',
#  'tear-jerking.a',
#  'tedious.a',
#  'terrible.a',
#  'terrific.a',
#  'terrifying.a',
#  'third-rate.a',
#  'thirst.n',
#  'thirst.v',
#  'thirsty.a',
#  'thorny.a',
#  'thrilling.a',
#  'thrive.v',
#  'tiff.n',
#  'tip-top.a',
#  'tiresome.a',
#  'tiring.a',
#  'tolerable.a',
#  'tolerant.a',
#  'tolerate.v',
#  'toleration.n',
#  'top-notch.a',
#  'tormenting.a',
#  'touching.a',
#  'traumatic.a',
#  'traumatising.a',
#  'tremendous.a',
#  'troop.n',
#  'troublesome.a',
#  'troubling.a',
#  'tussle.n',
#  'ugly.a',
#  'uncool.a',
#  'unexciting.a',
#  'unfazed.a',
#  'unfortunate.a',
#  'unfulfilling.a',
#  'unfunny.a',
#  'unnerving.a',
#  'unpleasant.a',
#  'unpleasing.a',
#  'unsettling.a',
#  'uplifting.a',
#  'upper-class.a',
#  'upset.a',
#  'upsetting.a',
#  'urge.n',
#  'use.n',
#  'vexation.n',
#  'vexatious.a',
#  'vexing.a',
#  'vulgar.a',
#  'want.v',
#  'wants.n',
#  'war.n',
#  'war.v',
#  'warfare.n',
#  'wash.v',
#  'wax.v',
#  'well.adv',
#  'white-knuckle.a',
#  'will.n',
#  'will.v',
#  'wish (that).v',
#  'wish.n',
#  'wish.v',
#  'wonderful.a',
#  'worked up.a',
#  'working-class.a',
#  'worried.a',
#  'worrisome.a',
#  'worrying.a',
#  'worthless.a',
#  'wrangling.n',
#  'wrapped up (in).a',
#  'yearn.v',
#  'yearning.n',
#  'yen.n',
#  'yen.v',
#  'yield.v'}

# %% [markdown]
# ##  Using the wordnet  adj wheel information to expand the set of adjective words

# %%
L[:10]
# Out:
# ['envy.n',
#  'calm.a',
#  'abhorrence.n',
#  'sacrifice.v',
#  'believe (in).v',
#  'desire.v',
#  'should.v',
#  'yen.n',
#  'scuffle.v',
#  'pine.v']

# %%
L = list(Experiencer_focus_words)
L_ss = [ss for w in  L if w[-1] == "a" for ss in wn.synsets(w[:-2],"a") if ss.pos()=="s"]
# filter out some highly ambiguous noise makers
L_ss = [ss for ss in L_ss if ss.lemmas()[0].name() not in ["hot", "in","good", "bad", "easy", "common", "neutral"]]
extended_experiencer_focus_adjectives_wn = sorted(list({ss2.name() for ss in L_ss for ss2 in get_wheels_and_axle(ss,return_set=True)}))
print(len(L),len(L_ss),len(expanded_L_ss))
# Out:
# 441 284 1268

# %%
L2 = list(Stimulus_focus_words)
L2_ss = [ss for w in  L2 if w[-1] == "a" for ss in wn.synsets(w[:-2],"a") if ss.pos()=="s"]
# filter out some highly ambiguous noise makers
#L_ss = [ss for ss in L_ss if ss.lemmas()[0].name() not in ["hot", "in","good", "bad", "easy", "common", "neutral"]]
extended_stimulus_focus_adjectives_wn = sorted(list({ss2.name() for ss in L2_ss for ss2 in get_wheels_and_axle(ss,return_set=True)}))
print(len(L2),len(L2_ss),len(expanded_L2_ss))
# Out:
# 186 217 1268

# %%
len(extended_stimulus_focus_adjectives_wn)
# Out:
# 1268

# %%
expanded_L2_ss# == expanded_L_ss
# Out:
# ['abashed.s.01',
#  'abhorrent.s.01',
#  'abject.s.01',
#  'abject.s.02',
#  'ablaze.s.03',
#  'abominable.s.01',
#  'abortive.s.01',
#  'abounding.s.01',
#  'absolute.s.02',
#  'absorbefacient.s.01',
#  'absorbent.a.01',
#  'absorbing.s.01',
#  'abundant.a.01',
#  'acarpous.s.01',
#  'accessary.s.01',
#  'accessory.s.02',
#  'accomplished.s.02',
#  'accordant.a.01',
#  'accordant.s.02',
#  'according.s.01',
#  'acerb.s.02',
#  'aching.s.01',
#  'acid-tasting.s.01',
#  'acknowledged.s.02',
#  'active.a.07',
#  'adequate.s.03',
#  'admirable.s.01',
#  'admirable.s.02',
#  'admired.s.01',
#  'admonitory.s.01',
#  'adorable.s.01',
#  'adored.s.01',
#  'adrenocorticotropic.s.01',
#  'advanced.s.04',
#  'affecting.s.01',
#  'afflicted.s.01',
#  'afflictive.s.01',
#  'aggravating.s.01',
#  'agitative.s.01',
#  'agonized.s.01',
#  'agonizing.s.01',
#  'agreeable.a.01',
#  'agreeable.s.03',
#  'aguish.s.01',
#  'ailing.s.01',
#  'airheaded.s.01',
#  'airsick.s.01',
#  'alarming.a.01',
#  'alienated.s.02',
#  'alienating.s.01',
#  'aligning.s.01',
#  'alimentary.s.01',
#  'aliquot.s.01',
#  'alive.s.04',
#  'all-or-none.s.01',
#  'all-out.s.01',
#  'all.s.02',
#  'all_right.s.01',
#  'alleged.s.02',
#  'alleviative.s.01',
#  'allover.s.01',
#  'alluring.s.01',
#  'alright.s.01',
#  'amazing.s.01',
#  'amazing.s.02',
#  'ambidextrous.s.02',
#  'ambitious.s.02',
#  'ambrosial.s.01',
#  'amentiferous.s.01',
#  'amiable.s.01',
#  'ample.a.01',
#  'ample.s.02',
#  'amusing.s.01',
#  'amusing.s.02',
#  'analeptic.s.01',
#  'analgesic.s.01',
#  'anechoic.s.01',
#  'angelic.s.03',
#  'anguished.s.01',
#  'animating.s.01',
#  'annihilating.s.02',
#  'annihilative.s.01',
#  'annoying.s.01',
#  'anserine.s.02',
#  'antagonistic.a.03',
#  'antic.s.01',
#  'antique.s.02',
#  'antsy.s.01',
#  'aphoristic.s.02',
#  'apocryphal.s.01',
#  'appalling.s.01',
#  'apparitional.s.01',
#  'appeasing.s.01',
#  'approximate.s.02',
#  'arable.s.01',
#  'arduous.s.01',
#  'arduous.s.02',
#  'arduous.s.03',
#  'armed.a.03',
#  'aroused.s.03',
#  'arresting.s.01',
#  'ashen.s.01',
#  'assimilating.s.01',
#  'assuasive.s.01',
#  'assuring.s.01',
#  'astonishing.s.02',
#  'astounding.s.01',
#  'astute.s.01',
#  'asymptomatic.s.01',
#  'at_odds.s.01',
#  'at_variance.s.01',
#  'ataractic.s.01',
#  'atrabilious.s.01',
#  'atrocious.s.02',
#  'atrocious.s.03',
#  'attention-getting.s.01',
#  'attractive.a.01',
#  'augmentative.s.02',
#  'autistic.s.01',
#  'awful.s.02',
#  'awkward.s.05',
#  'bad.a.01',
#  'bad.s.03',
#  'baffling.s.01',
#  'baleful.s.02',
#  'bang-up.s.01',
#  'bantering.s.01',
#  'barbed.s.02',
#  'bare.s.02',
#  'bargain-priced.s.01',
#  'baronial.s.01',
#  'bastardly.s.02',
#  'beastly.s.01',
#  'beatific.s.01',
#  'beautiful.s.02',
#  'bedfast.s.01',
#  'beguiling.s.02',
#  'beloved.s.01',
#  'benign.s.03',
#  'benignant.s.02',
#  'bereaved.s.01',
#  'bereft.s.01',
#  'berried.s.01',
#  'better_off.s.01',
#  'bewitching.s.01',
#  'beyond_doubt.s.01',
#  'big-ticket.s.01',
#  'big.s.04',
#  'big.s.05',
#  'bilious.s.02',
#  'biting.s.02',
#  'bitter.s.04',
#  'bitter.s.06',
#  'bitterish.s.01',
#  'bittersweet.s.02',
#  'black.s.06',
#  'bland.s.01',
#  'bland.s.02',
#  'blaring.s.01',
#  'blasting.s.01',
#  'bleached.s.01',
#  'blockheaded.s.01',
#  'bloodcurdling.s.01',
#  'blue-chip.s.01',
#  'blue-eyed.s.01',
#  'blue-fruited.s.01',
#  'blurred.s.02',
#  'blushful.s.01',
#  'bold.s.02',
#  'bona_fide.s.01',
#  'booming.s.02',
#  'boon.s.01',
#  'bootless.s.01',
#  'bootlicking.s.01',
#  'boring.s.01',
#  'bothered.s.01',
#  'bountiful.s.02',
#  'bracing.s.01',
#  'brackish.s.01',
#  'bratty.s.01',
#  'breathless.s.02',
#  'breeding.s.01',
#  'brief.s.02',
#  'bright.s.02',
#  'bright.s.08',
#  'brilliant.s.03',
#  'brisk.s.03',
#  'bristlelike.s.01',
#  'bristly.s.01',
#  'broad.s.04',
#  'broad.s.05',
#  'broken.s.13',
#  'brokenhearted.s.01',
#  'bronchitic.s.01',
#  'brumous.s.01',
#  'brushlike.s.01',
#  'buffoonish.s.01',
#  'burdensome.s.01',
#  'bustling.s.01',
#  'busy.s.04',
#  'buttery.s.01',
#  'cagey.s.01',
#  'callous.s.01',
#  'calm.s.01',
#  'cantankerous.s.02',
#  'casual.s.09',
#  'cataclysmal.s.01',
#  'catchpenny.s.01',
#  'catchy.s.01',
#  'categoric.s.02',
#  'caustic.s.02',
#  'certificatory.s.01',
#  'chafed.s.01',
#  'chaffy.s.02',
#  'challenging.s.02',
#  'challenging.s.03',
#  'changeable.s.04',
#  'charged.s.04',
#  'charismatic.s.01',
#  'charitable.s.03',
#  'charming.s.01',
#  'charming.s.02',
#  'charnel.s.01',
#  'chaste.s.03',
#  'cheap.a.01',
#  'cherished.s.01',
#  'childless.s.01',
#  'chilling.s.01',
#  'choice.s.02',
#  'choleric.s.02',
#  'choosy.s.01',
#  'chummy.s.02',
#  'churlish.s.01',
#  'churlish.s.02',
#  'clarion.s.01',
#  'clawed.s.02',
#  'clean.s.02',
#  'clean.s.10',
#  'clean.s.14',
#  'clean.s.15',
#  'clear-cut.s.01',
#  'clear.a.01',
#  'clear.a.11',
#  'cliff-hanging.s.01',
#  'clinking.s.01',
#  'cloddish.s.01',
#  'close-knit.s.01',
#  'close.a.02',
#  'cloud-covered.s.01',
#  'cloudless.s.01',
#  'cloudlike.s.01',
#  'cloudy.a.02',
#  'coaxing.s.01',
#  'cogent.s.01',
#  'collateral.s.02',
#  'collected.s.02',
#  'colorful.a.01',
#  'colorless.a.02',
#  'comfortable.a.01',
#  'comforting.s.01',
#  'comforting.s.02',
#  'comfortless.s.01',
#  'common.s.04',
#  'common_or_garden.s.01',
#  'commonplace.s.02',
#  'compelling.s.02',
#  'compendious.s.01',
#  'complete.a.01',
#  'completed.s.03',
#  'composed.a.01',
#  'conciliatory.a.02',
#  'concise.a.01',
#  'concordant.s.02',
#  'conditional.s.01',
#  'confidential.s.03',
#  'confounding.s.01',
#  'confusing.s.01',
#  'confusing.s.02',
#  'congenial.a.01',
#  'consensual.s.01',
#  'consentaneous.s.01',
#  'consistent.a.01',
#  'conspicuous.a.01',
#  'constructive.a.01',
#  'consumptive.s.02',
#  'contemptible.a.01',
#  'contemptuous.s.01',
#  'contumelious.s.01',
#  'convalescent.s.01',
#  'convincing.a.01',
#  'cool.s.02',
#  'cool.s.05',
#  'cool.s.06',
#  'copacetic.s.01',
#  'copious.s.01',
#  'cordial.s.03',
#  'corked.s.01',
#  'corn-fed.s.01',
#  'corroborant.s.01',
#  'corrupting.s.01',
#  'costly.s.02',
#  'courteous.s.01',
#  'courtly.s.01',
#  'cozy.s.01',
#  'cozy.s.03',
#  'crabbed.s.01',
#  'cranky.s.02',
#  'crazy.s.04',
#  'creative.s.02',
#  'credible.a.01',
#  'credible.s.03',
#  'creepy.s.01',
#  'creepy.s.02',
#  'crisp.s.06',
#  'crushing.s.01',
#  'crusty.s.02',
#  'crying.s.02',
#  'cryptic.s.01',
#  'cryptic.s.03',
#  'cuddlesome.s.01',
#  'cunning.s.01',
#  'cured.s.01',
#  'curious.s.01',
#  'currish.s.02',
#  'cushy.s.01',
#  'cutting.s.01',
#  'dainty.s.03',
#  'dainty.s.04',
#  'damaging.s.02',
#  'dapper.s.01',
#  'dark-fruited.s.01',
#  'dark.s.06',
#  'dark.s.11',
#  'dated.s.01',
#  'daunting.s.01',
#  'dazzling.s.01',
#  'dead.s.04',
#  'dead.s.06',
#  'dead.s.08',
#  'dead.s.15',
#  'dead.s.17',
#  'deafening.s.01',
#  'dear.s.02',
#  'dear.s.03',
#  'dearly-won.s.01',
#  'debased.s.02',
#  'debatable.s.01',
#  'debauched.s.01',
#  'debilitating.a.01',
#  'debilitative.s.01',
#  'deceitful.s.01',
#  'decent.s.01',
#  'deceptive.s.02',
#  'deep.s.07',
#  'deepening.s.01',
#  'deferent.s.01',
#  'degage.s.01',
#  'delectable.s.01',
#  'delicate.s.06',
#  'delightful.s.01',
#  'delirious.s.01',
#  'demeaning.s.01',
#  'demonstrative_of.s.01',
#  'demoralizing.s.01',
#  'dense.s.04',
#  'deplorable.s.01',
#  'depressant.a.01',
#  'depressed.s.01',
#  'derisive.s.01',
#  'describable.s.01',
#  'despised.s.01',
#  'destructive.a.01',
#  'diabetic.s.02',
#  'difficult.a.01',
#  'diffuse.s.03',
#  'dignified.a.01',
#  'dimensioning.s.01',
#  'dinky.s.02',
#  'dirt_cheap.s.01',
#  'dirty.s.03',
#  'disagreeable.a.01',
#  'disagreeable.s.02',
#  'disagreeable.s.03',
#  'disappointing.s.01',
#  'disarming.s.01',
#  'discombobulated.s.01',
#  'discomposed.a.01',
#  'disconcerting.s.01',
#  'disconfirming.s.02',
#  'discordant.a.01',
#  'discouraging.a.01',
#  'discouraging.s.02',
#  'discourteous.s.02',
#  'discrepant.s.01',
#  'disenchanting.s.01',
#  'disgraceful.s.01',
#  'disgusting.s.01',
#  'dishonest.a.01',
#  'disinherited.s.01',
#  'disorienting.a.01',
#  'displeasing.a.01',
#  'dispossessed.s.01',
#  'disrespectful.a.01',
#  'dissentious.s.01',
#  'dissimulative.s.01',
#  'dissuasive.a.01',
#  'distant.a.02',
#  'distasteful.s.01',
#  'distinguished.s.02',
#  'distressing.s.01',
#  'divine.s.04',
#  'divisional.s.03',
#  'dizzy.s.01',
#  'dolorous.s.01',
#  'doomed.s.03',
#  'doubtful.s.01',
#  'dour.s.02',
#  'dowdy.s.02',
#  'downright.s.01',
#  'downtrodden.s.01',
#  'drab.s.02',
#  'dragging.s.01',
#  'drained.a.01',
#  'draining.s.01',
#  'dramatic.s.02',
#  'dreadful.s.03',
#  'droll.s.01',
#  'dry.s.02',
#  'dry.s.09',
#  'dry.s.11',
#  'dulcet.s.01',
#  'dull.s.03',
#  'dull.s.05',
#  'dull.s.08',
#  'dull.s.10',
#  'dull.s.11',
#  'dull.s.12',
#  'dulled.s.03',
#  'dyspeptic.s.01',
#  'earnest.s.01',
#  'earthshaking.s.01',
#  'easy.a.01',
#  'easy.s.04',
#  'easy.s.09',
#  'easy.s.12',
#  'echoing.s.01',
#  'ecstatic.s.01',
#  'edgy.s.01',
#  'eerie.s.01',
#  'eerie.s.02',
#  'effective.a.01',
#  'effortful.a.01',
#  'effortless.a.01',
#  'elated.s.02',
#  'elating.s.01',
#  'eldritch.s.01',
#  'electric.s.02',
#  'electric.s.03',
#  'electrifying.s.01',
#  'elegant.s.02',
#  'elegiac.s.02',
#  'elementary.s.01',
#  'elfin.s.01',
#  'elliptic.s.03',
#  'embarrassing.s.02',
#  'empty.s.02',
#  'empty.s.03',
#  'empty.s.04',
#  'encouraging.a.01',
#  'encouraging.s.02',
#  'engaging.s.01',
#  'enjoyable.s.01',
#  'entertaining.s.01',
#  'entire.s.01',
#  'equable.s.02',
#  'equivocal.s.02',
#  'erosive.s.01',
#  'estimable.a.01',
#  'estranging.s.01',
#  'etiolate.s.01',
#  'euphonious.s.02',
#  'everyday.s.03',
#  'exasperating.s.01',
#  'excitant.s.01',
#  'exciting.a.01',
#  'exciting.s.02',
#  'exhausted.s.03',
#  'exhausting.s.02',
#  'exhaustive.s.01',
#  'exhilarating.s.01',
#  'exhortative.s.01',
#  'exiguous.s.01',
#  'exotic.s.02',
#  'expansive.s.02',
#  'expensive.a.01',
#  'explainable.s.01',
#  'explicable.a.01',
#  'expressible.a.01',
#  'exuberant.s.03',
#  'fabulous.s.01',
#  'fabulous.s.03',
#  'facile.s.02',
#  'faddish.s.01',
#  'failing.s.01',
#  'faint.s.04',
#  'fair.s.09',
#  'false.s.04',
#  'false.s.07',
#  'familiar.a.02',
#  'familiar.s.04',
#  'familiarizing.s.01',
#  'famished.s.01',
#  'faraway.s.02',
#  'farcical.s.01',
#  'fashionable.a.01',
#  'fastidious.a.01',
#  'fat.s.05',
#  'favored.s.01',
#  'fearful.s.04',
#  'featured.s.01',
#  'fecund.s.02',
#  'feigned.s.01',
#  'felicitous.s.02',
#  'fetching.s.01',
#  'feverish.s.03',
#  'fine.s.02',
#  'finespun.s.02',
#  'finical.s.01',
#  'fishy.s.02',
#  'flavorful.s.01',
#  'fleshed_out.s.01',
#  'flighty.s.01',
#  'flippant.s.01',
#  'fluorescent.s.02',
#  'flustered.s.01',
#  'fogbound.s.01',
#  'fogyish.s.01',
#  'foodless.s.01',
#  'fooling.s.01',
#  'for_sure.s.01',
#  'formative.s.01',
#  'formative.s.02',
#  'formidable.s.01',
#  'formidable.s.02',
#  'fortuitous.s.02',
#  'fortunate.a.01',
#  'fractional.a.01',
#  'fractious.s.03',
#  'fragmental.s.01',
#  'freaky.s.01',
#  'frivolous.a.01',
#  'fruitful.a.01',
#  'fruity.s.01',
#  'frustrating.s.01',
#  'full-blown.s.02',
#  'full-bodied.s.01',
#  'full-dress.s.03',
#  'full-length.s.01',
#  'full-page.s.01',
#  'full.a.05',
#  'full.s.03',
#  'full.s.04',
#  'full.s.06',
#  'funereal.s.01',
#  'funny.s.04',
#  'fur-bearing.s.01',
#  'gallant.s.03',
#  'gaumless.s.01',
#  'gay.s.02',
#  'gay.s.05',
#  'general.s.05',
#  'generative.s.02',
#  'generous.s.03',
#  'gentle.s.02',
#  'gentle.s.03',
#  'genuine.s.02',
#  'ghastly.s.01',
#  'ghoulish.s.01',
#  'gilbertian.s.02',
#  'gilded.s.02',
#  'gingery.s.01',
#  'glamorous.s.01',
#  'glib.s.03',
#  'glossy.s.03',
#  'going.s.01',
#  'good-for-nothing.s.01',
#  'good-natured.a.01',
#  'good.a.01',
#  'good.s.06',
#  'good.s.09',
#  'good.s.13',
#  'good.s.15',
#  'good_enough.s.01',
#  'goodish.s.01',
#  'gothic.s.05',
#  'gouty.s.01',
#  'graceless.s.01',
#  'gracious.a.01',
#  'graduate.s.01',
#  'grandiose.s.01',
#  'grapey.s.01',
#  'grateful.s.02',
#  'gratifying.s.01',
#  'grave.s.01',
#  'green.s.04',
#  'grievous.s.02',
#  'groovy.s.02',
#  'grotty.s.01',
#  'grumbling.s.01',
#  'hairy.s.02',
#  'half.s.01',
#  'half.s.02',
#  'halfway.s.03',
#  'hand-to-mouth.s.01',
#  'hands-down.s.01',
#  'hapless.s.01',
#  'hard-fought.s.01',
#  'hard-hitting.s.01',
#  'hard.s.11',
#  'hardscrabble.s.01',
#  'harsh-voiced.s.01',
#  'harsh.s.01',
#  'harsh.s.02',
#  'harsh.s.04',
#  'harsh.s.06',
#  'hateful.a.01',
#  'hateful.s.02',
#  'haunting.s.02',
#  'heady.s.02',
#  'healthy.s.03',
#  'heart-healthy.s.01',
#  'heart-whole.s.01',
#  'heartening.s.01',
#  'heartwarming.s.01',
#  'hearty.s.02',
#  'hearty.s.05',
#  'heaven-sent.s.01',
#  'heavy.a.04',
#  'heavy.s.07',
#  'heavy.s.15',
#  'heavy.s.23',
#  'hedged.s.01',
#  'heightening.s.01',
#  'herculean.s.02',
#  'hideous.s.01',
#  'high-yield.s.01',
#  'high.a.01',
#  'higher.s.01',
#  'higher.s.02',
#  'hilarious.s.01',
#  'hollow.s.02',
#  'homelike.s.01',
#  'homely.s.01',
#  'homing.s.01',
#  'honest.a.01',
#  'honest.s.02',
#  'honorific.s.01',
#  'hopeless.s.04',
#  'horrid.s.01',
#  'hot.s.09',
#  'hot.s.12',
#  'hot.s.15',
#  'huffish.s.01',
#  'huffy.s.01',
#  'humorless.a.01',
#  'humorous.a.01',
#  'hungry.a.01',
#  'hurtful.s.01',
#  'hushed.s.01',
#  'hygroscopic.s.01',
#  'hypnotic.s.02',
#  'hypocritical.s.01',
#  'icky.s.01',
#  'iconoclastic.s.02',
#  'idle.s.03',
#  'idle.s.04',
#  'idyllic.s.02',
#  'ill-fed.s.01',
#  'ill-mannered.s.01',
#  'ill-natured.a.01',
#  'ill.a.01',
#  'ill.s.03',
#  'immoral.a.01',
#  'impelling.s.01',
#  'imperturbable.s.01',
#  'impious.s.02',
#  'impolite.a.01',
#  'important-looking.s.01',
#  'imprecise.a.01',
#  'impressive.a.01',
#  'impressive.s.02',
#  'improbable.s.03',
#  'impudent.s.01',
#  'impugnable.s.01',
#  'in.s.03',
#  'in_evidence.s.01',
#  'inactive.a.07',
#  'incendiary.s.02',
#  'incompetent.s.04',
#  'incomplete.a.01',
#  'inconsistent.a.01',
#  'inconspicuous.a.01',
#  'incorrupt.s.02',
#  'incredible.a.01',
#  'indefinable.s.02',
#  'ineffable.s.02',
#  'ineffective.a.01',
#  'inexplicable.a.01',
#  'inexpressible.a.01',
#  'infelicitous.s.02',
#  'inferential.s.05',
#  'infra_dig.s.01',
#  'ingratiating.s.01',
#  'innocuous.s.02',
#  'inoffensive.a.02',
#  'insalubrious.s.01',
#  'insensible.s.02',
#  'insensitive.a.02',
#  'insidious.s.01',
#  'insignificant.s.02',
#  'insincere.a.01',
#  'insipid.s.02',
#  'inspirational.s.01',
#  'insubstantial.s.02',
#  'integral.s.02',
#  'intense.s.03',
#  'intensifying.a.01',
#  'interesting.a.01',
#  'intimate.s.01',
#  'intriguing.s.02',
#  'invaluable.s.01',
#  'invigorating.a.01',
#  'inviolable.s.03',
#  'irresistible.s.02',
#  'irritating.s.02',
#  'irritating.s.03',
#  'isotonic.s.04',
#  'itchy.s.02',
#  'jesting.s.01',
#  'jilted.s.01',
#  'jingling.s.01',
#  'joyful.a.01',
#  'joyless.a.01',
#  'joyous.a.01',
#  'killing.s.01',
#  'kind.a.01',
#  'kindhearted.s.01',
#  'labor-intensive.s.01',
#  'laic.s.01',
#  'laid-back.s.01',
#  'laid_low.s.01',
#  'laid_up.s.01',
#  'lamenting.s.01',
#  'last.s.07',
#  'latest.s.02',
#  'leaden.s.02',
#  'leaden.s.04',
#  'life-giving.s.01',
#  'light.a.05',
#  'light.s.20',
#  'likely.s.04',
#  'limited.s.04',
#  'limpid.s.03',
#  'little.s.05',
#  'live.s.04',
#  'livelong.s.01',
#  'long-winded.s.01',
#  'long.s.09',
#  'loosely_knit.s.01',
#  'loud-mouthed.s.01',
#  'loud-voiced.s.01',
#  'loud.a.01',
#  'lovable.a.01',
#  'loved.a.01',
#  'loveless.s.02',
#  'low-budget.s.01',
#  'low-cost.s.01',
#  'low-level.s.01',
#  'low.a.01',
#  'low.s.03',
#  'lucky.s.01',
#  'lugubrious.s.01',
#  'lumpish.s.01',
#  'lurid.s.02',
#  'lurid.s.04',
#  'malnourished.a.01',
#  'manky.s.01',
#  'mannerly.s.01',
#  'marked.s.02',
#  'marvelous.s.03',
#  'mathematical.s.03',
#  'meager.a.01',
#  'meaning.s.01',
#  'meaningful.a.01',
#  'meaningless.a.01',
#  'measly.s.01',
#  'meaty.s.02',
#  'mediocre.s.03',
#  'merciful.s.02',
#  'metaphysical.s.02',
#  'meticulous.s.01',
#  'meticulous.s.02',
#  'miasmal.s.01',
#  'microscopic.s.03',
#  'mild-tasting.s.01',
#  'milk-sick.s.01',
#  'mind-boggling.s.01',
#  'mindless.s.01',
#  'mirthless.s.01',
#  'misanthropic.s.02',
#  'miserable.s.05',
#  'misogynous.s.01',
#  'mod.s.01',
#  'moderating.a.01',
#  'moral.a.01',
#  'moralistic.s.01',
#  'morbid.s.01',
#  'mournful.s.01',
#  'moving.a.02',
#  'murmuring.s.01',
#  'murmurous.s.01',
#  'narcotic.s.02',
#  'narcotic.s.03',
#  'nasty.a.01',
#  'nasty.s.02',
#  'natural.a.03',
#  'naughty.s.02',
#  'nauseated.s.01',
#  'nauseating.s.01',
#  'necromantic.s.02',
#  'negative.s.03',
#  'negligible.s.02',
#  'neither.s.01',
#  'nerve-racking.s.01',
#  'nervous.s.01',
#  'newsworthy.s.01',
#  'nice.a.01',
#  'nice.s.03',
#  'nickel-and-dime.s.02',
#  'nippy.s.01',
#  'nitwitted.s.01',
#  'nonabsorbent.a.01',
#  'noninflammatory.s.01',
#  'nonnatural.s.01',
#  'nonproductive.s.01',
#  'nonsense.s.01',
#  'nourished.a.01',
#  'nugatory.s.01',
#  'numinous.s.01',
#  'nut-bearing.s.01',
#  'nutty.s.01',
#  'objectionable.s.01',
#  'obscure.s.01',
#  'obscure.s.05',
#  'oddish.s.01',
#  'off-putting.s.01',
#  'off.s.02',
#  'offending.a.01',
#  'offensive.a.05',
#  'offensive.s.01',
#  'oil-bearing.s.01',
#  'old-maidish.s.01',
#  'old-time.s.01',
#  'on_the_nose.s.01',
#  'open.s.21',
#  'oppressive.s.01',
#  'organic.s.04',
#  'orienting.a.01',
#  'orotund.s.02',
#  'other.s.04',
#  'otiose.s.01',
#  'out.s.07',
#  'outright.s.01',
#  'outstanding.s.02',
#  'oval-fruited.s.01',
#  'overabundant.s.01',
#  'overfed.s.01',
#  'overjoyed.s.01',
#  'overpriced.s.01',
#  'oversensitive.s.01',
#  'overserious.s.01',
#  'pacific.s.03',
#  'pain-free.s.01',
#  'painful.a.01',
#  'painless.a.02',
#  'painless.s.01',
#  'palatable.a.01',
#  'palatial.s.02',
#  'pale.s.04',
#  'pale.s.05',
#  'palsied.s.01',
#  'paradoxical.s.01',
#  'paralytic.s.02',
#  'paraplegic.s.01',
#  'partial.s.01',
#  'passing.s.03',
#  'pasty.s.01',
#  'pathetic.s.02',
#  'pathetic.s.03',
#  'peckish.s.01',
#  'pedestrian.s.01',
#  'peppery.s.01',
#  'pernickety.s.01',
#  'personable.s.01',
#  'persuasive.a.01',
#  'petrifying.s.01',
#  'photogenic.s.01',
#  'physical.s.04',
#  'picaresque.s.01',
#  'piquant.s.01',
#  'piquant.s.02',
#  'pithy.s.01',
#  'plangent.s.01',
#  'plausible.s.02',
#  'pleasant.a.01',
#  'pleasant.s.02',
#  'pleasing.a.01',
#  'plentiful.s.01',
#  'pleonastic.s.01',
#  'po-faced.s.01',
#  'poignant.s.02',
#  'polite.a.01',
#  'ponderous.s.03',
#  'poor.s.06',
#  'precious.s.02',
#  'precise.a.01',
#  'prefaded.s.01',
#  'prehistoric.s.03',
#  'prepossessing.s.01',
#  'presentable.s.01',
#  'presumptive.s.02',
#  'pretty.s.02',
#  'prima_facie.s.01',
#  'prismatic.s.02',
#  'productive.a.01',
#  'profanatory.s.01',
#  'profane.a.02',
#  'prolific.s.02',
#  'prolix.a.01',
#  'promotive.s.01',
#  'propitiative.s.01',
#  'provocative.a.01',
#  'psychedelic.s.02',
#  'pumped-up.s.01',
#  'pungent.s.01',
#  'purposeful.s.02',
#  'pursuant.s.01',
#  'putdownable.s.01',
#  'quaint.s.01',
#  'quaint.s.02',
#  'qualified.a.02',
#  'quasi-religious.s.01',
#  'questionable.a.01',
#  'racking.s.01',
#  'rallying.s.01',
#  'rampant.s.03',
#  'rank.s.02',
#  'rank.s.05',
#  'rare.s.03',
#  'rascally.s.02',
#  'ravaging.s.01',
#  'real.s.03',
#  'reassuring.a.01',
#  'rebarbative.s.01',
#  'receptive.s.04',
#  'reconciled.s.01',
#  'reconstructive.s.01',
#  'red-fruited.s.01',
#  'redeeming.s.02',
#  'reduced.s.02',
#  'regrettable.s.01',
#  'relaxant.s.01',
#  'relaxed.a.01',
#  'religious.s.01',
#  'removed.s.01',
#  'renewing.s.01',
#  'repellent.s.03',
#  'representable.s.01',
#  'resonant.s.01',
#  'respectable.a.01',
#  'respectful.a.01',
#  'reverberant.a.01',
#  'reverend.s.01',
#  'rich.s.03',
#  'rich.s.06',
#  'rich.s.09',
#  'rich.s.11',
#  'rickety.s.02',
#  'right.s.08',
#  'righteous.s.02',
#  'rocky.s.04',
#  'rough-and-ready.s.01',
#  'round-fruited.s.01',
#  'rousing.s.01',
#  'rousing.s.02',
#  'rubber.s.01',
#  'rubbishy.s.01',
#  'rudimentary.s.02',
#  'rugged.s.04',
#  'sacral.s.02',
#  ...]

# %% [markdown]
# Same thing for related adj list from feeling  Nouns

# %%
noun2related_adj_dict22.values()
# Out:
# dict_values([set(), set(), set(), set(), {'fiery', 'ardent', 'perfervid', 'fervent', 'fervid', 'impassioned', 'torrid'}, {'fiery', 'ardent', 'perfervid', 'fervent', 'fervid', 'impassioned', 'torrid'}, {'fiery', 'ardent', 'perfervid', 'fervent', 'fervid', 'impassioned', 'torrid'}, set(), set(), {'shamed', 'hangdog', 'guilty', 'shamefaced', 'sheepish'}, {'shamefaced', 'sheepish'}, {'heavy'}, set(), set(), set(), set(), set(), set(), set(), {'plaintive', 'mournful'}, set(), set(), set(), set(), set(), set(), set(), set(), {'angry'}, {'hotheaded', 'hot-tempered', 'short-tempered', 'choleric', 'quick-tempered', 'irascible'}, set(), set(), set(), set(), set(), set(), {'nervy', 'overstrung', 'edgy', 'jittery', 'restive', 'highly_strung', 'jumpy', 'high-strung', 'uptight'}, {'uneasy'}, set(), set(), set(), set(), set(), set(), set(), set(), {'moody', 'temperamental'}, set(), set(), set(), set(), {'blue', 'down', 'downcast', 'grim', 'depressed', 'downhearted', 'down_in_the_mouth', 'gloomy', 'low', 'low-spirited', 'dispirited'}, {'melancholy', 'somber', 'sombre'}, {'melancholy', 'somber', 'sombre'}, set(), {'aggressive', 'belligerent'}, {'aggressive', 'belligerent'}, {'tender'}, {'tenderhearted'}, {'kind-hearted', 'kindhearted'}, set(), {'uncheerful', 'depressing', 'cheerless'}, {'uncheerful', 'depressing', 'cheerless'}, {'dysphoric', 'unhappy', 'distressed'}, set(), {'protective'}, set(), set(), set(), set(), {'appetent'}, {'appetent'}, {'comfortable'}, set(), set(), set(), {'unhappy'}, {'earnest', 'heartfelt', 'devout', 'dear'}, set(), {'earnest', 'solemn', 'sincere'}, set(), set(), set(), set(), {'unmerciful', 'merciless'}, {'unkind', 'pitiless'}, {'remorseless', 'ruthless', 'pitiless', 'unpitying'}, set(), set(), {'hungry', 'thirsty', 'athirst'}, set(), set(), set(), {'misogynic', 'misogynous', 'misogynistic'}, set(), set(), {'algolagnic'}, set(), set(), set(), {'reverent', 'godly', 'reverential', 'venerating', 'worshipful', 'respectful'}, set(), set(), set(), {'unpleasant'}, set(), set(), {'euphoric'}, set(), {'lachrymose', 'weeping', 'tearful', 'dolourous', 'dolorous'}, set(), set(), {'huffish', 'sulky'}, {'huffish', 'sulky'}, set(), {'solicitous'}, {'hysterical'}, set(), set(), set(), set(), set(), {'optimistic', 'affirmative'}, set(), {'untroubled', 'unafraid', 'secure'}, {'despondent', 'heartsick'}, {'despondent', 'heartsick'}, {'despondent', 'heartsick', 'heartbroken', 'brokenhearted'}, {'disconsolate', 'unconsolable', 'inconsolable'}, set(), set(), set(), set(), set(), set(), set(), {'unagitated', 'tranquil', 'calm', 'serene'}, set(), set(), set(), {'misanthropical', 'misanthropic'}, {'joyous'}, {'joyous'}, {'gleeful', 'jubilant', 'elated', 'joyful'}, {'masochistic'}, set(), set(), set(), {'lonely', 'lonesome'}, set(), set(), set(), set(), set(), set(), set(), {'sedate', 'sincere', 'sober', 'grave', 'solemn', 'earnest'}, {'lovesick'}, set(), {'tetchy', 'techy', 'scratchy', 'nettlesome', 'peckish', 'petulant', 'irritable', 'testy', 'fractious', 'cranky', 'pettish', 'peevish'}, {'feisty', 'thin-skinned', 'touchy', 'huffy'}, {'tetchy', 'techy', 'scratchy', 'nettlesome', 'peckish', 'petulant', 'irritable', 'testy', 'fractious', 'cranky', 'pettish', 'peevish'}, set(), {'tyrannous', 'oppressive', 'tyrannical'}, {'brooding', 'broody', 'reflective', 'meditative', 'ruminative', 'musing', 'contemplative', 'pondering', 'pensive'}, set(), set(), set(), set(), set(), set(), set(), {'empathetic', 'empathic'}, set(), {'self-satisfied', 'complacent', 'self-complacent'}, {'self-satisfied', 'complacent', 'self-complacent'}, {'self-satisfied', 'complacent', 'self-complacent'}, set(), set(), {'titillating', 'erotic'}, {'lustful', 'lusty', 'concupiscent'}, set(), set(), {'scarey', 'shivery', 'chilling', 'shuddery', 'scary'}, set(), set(), {'scarey', 'shivery', 'chilling', 'shuddery', 'scary'}, set(), set(), {'huffish', 'sulky'}, {'huffish', 'sulky'}, set(), set(), set(), set(), set(), set(), set(), set(), set(), set(), {'worried', 'apprehensive'} ...

# %%
noun2related_adj_dict22 = make_noun2related_adj_dict_simple()
adj_yield22 = get_dict_yield(noun2related_adj_dict22)
dd_yield22a = len(adj_yield22)
print(f"noun2related_adj_dict22 has {len(noun2related_adj_dict22)}"\
      f" noun lemmas with {dd_yield22a} related adjectives")
# Out:
# noun2related_adj_dict22 has 856 noun lemmas with 613 related adjectives

# %%
noun2related_adj_dict22
# Out:
# defaultdict(set,
#             {'ardor.n.03.ardor': set(),
#              'ardor.n.03.ardour': set(),
#              'ardor.n.03.fervor': set(),
#              'ardor.n.03.fervour': set(),
#              'ardor.n.03.fervency': {'ardent',
#               'fervent',
#               'fervid',
#               'fiery',
#               'impassioned',
#               'perfervid',
#               'torrid'},
#              'ardor.n.03.fire': {'ardent',
#               'fervent',
#               'fervid',
#               'fiery',
#               'impassioned',
#               'perfervid',
#               'torrid'},
#              'ardor.n.03.fervidness': {'ardent',
#               'fervent',
#               'fervid',
#               'fiery',
#               'impassioned',
#               'perfervid',
#               'torrid'},
#              'worry.n.02.worry': set(),
#              'worry.n.02.trouble': set(),
#              'shamefacedness.n.01.shamefacedness': {'guilty',
#               'hangdog',
#               'shamed',
#               'shamefaced',
#               'sheepish'},
#              'shamefacedness.n.01.sheepishness': {'shamefaced', 'sheepish'},
#              'heaviness.n.02.heaviness': {'heavy'},
#              'gaiety.n.01.gaiety': set(),
#              'gaiety.n.01.merriment': set(),
#              'benevolence.n.01.benevolence': set(),
#              'scunner.n.01.scunner': set(),
#              'stewing.n.01.stewing': set(),
#              'suffering.n.04.suffering': set(),
#              'suffering.n.04.hurt': set(),
#              'plaintiveness.n.01.plaintiveness': {'mournful', 'plaintive'},
#              'dislike.n.02.dislike': set(),
#              'tumult.n.02.tumult': set(),
#              'tumult.n.02.turmoil': set(),
#              'fit.n.01.fit': set(),
#              'fit.n.01.tantrum': set(),
#              'fit.n.01.scene': set(),
#              'fit.n.01.conniption': set(),
#              'comfort.n.05.comfort': set(),
#              'anger.n.01.anger': {'angry'},
#              'anger.n.01.choler': {'choleric',
#               'hot-tempered',
#               'hotheaded',
#               'irascible',
#               'quick-tempered',
#               'short-tempered'},
#              'anger.n.01.ire': set(),
#              'stir.n.02.stir': set(),
#              'pique.n.02.pique': set(),
#              'pique.n.02.temper': set(),
#              'pique.n.02.irritation': set(),
#              'defeatism.n.01.defeatism': set(),
#              'edginess.n.01.edginess': {'edgy',
#               'high-strung',
#               'highly_strung',
#               'jittery',
#               'jumpy',
#               'nervy',
#               'overstrung',
#               'restive',
#               'uptight'},
#              'edginess.n.01.uneasiness': {'uneasy'},
#              'edginess.n.01.inquietude': set(),
#              'edginess.n.01.disquietude': set(),
#              'animosity.n.01.animosity': set(),
#              'animosity.n.01.animus': set(),
#              'animosity.n.01.bad_blood': set(),
#              'good_will.n.03.good_will': set(),
#              'good_will.n.03.goodwill': set(),
#              'temper.n.02.temper': set(),
#              'temper.n.02.mood': {'moody', 'temperamental'},
#              'temper.n.02.humor': set(),
#              'temper.n.02.humour': set(),
#              'agape.n.01.agape': set(),
#              'gloom.n.02.gloom': set(),
#              'gloom.n.02.gloominess': {'blue',
#               'depressed',
#               'dispirited',
#               'down',
#               'down_in_the_mouth',
#               'downcast',
#               'downhearted',
#               'gloomy',
#               'grim',
#               'low',
#               'low-spirited'},
#              'gloom.n.02.somberness': {'melancholy', 'somber', 'sombre'},
#              'gloom.n.02.sombreness': {'melancholy', 'somber', 'sombre'},
#              'fever.n.02.fever': set(),
#              'belligerence.n.01.belligerence': {'aggressive', 'belligerent'},
#              'belligerence.n.01.belligerency': {'aggressive', 'belligerent'},
#              'tenderness.n.03.tenderness': {'tender'},
#              'tenderness.n.03.tenderheartedness': {'tenderhearted'},
#              'kindheartedness.n.01.kindheartedness': {'kind-hearted',
#               'kindhearted'},
#              'kindheartedness.n.01.kind-heartedness': set(),
#              'cheerlessness.n.01.cheerlessness': {'cheerless',
#               'depressing',
#               'uncheerful'},
#              'cheerlessness.n.01.uncheerfulness': {'cheerless',
#               'depressing',
#               'uncheerful'},
#              'dysphoria.n.01.dysphoria': {'distressed',
#               'dysphoric',
#               'unhappy'},
#              'sexual_pleasure.n.01.sexual_pleasure': set(),
#              'protectiveness.n.01.protectiveness': {'protective'},
#              'frustration.n.01.frustration': set(),
#              'frustration.n.01.defeat': set(),
#              'stage_fright.n.01.stage_fright': set(),
#              'appetite.n.01.appetite': set(),
#              'appetite.n.01.appetency': {'appetent'},
#              'appetite.n.01.appetence': {'appetent'},
#              'comfortableness.n.02.comfortableness': {'comfortable'},
#              'annoyance.n.02.annoyance': set(),
#              'annoyance.n.02.chafe': set(),
#              'annoyance.n.02.vexation': set(),
#              'unhappiness.n.02.unhappiness': {'unhappy'},
#              'earnestness.n.01.earnestness': {'dear',
#               'devout',
#               'earnest',
#               'heartfelt'},
#              'earnestness.n.01.seriousness': set(),
#              'earnestness.n.01.sincerity': {'earnest', 'sincere', 'solemn'},
#              'relief.n.01.relief': set(),
#              'relief.n.01.alleviation': set(),
#              'relief.n.01.assuagement': set(),
#              'cruelty.n.02.cruelty': set(),
#              'cruelty.n.02.mercilessness': {'merciless', 'unmerciful'},
#              'cruelty.n.02.pitilessness': {'pitiless', 'unkind'},
#              'cruelty.n.02.ruthlessness': {'pitiless',
#               'remorseless',
#               'ruthless',
#               'unpitying'},
#              'longing.n.01.longing': set(),
#              'longing.n.01.yearning': set(),
#              'longing.n.01.hungriness': {'athirst', 'hungry', 'thirsty'},
#              'wonder.n.01.wonder': set(),
#              'wonder.n.01.wonderment': set(),
#              'wonder.n.01.admiration': set(),
#              'misogyny.n.01.misogyny': {'misogynic',
#               'misogynistic',
#               'misogynous'},
#              'misogyny.n.01.misogynism': set(),
#              'stupefaction.n.01.stupefaction': set(),
#              'algolagnia.n.01.algolagnia': {'algolagnic'},
#              'algolagnia.n.01.algophilia': set(),
#              'anxiety.n.02.anxiety': set(),
#              'fear.n.03.fear': set(),
#              'fear.n.03.reverence': {'godly',
#               'respectful',
#               'reverent',
#               'reverential',
#               'venerating',
#               'worshipful'},
#              'fear.n.03.awe': set(),
#              'fear.n.03.veneration': set(),
#              'dissatisfaction.n.01.dissatisfaction': set(),
#              'unpleasantness.n.01.unpleasantness': {'unpleasant'},
#              'belonging.n.01.belonging': set(),
#              'euphoria.n.01.euphoria': set(),
#              'euphoria.n.01.euphory': {'euphoric'},
#              'guilt_pang.n.01.guilt_pang': set(),
#              'dolor.n.01.dolor': {'dolorous',
#               'dolourous',
#               'lachrymose',
#               'tearful',
#               'weeping'},
#              'dolor.n.01.dolour': set(),
#              'shadow.n.04.shadow': set(),
#              'sulk.n.01.sulk': {'huffish', 'sulky'},
#              'sulk.n.01.sulkiness': {'huffish', 'sulky'},
#              'solicitude.n.01.solicitude': set(),
#              'solicitude.n.01.solicitousness': {'solicitous'},
#              'hysteria.n.02.hysteria': {'hysterical'},
#              'penis_envy.n.01.penis_envy': set(),
#              'civic_pride.n.01.civic_pride': set(),
#              'civic_pride.n.01.civic_spirit': set(),
#              'urge.n.02.urge': set(),
#              'urge.n.02.itch': set(),
#              'optimism.n.01.optimism': {'affirmative', 'optimistic'},
#              'intoxication.n.03.intoxication': set(),
#              'security.n.03.security': {'secure', 'unafraid', 'untroubled'},
#              'despondency.n.01.despondency': {'despondent', 'heartsick'},
#              'despondency.n.01.despondence': {'despondent', 'heartsick'},
#              'despondency.n.01.heartsickness': {'brokenhearted',
#               'despondent',
#               'heartbroken',
#               'heartsick'},
#              'despondency.n.01.disconsolateness': {'disconsolate',
#               'inconsolable',
#               'unconsolable'},
#              'wish.n.01.wish': set(),
#              'wish.n.01.wishing': set(),
#              'wish.n.01.want': set(),
#              'entrancement.n.01.entrancement': set(),
#              'entrancement.n.01.ravishment': set(),
#              'favor.n.04.favor': set(),
#              'favor.n.04.favour': set(),
#              'calmness.n.03.calmness': {'calm',
#               'serene',
#               'tranquil',
#               'unagitated'},
#              'compunction.n.01.compunction': set(),
#              'compunction.n.01.remorse': set(),
#              'compunction.n.01.self-reproach': set(),
#              'misanthropy.n.01.misanthropy': {'misanthropic',
#               'misanthropical'},
#              'joy.n.01.joy': {'joyous'},
#              'joy.n.01.joyousness': {'joyous'},
#              'joy.n.01.joyfulness': {'elated',
#               'gleeful',
#               'joyful',
#               'jubilant'},
#              'masochism.n.01.masochism': {'masochistic'},
#              'amicability.n.01.amicability': set(),
#              'amicability.n.01.amicableness': set(),
#              'forlornness.n.01.forlornness': set(),
#              'forlornness.n.01.loneliness': {'lonely', 'lonesome'},
#              'forlornness.n.01.desolation': set(),
#              'sensation.n.03.sensation': set(),
#              'horror.n.01.horror': set(),
#              'gratification.n.01.gratification': set(),
#              'gratification.n.01.satisfaction': set(),
#              'pride.n.02.pride': set(),
#              'gravity.n.03.gravity': set(),
#              'gravity.n.03.solemnity': {'earnest',
#               'grave',
#               'sedate',
#               'sincere',
#               'sober',
#               'solemn'},
#              'lovesickness.n.01.lovesickness': {'lovesick'},
#              'encouragement.n.03.encouragement': set(),
#              'testiness.n.01.testiness': {'cranky',
#               'fractious',
#               'irritable',
#               'nettlesome',
#               'peckish',
#               'peevish',
#               'pettish',
#               'petulant',
#               'scratchy',
#               'techy',
#               'testy',
#               'tetchy'},
#              'testiness.n.01.touchiness': {'feisty',
#               'huffy',
#               'thin-skinned',
#               'touchy'},
#              'testiness.n.01.tetchiness': {'cranky',
#               'fractious',
#               'irritable',
#               'nettlesome',
#               'peckish',
#               'peevish',
#               'pettish',
#               'petulant',
#               'scratchy',
#               'techy',
#               'testy',
#               'tetchy'},
#              'oppression.n.03.oppression': set(),
#              'oppression.n.03.oppressiveness': {'oppressive',
#               'tyrannical',
#               'tyrannous'},
#              'pensiveness.n.01.pensiveness': {'brooding',
#               'broody',
#               'contemplative',
#               'meditative',
#               'musing',
#               'pensive',
#               'pondering',
#               'reflective',
#               'ruminative'},
#              'pensiveness.n.01.brooding': set(),
#              'gloat.n.01.gloat': set(),
#              'gloat.n.01.gloating': set(),
#              'gloat.n.01.glee': set(),
#              'nirvana.n.01.nirvana': set(),
#              'nirvana.n.01.enlightenment': set(),
#              'broken_heart.n.01.broken_heart': set(),
#              'empathy.n.01.empathy': {'empathetic', 'empathic'},
#              'titillation.n.01.titillation': set(),
#              'complacency.n.01.complacency': {'complacent',
#               'self-complacent',
#               'self-satisfied'},
#              'complacency.n.01.complacence': {'complacent',
#               'self-complacent',
#               'self-satisfied'},
#              'complacency.n.01.self-complacency': {'complacent',
#               'self-complacent',
#               'self-satisfied'},
#              'complacency.n.01.self-satisfaction': set(),
#              'sexual_desire.n.01.sexual_desire': set(),
#              'sexual_desire.n.01.eros': {'erotic', 'titillating'},
#              'sexual_desire.n.01.concupiscence': {'concupiscent',
#               'lustful',
#               'lusty'},
#              'sexual_desire.n.01.physical_attraction': set(),
#              'frisson.n.01.frisson': set(),
#              'frisson.n.01.shiver': {'chilling',
#               'scarey',
#               'scary',
#               'shivery',
#               'shuddery'},
#              'frisson.n.01.chill': set(),
#              'frisson.n.01.quiver': set(),
#              'frisson.n.01.shudder': {'chilling',
#               'scarey',
#               'scary',
#               'shivery',
#               'shuddery'},
#              'frisson.n.01.thrill': set(),
#              'frisson.n.01.tingle': set(),
#              'sulkiness.n.02.sulkiness': {'huffish', 'sulky'},
#              'sulkiness.n.02.huffishness': {'huffish', 'sulky'},
#              'surprise.n.01.surprise': set(),
#              'bang.n.04.bang': set(),
#              'bang.n.04.boot': set(),
#              'bang.n.04.charge': set(),
#              'bang.n.04.rush': set(),
#              'bang.n.04.flush': set(),
#              'bang.n.04.thrill': set(),
#              'bang.n.04.kick': set(),
#              'despair.n.02.despair': set(),
#              'apprehension.n.01.apprehension': set(),
#              'apprehension.n.01.apprehensiveness': {'apprehensive', 'worried'},
#              'apprehension.n.01.dread': {'awful',
#               'dire',
#               'direful',
#               'dread',
#               'dreaded',
#               'dreadful',
#               'fearful',
#               'fearsome',
#               'frightening',
#               'horrendous',
#               'horrific',
#               'terrible'},
#              'state.n.06.state': set(),
#              'sensuousness.n.01.sensuousness': {'sensuous'},
#              'frustration.n.03.frustration': set(),
#              'mercifulness.n.01.mercifulness': {'merciful'},
#              'mercifulness.n.01.mercy': set(),
#              'fondness.n.01.fondness': {'fond', 'partial'},
#              'fondness.n.01.fancy': set(),
#              'fondness.n.01.partiality': set(),
#              'hesitance.n.01.hesitance': {'hesitant', 'hesitating'},
#              'hesitance.n.01.hesitancy': {'hesitant', 'hesitating'},
#              'sensitivity.n.03.sensitivity': {'sensitive'},
#              'sensitivity.n.03.sensitiveness': {'sensitive'},
#              'misology.n.01.misology': set(),
#              'wildness.n.01.wildness': {'wild'},
#              'wildness.n.01.abandon': set(),
#              'jocundity.n.01.jocundity': {'gay',
#               'jocund',
#               'jolly',
#               'jovial',
#               'merry',
#               'mirthful'},
#              'jocundity.n.01.jocularity': {'jesting',
#               'jocose',
#               'jocular',
#               'joking'},
#              'nostalgia.n.01.nostalgia': {'nostalgic'},
#              'hero_worship.n.01.hero_worship': set(),
#              'willies.n.01.willies': set(),
#              'passion.n.01.passion': set(),
#              'passion.n.01.passionateness': {'passionate'},
#              'survivor_guilt.n.01.survivor_guilt': set(),
#              'american_dream.n.01.American_Dream': set(),
#              'triumph.n.02.triumph': {'exultant',
#               'exulting',
#               'jubilant',
#               'prideful',
#               'rejoicing',
#               'triumphal',
#               'triumphant'},
#              'sanguinity.n.01.sanguinity': {'sanguine'},
#              'sanguinity.n.01.sanguineness': {'sanguine'},
#              'anxiousness.n.02.anxiousness': {'anxious',
#               'nervous',
#               'queasy',
#               'uneasy',
#               'unquiet'},
#              'anxiousness.n.02.disquiet': set(),
#              'foreboding.n.01.foreboding': set(),
#              'foreboding.n.01.premonition': set(),
#              'foreboding.n.01.presentiment': set(),
#              'foreboding.n.01.boding': set(),
#              'intimidation.n.02.intimidation': set(),
#              'soul.n.03.soul': set(),
#              'soul.n.03.soulfulness': {'soulful'},
#              'dolefulness.n.01.dolefulness': {'doleful', 'mournful'},
#              'sentimentality.n.02.sentimentality': {'sentimental'},
#              'electra_complex.n.01.Electra_complex': set(),
#              'oversensitiveness.n.01.oversensitiveness': {'oversensitive'},
#              'hankering.n.01.hankering': set(),
#              'hankering.n.01.yen': set(),
#              'exhilaration.n.01.exhilaration': set(),
#              'exhilaration.n.01.excitement': set(),
#              'approbation.n.01.approbation': set(),
#              'world-weariness.n.01.world-weariness': {'bored', 'world-weary'},
#              'world-weariness.n.01.Weltschmerz': set(),
#              'disinclination.n.01.disinclination': set(),
#              'mellowness.n.01.mellowness': {'mellow', 'mellowed'},
#              'bloodlust.n.01.bloodlust': set(),
#              'sorrow.n.01.sorrow': set(),
#              'angst.n.01.angst': set(),
#              'anguish.n.01.anguish': set(),
#              'anguish.n.01.torment': set(),
#              'anguish.n.01.torture': set(),
#              'caprice.n.01.caprice': {'capricious', 'impulsive', 'whimsical'},
#              'caprice.n.01.impulse': set(),
#              'caprice.n.01.whim': set(),
#              'faintness.n.01.faintness': {'faint',
#               'light',
#               'light-headed',
#               'lightheaded',
#               'swooning'},
#              'undertow.n.01.undertow': set(),
#              'joylessness.n.01.joylessness': {'joyless'},
#              'hope.n.02.hope': set(),
#              'embitterment.n.01.embitterment': set(),
#              'glow.n.04.glow': set(),
#              'devotion.n.01.devotion': set(),
#              'devotion.n.01.devotedness': {'devoted'},
#              'meekness.n.01.meekness': {'meek', 'mild', 'modest', 'tame'},
#              'meekness.n.01.submission': set(),
#              'mourning.n.01.mourning': set(),
#              'mourning.n.01.bereavement': set(),
#              'amusement.n.01.amusement': set(),
#              'infuriation.n.01.infuriation': set(),
#              'infuriation.n.01.enragement': set(),
#              'downheartedness.n.01.downheartedness': {'blue',
#               'depressed',
#               'dispirited',
#               'down',
#               'down_in_the_mouth',
#               'downcast',
#               'downhearted',
#               'gloomy',
#               'grim',
#               'low',
#               'low-spirited'},
#              'downheartedness.n.01.dejectedness': set(),
#              'downheartedness.n.01.low-spiritedness': {'blue',
#               'depressed',
#               'dispirited',
#               'down',
#               'down_in_the_mouth',
#               'downcast',
#               'downhearted',
#               'gloomy',
#               'grim',
#               'low',
#               'low-spirited'},
#              'downheartedness.n.01.lowness': {'blue',
#               'broken',
#               'crushed',
#               'depressed',
#               'dispirited',
#               'down',
#               'down_in_the_mouth',
#               'downcast',
#               'downhearted',
#               'gloomy',
#               'grim',
#               'humbled',
#               'humiliated',
#               'low',
#               'low-spirited'},
#              'downheartedness.n.01.dispiritedness': {'blue',
#               'depressed',
#               'dispirited',
#               'down',
#               'down_in_the_mouth',
#               'downcast',
#               'downhearted',
#               'gloomy',
#               'grim',
#               'listless',
#               'low',
#               'low-spirited'},
#              'intimidation.n.03.intimidation': set(),
#              'electricity.n.03.electricity': {'electric'},
#              'heartstrings.n.01.heartstrings': set(),
#              'sensuality.n.01.sensuality': {'animal',
#               'carnal',
#               'fleshly',
#               'sensual'},
#              'sensuality.n.01.sensualness': {'animal',
#               'carnal',
#               'fleshly',
#               'sensual',
#               'sultry'},
#              'sensuality.n.01.sensualism': set(),
#              'gratitude.n.01.gratitude': set(),
#              'fatigue.n.03.fatigue': set(),
#              'maleficence.n.01.maleficence': {'maleficent'},
#              'growing_pains.n.02.growing_pains': set(),
#              'covetousness.n.01.covetousness': set(),
#              'discomfiture.n.01.discomfiture': set(),
#              'discomfiture.n.01.discomposure': set(),
#              'discomfiture.n.01.disconcertion': set(),
#              'discomfiture.n.01.disconcertment': set(),
#              'pessimism.n.01.pessimism': {'pessimistic'},
#              'attrition.n.03.attrition': set(),
#              'attrition.n.03.contrition': set(),
#              'attrition.n.03.contriteness': {'contrite',
#               'remorseful',
#               'rueful',
#               'ruthful'},
#              'misoneism.n.01.misoneism': set(),
#              'diffidence.n.01.diffidence': {'diffident',
#               'shy',
#               'timid',
#               'unsure'},
#              'diffidence.n.01.self-doubt': set(),
#              'diffidence.n.01.self-distrust': set(),
#              'self-esteem.n.01.self-esteem': set(),
#              'self-esteem.n.01.self-pride': set(),
#              'liking.n.01.liking': set(),
#              'grudge.n.01.grudge': set(),
#              'grudge.n.01.score': set(),
#              'grudge.n.01.grievance': set(),
#              'guilt.n.02.guilt': {'guilty', 'hangdog', 'shamed', 'shamefaced'},
#              'guilt.n.02.guilty_conscience': set(),
#              'guilt.n.02.guilt_feelings': set(),
#              'guilt.n.02.guilt_trip': set(),
#              'love.n.01.love': set(),
#              'depression.n.04.depression': set(),
#              'sadism.n.01.sadism': {'sadistic'},
#              'umbrage.n.01.umbrage': {'incensed',
#               'indignant',
#               'outraged',
#               'umbrageous'},
#              'umbrage.n.01.offense': set(),
#              'umbrage.n.01.offence': set(),
#              'vindictiveness.n.01.vindictiveness': {'despiteful',
#               'revengeful',
#               'spiteful',
#               'vengeful',
#               'vindictive'},
#              'vindictiveness.n.01.vengefulness': {'revengeful',
#               'vengeful',
#               'vindictive'},
#              'anglophobia.n.01.Anglophobia': {'Anglophobic'},
#              'razbliuto.n.01.razbliuto': set(),
#              'discomfort.n.02.discomfort': set(),
#              'discomfort.n.02.soreness': {'afflictive',
#               'huffy',
#               'mad',
#               'painful',
#               'sore'},
#              'discomfort.n.02.irritation': set(),
#              'chagrin.n.01.chagrin': set(),
#              'chagrin.n.01.humiliation': set(),
#              'chagrin.n.01.mortification': set(),
#              'mental_anguish.n.01.mental_anguish': set(),
#              'repugnance.n.01.repugnance': {'abhorrent',
#               'detestable',
#               'obscene',
#               'repugnant',
#               'repulsive'},
#              'repugnance.n.01.repulsion': set(),
#              'repugnance.n.01.revulsion': set(),
#              'repugnance.n.01.horror': set(),
#              'antagonism.n.03.antagonism': {'antagonistic'},
#              'satisfaction.n.01.satisfaction': set(),
#              'stomach.n.03.stomach': set(),
#              'antipathy.n.01.antipathy': {'antagonistic',
#               'antipathetic',
#               'antipathetical',
#               'averse',
#               'indisposed',
#               'loath',
#               'loth'},
#              'antipathy.n.01.aversion': set(),
#              'antipathy.n.01.distaste': set(),
#              'sentiment.n.01.sentiment': {'bathetic',
#               'drippy',
#               'hokey',
#               'kitschy',
#               'maudlin',
#               'mawkish',
#               'mushy',
#               'schmaltzy',
#               'schmalzy',
#               'sentimental',
#               'slushy',
#               'soppy',
#               'soupy'},
#              'unassertiveness.n.01.unassertiveness': {'unassertive'},
#              'chill.n.04.chill': set(),
#              'chill.n.04.pall': set(),
#              'eagerness.n.01.eagerness': {'eager'},
#              'eagerness.n.01.avidity': {'avid', 'zealous'},
#              'eagerness.n.01.avidness': {'avid', 'zealous'},
#              'eagerness.n.01.keenness': set(),
#              'leaning.n.01.leaning': set(),
#              'leaning.n.01.propensity': set(),
#              'leaning.n.01.tendency': set(),
#              'passion.n.05.passion': set(),
#              'filial_love.n.01.filial_love': set(),
#              'insecurity.n.02.insecurity': {'insecure'},
#              'anglophilia.n.01.Anglophilia': {'Anglophilic'},
#              'misery.n.02.misery': set(),
#              'philhellenism.n.01.philhellenism': set(),
#              'abhorrence.n.01.abhorrence': {'abhorrent',
#               'detestable',
#               'obscene',
#               'repugnant',
#               'repulsive'},
#              'abhorrence.n.01.abomination': set(),
#              'abhorrence.n.01.detestation': set(),
#              'abhorrence.n.01.execration': set(),
#              'abhorrence.n.01.loathing': set(),
#              'abhorrence.n.01.odium': {'abominable',
#               'detestable',
#               'execrable',
#               'odious'},
#              'resentment.n.01.resentment': set(),
#              'resentment.n.01.bitterness': {'bitter'},
#              'resentment.n.01.gall': set(),
#              'resentment.n.01.rancor': {'rancorous'},
#              'resentment.n.01.rancour': set(),
#              'blessedness.n.01.blessedness': {'blessed'},
#              'blessedness.n.01.beatitude': set(),
#              'blessedness.n.01.beatification': set(),
#              'pet.n.03.pet': set(),
#              'bonheur.n.01.bonheur': set(),
#              'helplessness.n.03.helplessness': {'helpless', 'lost'},
#              'tsoris.n.01.tsoris': set(),
#              'ambivalence.n.01.ambivalence': {'ambivalent'},
#              'ambivalence.n.01.ambivalency': set(),
#              'cheerfulness.n.02.cheerfulness': {'cheerful',
#               'pollyannaish',
#               'upbeat'},
#              'cheerfulness.n.02.blitheness': {'cheerful',
#               'pollyannaish',
#               'upbeat'},
#              'bad_temper.n.01.bad_temper': set(),
#              'bad_temper.n.01.ill_temper': set(),
#              'happiness.n.02.happiness': {'happy'},
#              'self-torture.n.01.self-torture': set(),
#              'self-torture.n.01.self-torment': set(),
#              'mysophilia.n.01.mysophilia': set(),
#              'puppy_love.n.01.puppy_love': set(),
#              'puppy_love.n.01.calf_love': set(),
#              'puppy_love.n.01.crush': set(),
#              'puppy_love.n.01.infatuation': set(),
#              'confusion.n.03.confusion': set(),
#              'confusion.n.03.discombobulation': set(),
#              'velleity.n.01.velleity': set(),
#              'admiration.n.01.admiration': set(),
#              'admiration.n.01.esteem': set(),
#              'shame.n.01.shame': set(),
#              'oedipus_complex.n.01.Oedipus_complex': set(),
#              'oedipus_complex.n.01.Oedipal_complex': set(),
#              'buoyancy.n.01.buoyancy': {'buoyant', 'chirpy', 'perky'},
#              'buoyancy.n.01.perkiness': {'buoyant', 'chirpy', 'perky'},
#              'peace.n.03.peace': set(),
#              'peace.n.03.peacefulness': set(),
#              'peace.n.03.peace_of_mind': set(),
#              'peace.n.03.repose': set(),
#              'peace.n.03.serenity': set(),
#              'peace.n.03.heartsease': set(),
#              'peace.n.03.ataraxis': set(),
#              'amour_propre.n.01.amour_propre': set(),
#              'amour_propre.n.01.conceit': set(),
#              'amour_propre.n.01.self-love': set(),
#              'amour_propre.n.01.vanity': {'conceited',
#               'egotistic',
#               'egotistical',
#               'self-conceited',
#               'swollen',
#               'swollen-headed',
#               'vain'},
#              'scruple.n.02.scruple': {'scrupulous'},
#              'scruple.n.02.qualm': set(),
#              'scruple.n.02.misgiving': set(),
#              'hostility.n.03.hostility': {'hostile'},
#              'hostility.n.03.enmity': {'inimical', 'unfriendly'},
#              'hostility.n.03.ill_will': set(),
#              'technophobia.n.01.technophobia': set(),
#              'despisal.n.01.despisal': set(),
#              'despisal.n.01.despising': set(),
#              'inclination.n.05.inclination': set(),
#              'embarrassment.n.02.embarrassment': set(),
#              'heartburning.n.01.heartburning': set(),
#              'attachment.n.01.attachment': set(),
#              'attachment.n.01.fond_regard': set(),
#              'approval.n.02.approval': set(),
#              'distance.n.04.distance': {'aloof', 'distant', 'upstage'},
#              'distance.n.04.aloofness': set(),
#              'suspense.n.03.suspense': set(),
#              'feelings.n.01.feelings': set(),
#              'good_humor.n.01.good_humor': set(),
#              'good_humor.n.01.good_humour': set(),
#              'good_humor.n.01.good_temper': set(),
#              'good_humor.n.01.amiability': {'affable',
#               'amiable',
#               'cordial',
#               'genial',
#               'good-humored',
#               'good-humoured'},
#              'levity.n.01.levity': set(),
#              'soft_spot.n.02.soft_spot': set(),
#              'distress.n.01.distress': set(),
#              'distress.n.01.hurt': set(),
#              'distress.n.01.suffering': set(),
#              'consolation.n.01.consolation': set(),
#              'consolation.n.01.solace': set(),
#              'consolation.n.01.solacement': set(),
#              'resignation.n.01.resignation': set(),
#              'resignation.n.01.surrender': set(),
#              'regard.n.06.regard': set(),
#              'regard.n.06.respect': set(),
#              'unrest.n.02.unrest': set(),
#              'daze.n.01.daze': set(),
#              'daze.n.01.shock': set(),
#              'daze.n.01.stupor': set(),
#              'prurience.n.01.prurience': {'lubricious',
#               'lustful',
#               'prurient',
#               'salacious'},
#              'prurience.n.01.pruriency': {'lubricious',
#               'lustful',
#               'prurient',
#               'salacious'},
#              'prurience.n.01.lasciviousness': {'lascivious',
#               'lewd',
#               'libidinous',
#               'lustful'},
#              'prurience.n.01.carnality': {'animal',
#               'carnal',
#               'fleshly',
#               'sensual'},
#              'prurience.n.01.lubricity': set(),
#              'huffiness.n.01.huffiness': {'feisty',
#               'huffy',
#               'mad',
#               'sore',
#               'thin-skinned',
#               'touchy'},
#              'satyriasis.n.01.satyriasis': set(),
#              'comfort.n.02.comfort': set(),
#              'ego.n.01.ego': set(),
#              'ego.n.01.egotism': {'conceited',
#               'egotistic',
#               'egotistical',
#               'self-conceited',
#               'swollen',
#               'swollen-headed',
#               'vain'},
#              'ego.n.01.self-importance': {'arrogant',
#               'chesty',
#               'self-important'},
#              'mournfulness.n.01.mournfulness': {'doleful',
#               'mournful',
#               'plaintive'},
#              'mournfulness.n.01.sorrowfulness': {'sorrowful'},
#              'mournfulness.n.01.ruthfulness': {'contrite',
#               'remorseful',
#               'rueful',
#               'ruthful'},
#              'amorousness.n.01.amorousness': {'amative', 'amorous'},
#              'amorousness.n.01.enamoredness': {'enamored',
#               'in_love',
#               'infatuated',
#               'potty',
#               'smitten',
#               'soft_on',
#               'taken_with'},
#              'buck_fever.n.01.buck_fever': set(),
#              'schadenfreude.n.01.Schadenfreude': set(),
#              'exultation.n.01.exultation': set(),
#              'exultation.n.01.jubilance': {'elated',
#               'exultant',
#               'exulting',
#               'gleeful',
#               'joyful',
#               'jubilant',
#               'prideful',
#               'rejoicing',
#               'triumphal',
#               'triumphant'},
#              'exultation.n.01.jubilancy': {'elated',
#               'exultant',
#               'exulting',
#               'gleeful',
#               'joyful',
#               'jubilant',
#               'prideful',
#               'rejoicing',
#               'triumphal',
#               'triumphant'},
#              'exultation.n.01.jubilation': set(),
#              'affection.n.01.affection': set(),
#              'affection.n.01.affectionateness': {'affectionate',
#               'fond',
#               'lovesome',
#               'tender',
#               'warm'},
#              'affection.n.01.fondness': {'affectionate',
#               'fond',
#               'lovesome',
#               'tender',
#               'warm'},
#              'affection.n.01.tenderness': {'affectionate',
#               'fond',
#               'lovesome',
#               'tender',
#               'warm'},
#              'affection.n.01.heart': {'hearty'},
#              'affection.n.01.warmness': {'affectionate',
#               'fond',
#               'lovesome',
#               'tender',
#               'warm'},
#              'affection.n.01.warmheartedness': {'warmhearted'},
#              'affection.n.01.philia': set(),
#              'weight.n.05.weight': {'weighty'},
#              'discouragement.n.01.discouragement': set(),
#              'discouragement.n.01.disheartenment': set(),
#              'discouragement.n.01.dismay': set(),
#              'apathy.n.01.apathy': {'apathetic', 'indifferent'},
#              'sadness.n.02.sadness': {'sad'},
#              'sadness.n.02.sorrow': set(),
#              'sadness.n.02.sorrowfulness': {'sorrowful'},
#              'cold_comfort.n.01.cold_comfort': set(),
#              'ingratitude.n.01.ingratitude': set(),
#              'ingratitude.n.01.ungratefulness': {'thankless',
#               'ungrateful',
#               'unthankful'},
#              'libido.n.01.libido': {'lascivious',
#               'lewd',
#               'libidinal',
#               'libidinous',
#               'lustful'},
#              'addiction.n.02.addiction': set(),
#              'unfriendliness.n.01.unfriendliness': {'inimical', 'unfriendly'},
#              'weakness.n.05.weakness': set(),
#              'wistfulness.n.01.wistfulness': {'pensive', 'wistful'},
#              'anaphrodisia.n.01.anaphrodisia': set(),
#              'emotion.n.01.emotion': {'emotional'},
#              'misogamy.n.01.misogamy': set(),
#              'demoralization.n.03.demoralization': set(),
#              'demoralization.n.03.demoralisation': set(),
#              'compassion.n.01.compassion': set(),
#              'compassion.n.01.compassionateness': {'compassionate'},
#              'self-pity.n.01.self-pity': set(),
#              'emulation.n.01.emulation': set(),
#              'moroseness.n.01.moroseness': {'dark',
#               'dour',
#               'glowering',
#               'glum',
#               'moody',
#               'morose',
#               'saturnine',
#               'sour',
#               'sullen'},
#              'moroseness.n.01.glumness': {'dark',
#               'dour',
#               'glowering',
#               'glum',
#               'moody',
#               'morose',
#               'saturnine',
#               'sour',
#               'sullen'},
#              'moroseness.n.01.sullenness': {'heavy',
#               'lowering',
#               'sullen',
#               'threatening'},
#              'humility.n.02.humility': set(),
#              'humility.n.02.humbleness': set(),
#              'gusto.n.01.gusto': set(),
#              'gusto.n.01.relish': set(),
#              'gusto.n.01.zest': {'barmy', 'yeasty', 'zestful', 'zesty'},
#              'gusto.n.01.zestfulness': {'barmy', 'yeasty', 'zestful', 'zesty'},
#              'sorrow.n.02.sorrow': set(),
#              'sorrow.n.02.regret': set(),
#              'sorrow.n.02.rue': set(),
#              'sorrow.n.02.ruefulness': {'contrite',
#               'remorseful',
#               'rueful',
#               'ruthful'},
#              'disgust.n.01.disgust': set(),
#              'suspense.n.01.suspense': set(),
#              'embarrassment.n.01.embarrassment': set(),
#              'lecherousness.n.01.lecherousness': {'lecherous'},
#              'lecherousness.n.01.lust': {'concupiscent', 'lustful', 'lusty'},
#              'lecherousness.n.01.lustfulness': {'concupiscent',
#               'lascivious',
#               'lewd',
#               'libidinous',
#               'lubricious',
#               'lustful',
#               'lusty',
#               'prurient',
#               'salacious'},
#              'love.n.04.love': set(),
#              'love.n.04.sexual_love': set(),
#              'love.n.04.erotic_love': set(),
#              'nausea.n.02.nausea': {'loathsome',
#               'nauseating',
#               'nauseous',
#               'noisome',
#               'offensive',
#               'queasy',
#               'sickening',
#               'vile'},
#              'philogyny.n.01.philogyny': set(),
#              'pleasantness.n.01.pleasantness': {'pleasant'},
#              'lovingness.n.01.lovingness': {'loving'},
#              'lovingness.n.01.caring': {'caring'},
#              'tranquillity.n.02.tranquillity': {'placid',
#               'quiet',
#               'smooth',
#               'still',
#               'tranquil',
#               'unruffled'},
#              'tranquillity.n.02.tranquility': {'placid',
#               'quiet',
#               'smooth',
#               'still',
#               'tranquil',
#               'unruffled'},
#              'tranquillity.n.02.quietness': {'placid',
#               'quiet',
#               'smooth',
#               'still',
#               'tranquil',
#               'unruffled'},
#              'tranquillity.n.02.quietude': set(),
#              'thing.n.11.thing': set(),
#              'elation.n.02.elation': set(),
#              'elation.n.02.high_spirits': set(),
#              'elation.n.02.lightness': {'light'},
#              'peeve.n.01.peeve': set(),
#              'smugness.n.01.smugness': {'self-satisfied', 'smug'},
#              'astonishment.n.01.astonishment': set(),
#              'astonishment.n.01.amazement': set(),
#              'hopelessness.n.01.hopelessness': {'hopeless'},
#              'inferiority_complex.n.01.inferiority_complex': set(),
#              'impatience.n.02.impatience': {'impatient', 'raring'},
#              'gratefulness.n.01.gratefulness': {'grateful', 'thankful'},
#              'gratefulness.n.01.thankfulness': {'grateful', 'thankful'},
#              'gratefulness.n.01.appreciativeness': {'appreciative'},
#              'poignance.n.01.poignance': {'poignant'},
#              'poignance.n.01.poignancy': {'poignant'},
#              'boredom.n.01.boredom': set(),
#              'boredom.n.01.ennui': set(),
#              'boredom.n.01.tedium': {'boring',
#               'deadening',
#               'dull',
#               'ho-hum',
#               'irksome',
#               'slow',
#               'tedious',
#               'tiresome',
#               'wearisome'},
#              'sadomasochism.n.01.sadomasochism': {'sadomasochistic'},
#              'concern.n.03.concern': set(),
#              'class_feeling.n.01.class_feeling': set(),
#              'worship.n.02.worship': set(),
#              'worship.n.02.adoration': set(),
#              'conscience.n.03.conscience': {'conscientious'},
#              'hopefulness.n.02.hopefulness': {'hopeful'},
#              'rejoicing.n.01.rejoicing': set(),
#              'shyness.n.01.shyness': {'diffident', 'shy', 'timid', 'unsure'},
#              'indignation.n.01.indignation': set(),
#              'indignation.n.01.outrage': set(),
#              'carefreeness.n.01.carefreeness': {'carefree',
#               'devil-may-care',
#               'freewheeling',
#               'happy-go-lucky',
#               'harum-scarum',
#               'slaphappy'},
#              'carefreeness.n.01.insouciance': {'casual',
#               'insouciant',
#               'nonchalant'},
#              'carefreeness.n.01.lightheartedness': {'blithe',
#               'blithesome',
#               'light-hearted',
#               'lighthearted',
#               'lightsome'},
#              'carefreeness.n.01.lightsomeness': {'blithe',
#               'blithesome',
#               'light-hearted',
#               'lighthearted',
#               'lightsome'},
#              'agony.n.01.agony': {'agonal'},
#              'agony.n.01.torment': set(),
#              'agony.n.01.torture': {'agonising',
#               'agonizing',
#               'excruciating',
#               'harrowing',
#               'torturesome',
#               'torturing',
#               'torturous'},
#              'temptation.n.02.temptation': set(),
#              'anticipation.n.01.anticipation': set(),
#              'anticipation.n.01.expectancy': {'anticipant',
#               'anticipative',
#               'expectant'},
#              'creeps.n.02.creeps': set(),
#              'self-depreciation.n.01.self-depreciation': set(),
#              'moodiness.n.01.moodiness': {'dark',
#               'dour',
#               'glowering',
#               'glum',
#               'moody',
#               'morose',
#               'saturnine',
#               'sour',
#               'sullen'},
#              'envy.n.01.envy': set(),
#              'envy.n.01.enviousness': {'covetous', 'envious', 'jealous'},
#              'happiness.n.01.happiness': {'felicitous', 'happy'},
#              'happiness.n.01.felicity': {'felicitous', 'happy'},
#              'pining.n.01.pining': set(),
#              'ardor.n.01.ardor': set(),
#              'ardor.n.01.ardour': set(),
#              'ardor.n.01.elan': set(),
#              'ardor.n.01.zeal': {'avid', 'zealous'},
#              'fear.n.01.fear': set(),
#              'fear.n.01.fearfulness': {'fearful'},
#              'fear.n.01.fright': set(),
#              'hope.n.01.hope': set(),
#              'fearlessness.n.01.fearlessness': {'audacious',
#               'brave',
#               'dauntless',
#               'fearless',
#               'hardy',
#               'intrepid',
#               'unafraid',
#               'unfearing'},
#              'fearlessness.n.01.bravery': set(),
#              'timidity.n.01.timidity': {'timid'},
#              'timidity.n.01.timidness': {'diffident',
#               'faint',
#               'faint-hearted',
#               'fainthearted',
#               'shy',
#               'timid',
#               'unsure'},
#              'timidity.n.01.timorousness': {'faint',
#               'faint-hearted',
#               'fainthearted',
#               'timid'},
#              'acquired_taste.n.01.acquired_taste': set(),
#              'desire.n.01.desire': set(),
#              'technophilia.n.01.technophilia': set(),
#              'infatuation.n.01.infatuation': set(),
#              'fidget.n.01.fidget': {'antsy', 'fidgety', 'fretful', 'itchy'},
#              'fidget.n.01.fidgetiness': {'antsy',
#               'fidgety',
#               'fretful',
#               'itchy'},
#              'fidget.n.01.restlessness': set(),
#              'agape.n.02.agape': set(),
#              'agape.n.02.agape_love': set(),
#              'homesickness.n.01.homesickness': {'homesick'},
#              'disappointment.n.01.disappointment': set(),
#              'disappointment.n.01.letdown': set(),
#              'self-consciousness.n.01.self-consciousness': {'self-conscious'},
#              'self-consciousness.n.01.uneasiness': {'awkward',
#               'ill_at_ease',
#               'uneasy'},
#              'self-consciousness.n.01.uncomfortableness': {'uncomfortable'},
#              'withdrawal.n.04.withdrawal': set(),
#              'withdrawal.n.04.detachment': set(),
#              'storminess.n.02.storminess': {'stormy', 'tempestuous'},
#              'brotherhood.n.03.brotherhood': set(),
#              'fury.n.01.fury': {'angered',
#               'enraged',
#               'furious',
#               'infuriated',
#               'maddened'},
#              'fury.n.01.rage': set(),
#              'fury.n.01.madness': {'huffy', 'mad', 'sore'},
#              'displeasure.n.01.displeasure': set(),
#              'unconcern.n.02.unconcern': set(),
#              'confidence.n.02.confidence': {'confidential'},
#              'wrath.n.01.wrath': set(),
#              'swivet.n.01.swivet': set(),
#              'misocainea.n.01.misocainea': set(),
#              'devastation.n.02.devastation': set(),
#              'quality_of_life.n.01.quality_of_life': set(),
#              'gladness.n.01.gladness': {'beaming', 'glad'},
#              'gladness.n.01.gladfulness': set(),
#              'gladness.n.01.gladsomeness': {'gladsome'},
#              'emotionlessness.n.01.emotionlessness': {'emotionless',
#               'passionless'},
#              'emotionlessness.n.01.impassivity': {'impassive', 'stolid'},
#              'emotionlessness.n.01.impassiveness': {'deadpan',
#               'expressionless',
#               'impassive',
#               'poker-faced',
#               'stolid',
#               'unexpressive'},
#              'emotionlessness.n.01.phlegm': {'phlegmatic', 'phlegmatical'},
#              'emotionlessness.n.01.indifference': set(),
#              'emotionlessness.n.01.stolidity': {'impassive', 'stolid'},
#              'emotionlessness.n.01.unemotionality': set(),
#              'nationalism.n.03.nationalism': set(),
#              'the_hots.n.01.the_hots': set(),
#              'jollity.n.01.jollity': {'gay',
#               'jocund',
#               'jolly',
#               'jovial',
#               'merry',
#               'mirthful'},
#              'jollity.n.01.jolliness': {'gay',
#               'jocund',
#               'jolly',
#               'jovial',
#               'merry',
#               'mirthful'},
#              'jollity.n.01.joviality': {'gay',
#               'jocund',
#               'jolly',
#               'jovial',
#               'merry',
#               'mirthful'},
#              'aphrodisia.n.01.aphrodisia': set(),
#              'languor.n.02.languor': set(),
#              'languor.n.02.lassitude': set(),
#              'languor.n.02.listlessness': {'dispirited', 'listless'},
#              'jitteriness.n.01.jitteriness': {'edgy',
#               'high-strung',
#               'highly_strung',
#               'jittery',
#               'jumpy',
#               'nervy',
#               'overstrung',
#               'restive',
#               'uptight'},
#              'jitteriness.n.01.jumpiness': {'edgy',
#               'high-strung',
#               'highly_strung',
#               'jittery',
#               'jumpy',
#               'nervy',
#               'overstrung',
#               'restive',
#               'uptight'},
#              'jitteriness.n.01.nervousness': {'aflutter',
#               'anxious',
#               'nervous',
#               'queasy',
#               'uneasy',
#               'unquiet'},
#              'jitteriness.n.01.restiveness': {'edgy',
#               'high-strung',
#               'highly_strung',
#               'jittery',
#               'jumpy',
#               'nervy',
#               'overstrung',
#               'restive',
#               'uptight'},
#              'ecstasy.n.01.ecstasy': {'ecstatic',
#               'enraptured',
#               'rapt',
#               'rapturous',
#               'rhapsodic'},
#              'ecstasy.n.01.rapture': {'ecstatic',
#               'enraptured',
#               'rapt',
#               'rapturous',
#               'rhapsodic'},
#              'ecstasy.n.01.transport': set(),
#              'ecstasy.n.01.exaltation': set(),
#              'ecstasy.n.01.raptus': set(),
#              'nymphomania.n.01.nymphomania': {'nymphomaniac',
#               'nymphomaniacal'},
#              'sadness.n.01.sadness': {'sad'},
#              'sadness.n.01.unhappiness': {'distressed',
#               'dysphoric',
#               'unhappy'},
#              'closeness.n.01.closeness': {'close'},
#              'closeness.n.01.intimacy': set(),
#              'contempt.n.01.contempt': {'contemptuous',
#               'disdainful',
#               'insulting',
#               'scornful'},
#              'contempt.n.01.disdain': set(),
#              'contempt.n.01.scorn': set(),
#              'contempt.n.01.despite': set(),
#              'mawkishness.n.01.mawkishness': {'bathetic',
#               'drippy',
#               'hokey',
#               'kitschy',
#               'maudlin',
#               'mawkish',
#               'mushy',
#               'schmaltzy',
#               'schmalzy',
#               'sentimental',
#               'slushy',
#               'soppy',
#               'soupy'},
#              'mawkishness.n.01.bathos': set(),
#              'exuberance.n.01.exuberance': {'ebullient',
#               'exuberant',
#               'high-spirited'},
#              'disgruntlement.n.01.disgruntlement': set(),
#              'alienation.n.01.alienation': set(),
#              'alienation.n.01.disaffection': set(),
#              'alienation.n.01.estrangement': set(),
#              'indifference.n.01.indifference': {'immaterial',
#               'indifferent',
#               'unbiased',
#               'unbiassed'},
#              'captivation.n.02.captivation': set(),
#              'captivation.n.02.enchantment': set(),
#              'captivation.n.02.enthrallment': set(),
#              'captivation.n.02.fascination': set(),
#              'pleasure.n.01.pleasure': set(),
#              'pleasure.n.01.pleasance': {'pleasant'},
#              'enthusiasm.n.01.enthusiasm': {'enthusiastic'},
#              'zeal.n.02.zeal': {'avid', 'zealous'},
#              'aggravation.n.01.aggravation': set(),
#              'aggravation.n.01.exasperation': set(),
#              'agitation.n.03.agitation': set(),
#              'softheartedness.n.01.softheartedness': {'soft-boiled',
#               'softhearted'},
#              'softheartedness.n.01.tenderness': {'tender'},
#              'scare.n.02.scare': {'chilling',
#               'scarey',
#               'scary',
#               'shivery',
#               'shuddery'},
#              'scare.n.02.panic_attack': set(),
#              'irritability.n.01.irritability': {'cranky',
#               'fractious',
#               'irritable',
#               'nettlesome',
#               'peckish',
#               'peevish',
#               'pettish',
#               'petulant',
#               'scratchy',
#               'techy',
#               'testy',
#               'tetchy'},
#              'irritability.n.01.crossness': set(),
#              'irritability.n.01.fretfulness': {'fretful',
#               'querulous',
#               'whiney',
#               'whiny'},
#              'irritability.n.01.fussiness': {'bad-tempered',
#               'crabbed',
#               'crabby',
#               'cross',
#               'fussy',
#               'grouchy',
#               'grumpy',
#               'ill-tempered'},
#              'irritability.n.01.peevishness': {'cranky',
#               'fractious',
#               'irritable',
#               'nettlesome',
#               'peckish',
#               'peevish',
#               'pettish',
#               'petulant',
#               'scratchy',
#               'techy',
#               'testy',
#               'tetchy'},
#              'irritability.n.01.petulance': {'cranky',
#               'fractious',
#               'irritable',
#               'nettlesome',
#               'peckish',
#               'peevish',
#               'pettish',
#               'petulant',
#               'scratchy',
#               'techy',
#               'testy',
#               'tetchy'},
#              'irritability.n.01.choler': set(),
#              'sweet_tooth.n.01.sweet_tooth': set(),
#              'misopedia.n.01.misopedia': set(),
#              'aggression.n.02.aggression': set(),
#              'aggression.n.02.aggressiveness': set(),
#              'ambition.n.01.ambition': {'ambitious', 'challenging'},
#              'ambition.n.01.aspiration': set(),
#              'ambition.n.01.dream': set(),
#              'woe.n.02.woe': set(),
#              'woe.n.02.woefulness': {'woebegone', 'woeful'},
#              'sex.n.03.sex': {'aphrodisiac', 'aphrodisiacal', 'sexy'},
#              'sex.n.03.sexual_urge': set(),
#              'warmheartedness.n.01.warmheartedness': {'warmhearted'},
#              'warmheartedness.n.01.warmth': set(),
#              'pain.n.02.pain': set(),
#              'pain.n.02.painfulness': {'afflictive', 'painful', 'sore'},
#              'contentment.n.01.contentment': set(),
#              'conflict.n.02.conflict': set(),
#              'abashment.n.01.abashment': set(),
#              'abashment.n.01.bashfulness': {'bashful'},
#              'grief.n.01.grief': set(),
#              'grief.n.01.heartache': set(),
#              'grief.n.01.heartbreak': set(),
#              'grief.n.01.brokenheartedness': {'brokenhearted',
#               'heartbroken',
#               'heartsick'},
#              'hilarity.n.01.hilarity': {'hilarious',
#               'screaming',
#               'uproarious'},
#              'hilarity.n.01.mirth': set(),
#              'hilarity.n.01.mirthfulness': {'amusing',
#               'comic',
#               'comical',
#               'funny',
#               'gay',
#               'jocund',
#               'jolly',
#               'jovial',
#               'laughable',
#               'merry',
#               'mirthful',
#               'risible'},
#              'hilarity.n.01.glee': set(),
#              'hilarity.n.01.gleefulness': {'elated',
#               'gleeful',
#               'joyful',
#               'jubilant'},
#              'repentance.n.01.repentance': {'penitent', 'repentant'},
#              'repentance.n.01.penitence': {'penitent',
#               'penitential',
#               'penitentiary',
#               'repentant'},
#              'repentance.n.01.penance': set(),
#              'panic.n.01.panic': {'frightened',
#               'panic-stricken',
#               'panic-struck',
#               'panicked',
#               'panicky',
#               'terrified'},
#              'panic.n.01.terror': set(),
#              'panic.n.01.affright': set(),
#              'amorousness.n.02.amorousness': {'amatory',
#               'amorous',
#               'romantic'},
#              'amorousness.n.02.eroticism': set(),
#              'amorousness.n.02.erotism': set(),
#              'amorousness.n.02.sexiness': {'aphrodisiac',
#               'aphrodisiacal',
#               'sexy'},
#              'amorousness.n.02.amativeness': {'amative', 'amorous'},
#              'afterglow.n.02.afterglow': set(),
#              'delight.n.01.delight': set(),
#              'delight.n.01.delectation': set(),
#              'insight.n.02.insight': set(),
#              'insight.n.02.perceptiveness': {'perceptive'},
#              'insight.n.02.perceptivity': {'perceptive'},
#              'wound.n.03.wound': set(),
#              'friendliness.n.01.friendliness': {'favorable',
#               'friendly',
#               'well-disposed'},
#              'placidity.n.01.placidity': set(),
#              'placidity.n.01.placidness': {'equable',
#               'even-tempered',
#               'good-tempered',
#               'placid',
#               'quiet',
#               'smooth',
#               'still',
#               'tranquil',
#               'unruffled'},
#              'joie_de_vivre.n.01.joie_de_vivre': set(),
#              'gaiety.n.02.gaiety': set(),
#              'gaiety.n.02.playfulness': {'playful'},
#              'stomach.n.04.stomach': set(),
#              'sinking.n.03.sinking': set(),
#              'sinking.n.03.sinking_feeling': set(),
#              'melancholy.n.01.melancholy': set(),
#              'concern.n.02.concern': set(),
#              'concern.n.02.care': set(),
#              'concern.n.02.fear': set(),
#              'weepiness.n.01.weepiness': {'weepy'},
#              'weepiness.n.01.tearfulness': {'dolorous',
#               'dolourous',
#               'lachrymose',
#               'tearful',
#               'weeping'},
#              'loyalty.n.02.loyalty': set(),
#              'dander.n.02.dander': set(),
#              'dander.n.02.hackles': set(),
#              'commiseration.n.01.commiseration': set(),
#              'commiseration.n.01.pity': {'hapless',
#               'miserable',
#               'misfortunate',
#               'pathetic',
#               'piteous',
#               'pitiable',
#               'pitiful',
#               'poor',
#               'wretched'},
#              'commiseration.n.01.ruth': set(),
#              'commiseration.n.01.pathos': {'hapless',
#               'miserable',
#               'misfortunate',
#               'pathetic',
#               'piteous',
#               'pitiable',
#               'pitiful',
#               'poor',
#               'wretched'},
#              'ardor.n.02.ardor': set(),
#              'ardor.n.02.ardour': set(),
#              'dudgeon.n.01.dudgeon': set(),
#              'dudgeon.n.01.high_dudgeon': set(),
#              'jealousy.n.01.jealousy': set(),
#              'jealousy.n.01.green-eyed_monster': set(),
#              'murderousness.n.01.murderousness': {'homicidal', 'murderous'},
#              'pride.n.01.pride': set(),
#              'pride.n.01.pridefulness': {'exultant',
#               'exulting',
#               'jubilant',
#               'prideful',
#               'rejoicing',
#               'triumphal',
#               'triumphant'},
#              'isolation.n.02.isolation': set(),
#              'enjoyment.n.01.enjoyment': set(),
#              'silver_lining.n.01.silver_lining': set(),
#              'silver_lining.n.01.bright_side': set(),
#              'sympathy.n.02.sympathy': {'sympathetic'},
#              'sympathy.n.02.fellow_feeling': set(),
#              'throes.n.01.throes': set(),
#              'creepy-crawlies.n.01.creepy-crawlies': set(),
#              'conditioned_emotional_response.n.01.conditioned_emotional_response': set(),
#              'conditioned_emotional_response.n.01.CER': set(),
#              'conditioned_emotional_response.n.01.conditioned_emotion': set(),
#              'disapproval.n.01.disapproval': set(),
#              'wishfulness.n.01.wishfulness': {'desirous', 'wishful'},
#              'malevolence.n.01.malevolence': {'malevolent'},
#              'malevolence.n.01.malignity': set(),
#              'heartlessness.n.01.heartlessness': {'hardhearted', 'heartless'},
#              'heartlessness.n.01.coldheartedness': {'coldhearted'},
#              'heartlessness.n.01.hardheartedness': {'hardhearted',
#               'heartless',
#               'stonyhearted',
#               'unfeeling'},
#              'irascibility.n.01.irascibility': {'choleric',
#               'hot-tempered',
#               'hotheaded',
#               'irascible',
#               'quick-tempered',
#               'short-tempered'},
#              'irascibility.n.01.short_temper': set(),
#              'irascibility.n.01.spleen': {'bristly',
#               'prickly',
#               'splenetic',
#               'waspish'},
#              'irascibility.n.01.quick_temper': set(),
#              'compatibility.n.01.compatibility': set(),
#              'alarm.n.01.alarm': set(),
#              'alarm.n.01.dismay': set(),
#              'alarm.n.01.consternation': set(),
#              'gold_fever.n.01.gold_fever': set(),
#              'malice.n.01.malice': {'malicious'},
#              'malice.n.01.maliciousness': {'malicious'},
#              'malice.n.01.spite': set(),
#              'malice.n.01.spitefulness': {'despiteful',
#               'spiteful',
#               'vindictive'},
#              'malice.n.01.venom': {'poisonous', 'venomous', 'vicious'},
#              'affect.n.01.affect': {'affectional', 'affective', 'emotive'},
#              'fulfillment.n.01.fulfillment': set(),
#              'fulfillment.n.01.fulfilment': set(),
#              'ill_humor.n.01.ill_humor': set(),
#              'ill_humor.n.01.ill_humour': set(),
#              'ill_humor.n.01.distemper': set(),
#              'pang.n.01.pang': set(),
#              'pang.n.01.stab': set(),
#              'pang.n.01.twinge': set(),
#              'awe.n.01.awe': set(),
#              'beneficence.n.01.beneficence': {'beneficent'},
#              'lividity.n.01.lividity': {'livid'},
#              'expectation.n.03.expectation': set(),
#              'coolness.n.01.coolness': {'cool'},
#              'coolness.n.01.imperturbability': {'imperturbable',
#               'unflappable'},
#              'coolness.n.01.imperturbableness': {'imperturbable',
#               'unflappable'},
#              'sensibility.n.02.sensibility': set(),
#              'cynicism.n.01.cynicism': set(),
#              'preference.n.01.preference': set(),
#              'preference.n.01.penchant': set(),
#              'preference.n.01.predilection': set(),
#              'preference.n.01.taste': set(),
#              'languor.n.01.languor': set(),
#              'languor.n.01.dreaminess': {'dreamy',
#               'lackadaisical',
#               'languid',
#               'languorous',
#               'moony',
#               'woolgathering'},
#              'trepidation.n.01.trepidation': set(),
#              'blahs.n.01.blahs': set(),
#              'togetherness.n.01.togetherness': {'together'},
#              'hate.n.01.hate': set(),
#              'hate.n.01.hatred': set(),
#              'heavyheartedness.n.01.heavyheartedness': {'heavyhearted'},
#              'forgiveness.n.01.forgiveness': set(),
#              'presage.n.01.presage': set(),
#              'self-disgust.n.01.self-disgust': set(),
#              'self-disgust.n.01.self-hatred': set(),
#              'craving.n.01.craving': set(),
#              'easiness.n.01.easiness': {'easy'},
#              'easiness.n.01.relaxation': set(),
#              'dignity.n.01.dignity': set(),
#              'dignity.n.01.self-respect': set(),
#              'dignity.n.01.self-regard': set(),
#              'dignity.n.01.self-worth': set(),
#              'radiance.n.03.radiance': set(),
#              'discontentment.n.01.discontentment': set(),
#              'discontentment.n.01.discontent': {'discontent', 'discontented'},
#              'discontentment.n.01.discontentedness': {'discontent',
#               'discontented'},
#              'warpath.n.01.warpath': set(),
#              'fetish.n.01.fetish': set(),
#              'complex.n.03.complex': set(),
#              'harassment.n.01.harassment': set(),
#              'harassment.n.01.torment': set(),
#              'cold_feet.n.01.cold_feet': set(),
#              'emotional_state.n.01.emotional_state': set(),
#              'emotional_state.n.01.spirit': set()})

# %%
rel_adjs_22 = [wn.synset(adj) for adj_list in noun2related_adj_dict22.values() for adj in adj_list]
extended_rel_adjs_22 = sorted(list({ss2.name() for ss in rel_adjs_22 for ss2 in get_wheels_and_axle(ss,return_set=True)}))
print(len(rel_adjs_22),len(extended_rel_adjs_22))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[316], line 1
# ----> 1 rel_adjs_22 = [wn.synset(adj) for adj_list in noun2related_adj_dict22.values() for adj in adj_list]
#       2 extended_rel_adjs_22 = sorted(list({ss2.name() for ss in rel_adjs_22 for ss2 in get_wheels_and_axle(ss,return_set=True)}))
#       3 print(len(rel_adjs_22),len(extended_rel_adjs_22))
#
# File ~/opt/anaconda3/envs/p312/lib/python3.12/site-packages/nltk/corpus/reader/wordnet.py:1509, in WordNetCorpusReader.synset(self, name)
#    1507 def synset(self, name):
#    1508     # split name into lemma, part of speech and synset number
# -> 1509     lemma, pos, synset_index_str = name.lower().rsplit(".", 2)
#    1510     synset_index = int(synset_index_str) - 1
#    1512     # get the offset for this synset
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %% [markdown]
# ## Abortive fe relation expriment
#
# Thoughts while compiling the fe list below:
#
# 1.  Medical frames out.  The only interesting case to think about  was Ailment->Medical_Condition->cold.n
#
#
#     I have a cold.
#
#
#     Why is this not an expressive? (On the most natural content, it is prompted by tbe speaker's
#     own internal perceptions.  Are we taking the line that it may be prompted by those perceptions
#     [miserable headache] but is not a report of those perceptions?)
#
# 2.  Cognizer_agent -> Seeking -> feel.v (for), listen (for), dig (for). ThisWhy not an expressive. is the case to wonder 'bout:
#
#     a.  I'm digging for worms.
#     b.  Shh!  I'm listening for termites.
#
#     Why not an expressive?  Especially b.  A report on an internal state.  Why is it descriptive/ascriptve
#     rather than depictive?
#
# 3.  Faculty -> Grasp -> see.v
#
#     I don't see what you're getting at.
#
#     Report on cognitive state.  No perceptual, emotional, surprise.  This is the heart of it.  Within
#     cognitive states we make a distinction between those that are wriggling to get out (internal to external
#     moment) and those that are not (grasping, understanding).  The resultant state is internal?  Grasping
#     leads to further thought.  Surprise leads to a gasp.
#
# 4. Expression -> {Emotion_heat,Facial_expression}
#
#    The former is a bunch of verbs, the latter a bunch of nouns.  Consider
#
#    I'm seething.
#
#    Not an expressive.  On the following grounds:  Most natural context is when speaker has
#    just been asked how they are feeling about X.  In part because X has to be salient for this
#    sentence to be natural.  But on the line where the property of being usable as an expressive
#    is gradable, this is an indicator:  Dependent on prior contextual setup.  In others
#    the word prefers contexts in which a description has been called for, and is used to
#    supply one.
#
# 5. Information -> Trust -> trust.v
#
#    a.  I trust you.
#    b.  I trust John.
#
#    (a) seems very likely to be an expression of an emotional state, one which could
#    result in greater bonding with the addressee; (b) certainly can be a description,
#    so can (a), especially in a context inviting affirmation ("Will you let me handle this?")
#
# 6.  Judge -> {Rashnessness, Volubility}
#
#     The *Rashness* frame has no expressives but has a lot of clear cases of adjectives imposing
#     an external perspective on empotional states: *impatient.a, impetuous.a, rash.a*.  Ditto
#     *Volubility* (*chatterbox, voluble,  terse*).

# %%
# A cobbled together list of FEs with known expressive frames
fe_string = \
"""
Cognizer,Cognizer_1,Cognizer_2,Cognizer_agent,Cognizers,Communicator,Complainer,Conveyed_emotion,
Desirability,Desirable_action,Desirable_situation,Desired_goal,Desired_state_of_affairs,Emotional_state,
Emotion,Expectation,Expected_entity,Expected_event,Expected_request,Experience,Experiencer,
Expressor,Faculty,Interested_party,Means_of_communication,Mental_content,Message,Opinion,
Requirement,Responsible_party,Seeker,Sentient_entity,Sleep_state,Speaker,Stimulus,Supporter
"""
fe_list = fe_string.replace("\n","").split(",")

#  The fes that brought these up are very noisy so just use the frames directly.
expr_frame_list = "Trust Importance Cognitive_impact Regard Estimating Be_in_agreement_on_assessment Catastrophe Desirable_event".split()

# %%
from collections import defaultdict
expressive_fes2frames_dict = defaultdict(set)
for fe_name in fe_list:
    expressive_fes2frames_dict[fe_name]
for fr in expr_frame_list:
    expressive_fes2frames_dict["Dummy_fe"].add(fr)

def collect_expressive_frames(expressive_frames_dict, lexical_frames_only=False):
    fe_set = set(expressive_frames_dict.keys())
    frame_lex_dict = defaultdict(set)
    frame_fe_dict = defaultdict(set)
    for frame in fn.frames():
        if lexical_frames_only and len(frame.lexUnit) == 0:
            continue
        try:
            frame_fes = frame.FE
        except:
            continue
        for fe in fe_set:
            if fe in frame_fes and frame_fes[fe].coreType != "Extra-Thematic":
                expressive_frames_dict[fe].add(frame.name)
                frame_lex_dict[frame.name].update(frame.lexUnit.keys())
                frame_fe_dict[frame.name].add(fe)
    return frame_lex_dict,frame_fe_dict

frame_lex_dict0,frame_fe_dict = collect_expressive_frames(expressive_fes2frames_dict)

expressive_frame_yield = {frame for fe,frame_set in expressive_fes2frames_dict.items() for frame in frame_set}
expressive_fes_yield = {lu for frame in expressive_frame_yield for lu in fn.frame(frame).lexUnit}
print(len(expressive_fes_yield))
#expressive_fes_yield
# Out:
# 2391

# %%
import datetime

def get_ex (ex0):
    try:
        part1 = f"> {ex0['LU'].name} {ex0['frame'].name} corp{ex0['corpID']}_doc{ex0['docID']}_sent{ex0['sentNo']}_para{ex0['paragNo']}_aPos{ex0['aPos']}"
    except KeyError:
        part1 = f"> {ex0['LU'].name} {ex0['frame'].name}"
    start,end = ex0.frameAnnotation.Target[0]
    text = ex0.frameAnnotation.text  
    part2 = text[:start]+ "<" + ex0.frameAnnotation.text[start:end] + ">" + text[end:]
    return "\n".join([part1,part2+"\n"])

def write_minicorpus (frame_lex_dict,fn0,max_ex=20):
    today = datetime.date.today().__str__()
    filename = f"{fn0}_{today}.txt"
    ctr_lex,ctr_fm,ctr22=0,0,0
    with open(filename,'w') as ofh:
        for fm,lexset in frame_lex_dict.items():
            ctr_fm+=1
            for lex in lexset:
                ctr_lex += 1
                lu = fn.frame(fm).lexUnit[lex]
                for ex in lu.exemplars[:max_ex]:
                    ctr22 += 1
                    if ctr22%50 == 0:
                        print(f"{ctr_fm} frames {ctr_lex} LUs {ctr22} examples")
                    try:
                        print(get_ex(ex),file=ofh)
                    except:
                        print(f"bad ex {ctr22}")
                        print("\n", file=ofh)

def write_frame_corpus (frame_name, max_ex=20):
    today = datetime.date.today().__str__()
    filename = f"{frame_name}_minicorpus_{today}.txt"
    ctr_lex, ctr22=0,0
    frame = fn.frame(frame_name)
    with open(filename,'w') as ofh:
        LUs = frame.lexUnit
        for lex in LUs:
            ctr_lex += 1
            lu = LUs[lex]
            for ex in lu.exemplars[:max_ex]:
                ctr22 += 1
                if ctr22%50 == 0:
                    print(f"{ctr_lex} LUs {ctr22} examples")
                try:
                    print(get_ex(ex),file=ofh)
                except:
                    print(f"bad ex {ctr22}")
                    print("\n", file=ofh)

# %%
write_frame_corpus ("Experiencer_focus", max_ex=20)
# Out:
# 4 LUs 50 examples
# 6 LUs 100 examples
# 9 LUs 150 examples
# 11 LUs 200 examples
# 14 LUs 250 examples
# 16 LUs 300 examples
# 19 LUs 350 examples
# 23 LUs 400 examples
# 25 LUs 450 examples
# 28 LUs 500 examples
# 31 LUs 550 examples
# 33 LUs 600 examples
# 38 LUs 650 examples
# 40 LUs 700 examples
# 65 LUs 750 examples

# %%
write_frame_corpus ("Stimulus_focus", max_ex=20)
# Out:
# 3 LUs 50 examples
# 8 LUs 100 examples
# 10 LUs 150 examples
# 15 LUs 200 examples
# 21 LUs 250 examples
# 26 LUs 300 examples
# 28 LUs 350 examples
# 32 LUs 400 examples
# 35 LUs 450 examples
# 37 LUs 500 examples
# 40 LUs 550 examples
# 42 LUs 600 examples
# 46 LUs 650 examples
# 49 LUs 700 examples
# 52 LUs 750 examples
# 55 LUs 800 examples
# 59 LUs 850 examples
# 61 LUs 900 examples
# 65 LUs 950 examples
# 69 LUs 1000 examples
# 72 LUs 1050 examples
# 74 LUs 1100 examples
# 77 LUs 1150 examples
# 80 LUs 1200 examples
# 83 LUs 1250 examples
# 86 LUs 1300 examples
# 88 LUs 1350 examples
# 91 LUs 1400 examples
# 93 LUs 1450 examples
# 96 LUs 1500 examples
# 100 LUs 1550 examples
# 103 LUs 1600 examples
# 106 LUs 1650 examples
# 110 LUs 1700 examples
# 114 LUs 1750 examples
# 119 LUs 1800 examples
# 122 LUs 1850 examples
# 124 LUs 1900 examples
# 127 LUs 1950 examples
# 130 LUs 2000 examples
# 133 LUs 2050 examples
# 137 LUs 2100 examples
# 139 LUs 2150 examples
# 142 LUs 2200 examples
# 144 LUs 2250 examples
# 150 LUs 2300 examples
# 154 LUs 2350 examples
# 156 LUs 2400 examples

# %%
bad_frames = "Achieving_first Adducing Adding_up Age".split()
for fm in bad_frames:
    try:
        del frame_lex_dict0[fm]
    except:
        continue
write_minicorpus (frame_lex_dict0,"fe_driven_frame_collection")

# %%
ex0 = exemplars[0]

# %%
ex0.keys()
# Out:
# dict_keys(['corpID', 'docID', 'sentNo', 'paragNo', 'aPos', 'ID', '_type', 'annotationSet', '_ascii', 'text', 'POS', 'POS_tagset', 'frameAnnotation', 'Target', 'FE', 'GF', 'PT', 'Other', 'Sent', 'Verb', 'LU', 'frame'])

# %% [markdown]
# The following set is largely noise but there are some words we want we lose by not doiing
# the recursiove parent-child link descent (e.g., execellent.a, fantastic.a).  We should
# capture these by frame by frame stipulation unless there are fe-based generalizations
# that work better:

# %%
Experiencer_focus_words - expressive_fes_yield
# Out:
# {'ablution.n',
#  'acquiesce.v',
#  'affray.n',
#  'aim.n',
#  'aim.v',
#  'airman.n',
#  'altercation.n',
#  'average.a',
#  'awesome.a',
#  'awful.a',
#  'bathe.v',
#  'battle.n',
#  'battle.v',
#  'beautiful.a',
#  'belligerent.n',
#  'bent.a',
#  'best thing since sliced bread.n',
#  'bout.n',
#  'brawl.n',
#  'brawl.v',
#  'brush [hair].v',
#  'brush [teeth].v',
#  'bw.n',
#  'capitulate.v',
#  'cave in.v',
#  'cave.v',
#  'clash.n',
#  'clash.v',
#  'cleanse.v',
#  'combat.n',
#  'combatant.n',
#  'commando.n',
#  'common.a',
#  'compromise.v',
#  'conflict.n',
#  'confront.v',
#  'confrontation.n',
#  'control.v',
#  'crap.n',
#  'crappy.a',
#  'cw.n',
#  'depend.v',
#  'dependence.n',
#  'dependency.n',
#  'desirable.a',
#  'determined.a',
#  'donnybrook.n',
#  'duel.n',
#  'duel.v',
#  'dust-up.n',
#  'elegant.a',
#  'enemy.n',
#  'engagement.n',
#  'excellence.n',
#  'excellent.a',
#  'execrable.a',
#  'extraordinary.a',
#  'fabulous.a',
#  'facial.n',
#  'fair.a',
#  'fantastic.a',
#  'fight.n',
#  'fight.v',
#  'fighter.n',
#  'fighting.n',
#  'file.v',
#  'fire fighting.n',
#  'firefight.n',
#  'first-rate.a',
#  'fistfight.n',
#  'floss.v',
#  'fold [to demands].v',
#  'fracas.n',
#  'fray.n',
#  'free-for-all.n',
#  'friendly.n',
#  'function.n',
#  'gain ground.idio',
#  'garbage.n',
#  'gem.n',
#  'give in.v',
#  'give way.v',
#  'goal.n',
#  'gold.n',
#  'great.a',
#  'groom.v',
#  'guerrilla.n',
#  'gunfight.n',
#  'gunner.n',
#  'handsome.a',
#  'hideous.a',
#  'hostile.a',
#  'hostile.n',
#  'hostility.n',
#  'humble.a',
#  'idyllic.a',
#  'in demand.a',
#  'in order.adv',
#  'in.a',
#  'incredible.a',
#  'infantryman.n',
#  'inferior.a',
#  'infighting.n',
#  'intend.v',
#  'intent.a',
#  'intention.n',
#  'junk.n',
#  'killer.a',
#  'lame.a',
#  'lamer.n',
#  'lave.v',
#  'left.a',
#  'lovely.a',
#  'magnificent.a',
#  'manicure.n',
#  'manicure.v',
#  'marine.n',
#  'marvellous.a',
#  'mediocre.a',
#  'melee.n',
#  'militant.n',
#  'moisturize.v',
#  'nasty.a',
#  'object.n',
#  'objective.n',
#  'okay.a',
#  'outstanding.a',
#  'pedestrian.a',
#  'pedicure.n',
#  'plait.v',
#  'plan.n',
#  'plan.v',
#  'plebeian.a',
#  'pluck.v',
#  'poor.a',
#  'popular.a',
#  'program.n',
#  'project.n',
#  'proletarian.a',
#  'protest.n',
#  'protest.v',
#  'protester.n',
#  'purpose.n',
#  'relent.v',
#  'reliance.n',
#  'rely.v',
#  'remain.v',
#  'remainder.n',
#  'rock.v',
#  'rotten.a',
#  'row.n',
#  'sailor.n',
#  'scheme.n',
#  'scuffle.n',
#  'scuffle.v',
#  'second-rate.a',
#  'sensational.a',
#  'service member.n',
#  'shampoo.v',
#  'shave.v',
#  'shit.n',
#  'shitty.a',
#  'shootout.n',
#  'showdown.n',
#  'shower.v',
#  'signaller.n',
#  'skirmish.n',
#  'skirmish.v',
#  'sniper.n',
#  'so-so.a',
#  'soap.v',
#  'soldier.n',
#  'spat.n',
#  'splendid.a',
#  'squabble.n',
#  'stalemate.n',
#  'standoff.n',
#  'standout.n',
#  'strife.n',
#  'struggle.n',
#  'struggle.v',
#  'stupendous.a',
#  'style.n',
#  'submit.v',
#  'substandard.a',
#  'suck.v',
#  'super.a',
#  'superb.a',
#  'superlative.a',
#  'tackle.v',
#  'target.n',
#  'tasty.a',
#  'terrible.a',
#  'terrific.a',
#  'third-rate.a',
#  'tiff.n',
#  'tip-top.a',
#  'tolerable.a',
#  'top-notch.a',
#  'tremendous.a',
#  'troop.n',
#  'tussle.n',
#  'ugly.a',
#  'uncool.a',
#  'unfortunate.a',
#  'upper-class.a',
#  'use.n',
#  'vulgar.a',
#  'war.n',
#  'war.v',
#  'warfare.n',
#  'wash.v',
#  'wax.v',
#  'well.adv',
#  'wonderful.a',
#  'working-class.a',
#  'worthless.a',
#  'wrangling.n',
#  'yield.v'}

# %%
for frame in expressive_fes2frames_dict["Unwanted_characteristics"]:
    print(fn.frame(frame),end="\n\n")
# Out:
# frame (1301): Operational_testing
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Operational_testing.xml
#
# [definition]
#   A Tester uses a concrete or conceptual Product in order to
#   determine either whether it works or to find out how well or in
#   which manner it works. The Tester may have particular
#   Unwanted_characteristics in mind that they are specifically
#   looking for. The operational test may also be carried out under a
#   particular set of Circumstances that are typically relevant to
#   the functioning of the Product.  'Sun has (hopefully) already
#   tested it for compliance.' 'The Velcro hook and loop closure
#   system has been tested under wet conditions and retains its
#   holding power after 10,000 open and close functions. CNI INI'
#   'Roe revisited the compound and tested it as a mosquito
#   repellent.'
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Operating_a_system -- Using -> Child=Operational_testing>
#
# [lexUnit] 10 lexical units
#   crash-test.v (11465), flight test.n (12255), flight test.v
#   (13084), flight-test.v (11464), flight-testing.n (11467), test.n
#   (11463), test.v (11462), testing.n (11466), trial.n (18806), try
#   out.v (18808)
#
# [FE] 17 frame elements
#             Core: Desired_state_of_affairs (7369), Product (7362), Purpose (7365), Tested_property (7375), Tester (7361), Unwanted_characteristics (7363)
#       Peripheral: Degree (7367), Duration (7372), Function (7374), Manner (7366), Means (7364), Place (7373), Time (7370)
#   Extra-Thematic: Circumstances (7371), Location_of_protagonist (7368), Period_of_iterations (11033), Result (11080)
#
# [FEcoreSets] 1 frame element core sets
#   Purpose, Unwanted_characteristics, Tested_property, Desired_state_of_affairs

# %% [markdown]
# ## output word sets to file

# %%
def get_derivationally_related_words(ss_set, stemmer, pos="a"):
    new_pos_ss_set = []
    for ss1 in ss_set:
        #for ss2 in wn.synsets(stemmer.stem(ss1.name()),"a"):
        for l in ss1.lemmas():
            #[l.name() for l in sadness_ss.lemmas()]
            for ss_res in wn.synsets(stemmer.stem(l.name()),pos):
                new_pos_ss_set.append(ss_res)
    return new_pos_ss_set

def ss_set_to_word_set (ss_set):
    return sorted(list(set([nm for ss in ss_set for nm in ss.lemma_names()])))

# %%
with open("expressive_corpora/emotion_nouns_0.1.txt","w") as ofh:
    for wd in emotion_noun_words:
        print(wd,file=ofh)

# %%
with open("expressive_corpora/emotion_adjectives_0.1.txt","w") as ofh:
    for wd in emotion_adjective_words:
        print(wd,file=ofh)

# %%
with open("expressive_corpora/extended_experiencer_focus_adjectives_wn.txt","w") as ofh:
    for wd in extended_experiencer_focus_adjectives_wn:
        print(wd,file=ofh)

# %%
with open("expressive_corpora/extended_stimulus_focus_adjectives_wn.txt","w") as ofh:
    for wd in extended_stimulus_focus_adjectives_wn:
        print(wd,file=ofh)
