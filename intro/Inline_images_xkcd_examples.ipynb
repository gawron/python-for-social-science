# %% [markdown]
# From [IPython image display in Notebooks page](http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb)

# %%
from IPython.display import Image, IFrame, display, HTML

# %%
img_url ="https://imgs.xkcd.com/comics/boyfriend.png"
Image(url=img_url)
# Out:
# <img src="https://imgs.xkcd.com/comics/boyfriend.png"/>

# %%
img_url = "https://imgs.xkcd.com/comics/earth_temperature_timeline.png"
Image(url=img_url)
# Out:
# <img src="https://imgs.xkcd.com/comics/earth_temperature_timeline.png"/>

# %%
img_url = "https://imgs.xkcd.com/comics/fireflies.png"

Image(url=img_url)
# Out:
# <img src="https://imgs.xkcd.com/comics/fireflies.png"/>

# %%
img_url = "https://imgs.xkcd.com/comics/phase_change.png"
Image(url=img_url)
# Out:
# <img src="https://imgs.xkcd.com/comics/phase_change.png"/>

# %%
img_url = "https://imgs.xkcd.com/comics/the_maritime_approximation.png"
Image(url=img_url)
# Out:
# <img src="https://imgs.xkcd.com/comics/the_maritime_approximation.png"/>

# %% [markdown]
# Verifying:

# %%
import numpy as np
#knot/mph  (100 knots is approx 115 mph)
k = 1.15078
1 - (k*np.e)/np.pi
# Out:
# 0.004280723988937973

# %% [markdown]
# ## Exercise
#
# What is the speed of light in megaknots (1 megaknot = 1 million knots)?

# %%
# approx speed of light in mps
c = 1.860e+05
# megaknots per knot
kpmk = 1e-6
# Speed of light in megaknots
print(f"The speed of light is {c*60*60*k*kpmk:.1f} megaknots.")
# Out:
# The speed of light is 770.6 megaknots.
